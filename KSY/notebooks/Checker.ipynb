# %%
import csv
import pandas as pd
test_csv = pd.read_csv('/opt/ml/dataset/test/test_data.csv')

# %%
test_csv.head(10)
# Out:
#    id                                           sentence  \
# 0   0               지난 15일 MBC '탐사기획 스트레이트'가 이 사실을 보도했다.
# 1   1  사랑스러운 ‘프린세스 프링’의 이름은 봄의 공주님: Princess(s)Pring이...
# 2   2  한편, 본인(이근안)을 모델로 한 MBC 특집드라마 가 1995년 6.25 특집극으...
# 3   3  정창손은 김질과 같이 대궐로 달려가 고변하며 '신은 실로 모르고 김질만 혼자 참여하...
# 4   4  당시 민주당 이진련 시의원은 권영진 시장에게 "긴급 생계자금을 왜 현금으로 지원하지...
# 5   5  미국은 필리핀 측에서는 동맹이 아니라 지배자가 되었다고 볼 수 있기 때문에, 필리핀...
# 6   6  한국당 전희경 대변인은 이날 정 총리 후보자 지명 직후 논평을 내고 "의회를 시녀화...
# 7   7  문재인 대통령 부인 김정숙 여사는 22일부터 1박2일 일정으로 광주를 방문해 경기를...
# 8   8  조선민주주의인민공화국 관할 지역은 개풍군 영북면 월고리 및 연천군 서남면 지역을 합...
# 9   9         소련군에서 그의 이름도 중국식의 진지첸으로 조선인으로서의 정체성도 희박했다.
#
#                                       subject_entity  \
# 0  {'word': 'MBC', 'start_idx': 7, 'end_idx': 9, ...
# 1  {'word': '프린세스 프링', 'start_idx': 7, 'end_idx':...
# 2  {'word': '경찰', 'start_idx': 121, 'end_idx': 12...
# 3  {'word': '세조', 'start_idx': 78, 'end_idx': 79,...
# 4  {'word': '민주당', 'start_idx': 3, 'end_idx': 5, ...
# 5  {'word': '필리핀', 'start_idx': 4, 'end_idx': 6, ...
# 6  {'word': '전희경', 'start_idx': 4, 'end_idx': 6, ...
# 7  {'word': '문재인', 'start_idx': 0, 'end_idx': 2, ...
# 8  {'word': '조선민주주의인민공화국', 'start_idx': 0, 'end_i...
# 9  {'word': '소련군', 'start_idx': 0, 'end_idx': 2, ...
#
#                                        object_entity  label     source
# 0  {'word': '탐사기획 스트레이트', 'start_idx': 12, 'end_i...    100   wikitree
# 1  {'word': '공주', 'start_idx': 84, 'end_idx': 85,...    100  wikipedia
# 2  {'word': '1995년', 'start_idx': 31, 'end_idx': ...    100  wikipedia
# 3  {'word': '정창손', 'start_idx': 0, 'end_idx': 2, ...    100  wikipedia
# 4  {'word': '권영진', 'start_idx': 16, 'end_idx': 18...    100   wikitree
# 5  {'word': '미국', 'start_idx': 0, 'end_idx': 1, '...    100  wikipedia
# 6  {'word': '한국당', 'start_idx': 0, 'end_idx': 2, ...    100   wikitree
# 7  {'word': '김정숙', 'start_idx': 11, 'end_idx': 13...    100   wikitree
# 8  {'word': '개풍군', 'start_idx': 19, 'end_idx': 21...    100  wikipedia
# 9  {'word': '진지첸', 'start_idx': 18, 'end_idx': 20...    100  wikipedia

# %%
kfold = pd.read_csv('/opt/ml/level2-klue-level2-nlp-03/eunki/code/prediction_kfold10_2400/final/submission_final_roberta_large_end.csv')
stratified2400 = pd.read_csv('/opt/ml/level2-klue-level2-nlp-03/eunki/code/prediction_2e-5_2400/final/submission_final_roberta_large_end.csv')

# %%
cnt
# Out:
# 392

# %%
cnt = 0
for idx, (ks, strs) in enumerate(zip(kfold['pred_label'], stratified2400['pred_label'])):
    if ks != strs:
        print('-'*10)
        print(idx, test_csv['sentence'][idx],test_csv['subject_entity'][idx], test_csv['object_entity'][idx])
        print(ks, ' '*4, strs)
        print('-'*10)
        cnt+= 1
# Out:
# ----------
# 79 드와이트 라이먼 무디(Dwight Lyman Moody, 드와이트 라이먼 무디, 1837년 2월 5일 ~ 1899년12월 22일)은 미국의 침례교 평신도 설교자이다. {'word': '침례교', 'start_idx': 78, 'end_idx': 80, 'type': 'ORG'} {'word': '미국', 'start_idx': 74, 'end_idx': 75, 'type': 'LOC'}
# org:place_of_headquarters      per:religion
# ----------
# ----------
# 93 LG전자가 글로벌 자동차 업체 GM의 프리미엄 브랜드 ‘캐딜락’에 플라스틱 OLED(P-OLED) 기반 디지털 콕핏 시스템을 세계 최초로 공급한다고 6일 밝혔다. {'word': 'GM', 'start_idx': 17, 'end_idx': 18, 'type': 'ORG'} {'word': '캐딜락', 'start_idx': 31, 'end_idx': 33, 'type': 'POH'}
# org:product      org:members
# ----------
# ----------
# 97 이경자 정의당 국회의원 예비후보는 포스코 측에 조속한 시일 내 노조의 면담요청에 응하고 전면적인 안전보건 진단을 실시할 것을 제안한다. {'word': '정의당', 'start_idx': 4, 'end_idx': 6, 'type': 'ORG'} {'word': '후보', 'start_idx': 15, 'end_idx': 16, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 99 2008년 2월 2일에 실시된 러시아 대통령 선거에서 그의 후계자로 알려진 메드베데프가 70% 득표로 당선되었다. {'word': '메드베데프', 'start_idx': 42, 'end_idx': 46, 'type': 'PER'} {'word': '후계자', 'start_idx': 33, 'end_idx': 35, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 108 공단 강병흥 세종지부장은 “앞으로도 세종시 이전 공무원의 일·가정양립 지원을 위해 공무원과 자녀들이 함께할 수 있는 다채로운 복지프로그램을 마련할 계획이다”고 말했다. {'word': '강병흥', 'start_idx': 3, 'end_idx': 5, 'type': 'PER'} {'word': '공무원', 'start_idx': 27, 'end_idx': 29, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 110 졸업생 여러분을 모교가 응원하듯, 여러분의 전남대학교를 늘 가슴에 품고 사랑하십시오. {'word': '전남대학교', 'start_idx': 24, 'end_idx': 28, 'type': 'ORG'} {'word': '졸업생', 'start_idx': 0, 'end_idx': 2, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 124 한편 에버르는 연적을 죽이려고 했으나 판드가 쿠 훌린을 얼마나 사랑하는지 목격하고는 그냥 쿠 훌린을 그녀에게 넘겨주기로 마음먹는다. {'word': '판드', 'start_idx': 21, 'end_idx': 22, 'type': 'PER'} {'word': '쿠 훌린', 'start_idx': 25, 'end_idx': 28, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 138 광주시 광산구 신창동 관계자는 “휘현 단원들은 늦게 가야금을 시작했지만, 그동안 ‘ACC와 함께하는 광주음악제’를 비롯해 거리 버스킹 등 수많은 무대에서 내공을 쌓아왔기에 탄탄한 공연을 펼칠 것으로 자신한다”며 “첫 공연을 축하하고, 더 많은 시민이 주민자치 프로그램에서 출발해 끼와 재능을 계발해서 지역사회와 공유할 수 있도록 지원하겠다”고 밝혔다. {'word': '휘현', 'start_idx': 18, 'end_idx': 19, 'type': 'PER'} {'word': '신창동', 'start_idx': 8, 'end_idx': 10, 'type': 'ORG'}
# per:employee_of      org:place_of_headquarters
# ----------
# ----------
# 163 11월 12일에는 평화민주당을 창당해 대표 겸 13대 대통령 후보로 선출된 이후 야당 후보였던 김영삼과 후보 단일화를 이루지 못한 채 12월 16일에 제13대 대통령 선거에 출마했지만, 노태우와 김영삼에게 밀려 611만 표를 얻고 낙선했다. {'word': '김영삼', 'start_idx': 53, 'end_idx': 55, 'type': 'PER'} {'word': '노태우', 'start_idx': 104, 'end_idx': 106, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 171 스페인 왕위 계승 전쟁에 휘말려, 1714년 바르셀로나 공방전에서 패배한 카탈루냐는 카스티야 왕국의 영토가 되었다. {'word': '카탈루냐', 'start_idx': 41, 'end_idx': 44, 'type': 'ORG'} {'word': '스페인', 'start_idx': 0, 'end_idx': 2, 'type': 'LOC'}
# org:member_of      no_relation
# ----------
# ----------
# 175 2008년 경선에서는 그의 풍부한 상원에서의 경험에도 불구하고 버락 오바마와 힐러리 클린턴에 밀려 일찌감치 경선을 포기했다. {'word': '상원', 'start_idx': 19, 'end_idx': 20, 'type': 'ORG'} {'word': '버락 오바마', 'start_idx': 35, 'end_idx': 40, 'type': 'PER'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 192 'YG 환장의 콤비' 양현석X승리가 입건됐다. {'word': 'YG', 'start_idx': 1, 'end_idx': 2, 'type': 'ORG'} {'word': '양현석', 'start_idx': 12, 'end_idx': 14, 'type': 'PER'}
# per:employee_of      org:top_members/employees
# ----------
# ----------
# 209 LG유플러스는 ▲멸종위기 동식물 ▲가상 현실 증강 현실 ▲토목과 건축 ▲카메라 ▲기생충 ▲익충과 해충 등 총 6권을 원작에 기반해 3D 애니메이션과 음향효과를 주어 마치 원작에 들어와 있는 듯한 실감형 콘텐츠로 탈바꿈시켰다. {'word': 'LG유플러스', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '카메라', 'start_idx': 40, 'end_idx': 42, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 214 문재인 대통령이 김정은 북한 국무위원장을 오는 25일 부산에서 열리는 한·아세안 특별정상회의에 초청했지만 북한이 21일 '정중히' 거절했다. {'word': '문재인', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '김정은', 'start_idx': 9, 'end_idx': 11, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 234 지난 3.1절 여운형 선생 등 54명의 사회주의 계열 독립투사 서훈에 이어 주요한 사회주의 활동가들에 대해 재조명해 뒤늦게 서훈이 추서되었다. {'word': '여운형', 'start_idx': 8, 'end_idx': 10, 'type': 'PER'} {'word': '사회주의', 'start_idx': 22, 'end_idx': 25, 'type': 'POH'}
# no_relation      per:religion
# ----------
# ----------
# 242 그 리고 그의 가족들은 닉이 너무 빨리 사랑에 빠지는것을 못마땅해한다. 가끔 케빈의 터무니 없는 행동에 참을성을 잃기도 하지만 닉은 멤버들 중에서는 가장 진지하다. {'word': '케빈', 'start_idx': 43, 'end_idx': 44, 'type': 'PER'} {'word': '닉', 'start_idx': 13, 'end_idx': 13, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 259 bhc치킨은 오는 22일까지 BSR(bhcCSR) 공식 블로그와 페이스북을 통해 봉사활동 추천 댓글 이벤트를 펼친다. {'word': 'bhc치킨', 'start_idx': 0, 'end_idx': 4, 'type': 'ORG'} {'word': 'bhcCSR', 'start_idx': 20, 'end_idx': 25, 'type': 'ORG'}
# no_relation      org:alternate_names
# ----------
# ----------
# 291 지난 12일 샤이니 멤버 태민은 인스타그램에 "멤버들 나 오늘 투어 잘 마쳤어! 보고 싶다~"라는 글을 남기며 사진을 게재했다. {'word': '샤이니', 'start_idx': 7, 'end_idx': 9, 'type': 'PER'} {'word': '멤버', 'start_idx': 26, 'end_idx': 27, 'type': 'POH'}
# per:employee_of      no_relation
# ----------
# ----------
# 298 아랍에미리트의 관광업은 급격하게 성장하고 있고, 정부 차원에서도 대대적으로 투자하는 분야들 중 하나이다. {'word': '정부', 'start_idx': 27, 'end_idx': 28, 'type': 'ORG'} {'word': '아랍에미리트', 'start_idx': 0, 'end_idx': 5, 'type': 'LOC'}
# org:place_of_headquarters      org:member_of
# ----------
# ----------
# 339 영국은 한국전쟁 때 미국에 이어 두 번째로 가장 큰 규모의 UN 소속의 UN군을 파견한 바 있다. {'word': 'UN', 'start_idx': 33, 'end_idx': 34, 'type': 'ORG'} {'word': '영국', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 391 최종 계급은 육군 원수. 동부전선에서는 물론, 노르망디 상륙작전 이후의 서부전선에서도 방어전으로 명성을 쌓았으며 독일 제3국 최고의 방어전 지휘관이며 제2차 세계 대전 최고의 방어전 지휘관이다. {'word': '육군', 'start_idx': 7, 'end_idx': 8, 'type': 'ORG'} {'word': '지휘관', 'start_idx': 78, 'end_idx': 80, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 393 옥스퍼드 대학교 명예 박사학위를 비롯한 수많은 학위와 미국의 자유의 훈장, 프랑스의 레종 도뇌르 훈장 등 온갖 상훈, 영국의 명예 기사작위까지도 있다. {'word': '옥스퍼드 대학교', 'start_idx': 0, 'end_idx': 7, 'type': 'ORG'} {'word': '영국', 'start_idx': 66, 'end_idx': 67, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 404 또한 유비를 행대사마 영사례교위로 추천했으며 유비는 유장을 행진서대장군(行鎭西大將軍) 영익주목으로 추천하였다. {'word': '유장', 'start_idx': 29, 'end_idx': 30, 'type': 'PER'} {'word': '유비', 'start_idx': 25, 'end_idx': 26, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 431 전북 김제시가 '김제시 행정기구 설치 조례 일부개정조례안'(이하 조직개편안)과 '지방공무원 정원 조례 일부개정안(이하 정원 조례 개정안)'을 추진하는 과정에서 1일, 김제시의회 의원 간담회 보고 안건에 또다시 등장하면서 김주택 의원이 강한 불만을 쏟아 냈다. {'word': '김주택', 'start_idx': 123, 'end_idx': 125, 'type': 'PER'} {'word': '김제시', 'start_idx': 3, 'end_idx': 5, 'type': 'ORG'}
# no_relation      per:employee_of
# ----------
# ----------
# 435 이 영화의 제작사 케이퍼필름 안수현 대표는 조승우를 선택한 이유에 대하여 "김원봉의 경우 고민을 많이 할 수 밖에 없었다. 젊은 층에선 김원봉이란 인물을 알지 못하는 경우도 많더라. 독립운동을 풍미했던 대단한 인물이라는 점을 부각시키기 위해선 그 만큼 '임팩트' 강한 배우가 필요했다."라고 밝혔다. {'word': '김원봉', 'start_idx': 42, 'end_idx': 44, 'type': 'PER'} {'word': '조승우', 'start_idx': 24, 'end_idx': 26, 'type': 'PER'}
# per:alternate_names      no_relation
# ----------
# ----------
# 445 알렉은 다넬과 미스티, 토드를 '광대 삼남매'라고 부른다. {'word': '미스티', 'start_idx': 8, 'end_idx': 10, 'type': 'PER'} {'word': '알렉', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 473 전남 순천이 고향인 김창수 서장은 1999년 제11기 소방간부후보생으로 입문해 전남소방교육대장, 전남소방본부 구조구급과장 등 주요요직을 두루 거쳤으며, 특히, 직원 상호 간 배려와 소통을 바탕으로 탁월한 업무 추진력과 통솔력을 겸비한 지휘관으로 인정받고 있다. {'word': '김창수', 'start_idx': 11, 'end_idx': 13, 'type': 'PER'} {'word': '구조구급과장', 'start_idx': 61, 'end_idx': 66, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 495 나해수 진안군수 권한대행은 "정월대보름 행사는 한해의 액운을 쫒아내고 풍년이 들도록 기원하는 우리민족 고유의 전통행사이지만 신종 코로나바이러스가 확산되는 상황에서 군민들의 안전과 건강을 최우선으로 고려해 취소하기로 결정했다"고 밝혔다. {'word': '나해수', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '군수', 'start_idx': 6, 'end_idx': 7, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 518 노산대군은 세종의 적장손이고 문종의 적장자이니 옳고, 세조는 세종대왕의 차남으로 왕통을 이었으니 옳다는 것이었다. {'word': '세조', 'start_idx': 30, 'end_idx': 31, 'type': 'PER'} {'word': '문종', 'start_idx': 16, 'end_idx': 17, 'type': 'PER'}
# per:other_family      per:parents
# ----------
# ----------
# 520 숀은 레논의 35번째 생일이었던 1975년 10월 9일 제왕 절개를 통해 출생했다. {'word': '숀', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '레논', 'start_idx': 3, 'end_idx': 4, 'type': 'PER'}
# per:parents      per:alternate_names
# ----------
# ----------
# 534 정명훈은 18세에 런던에서 줄리니가 연주하는 베토벤 교향곡 제7번을 듣고 작품의 핵심을 짚어내는 연주에 깊은 감명을 받았으며 마리아 쿠르초의 소개로 무대 뒤에서 그를 만났다. {'word': '줄리니', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'} {'word': '정명훈', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 587 이 관계자는 이어 "문 대통령을 비롯해 청와대는 코로나19 대응에 매진하겠다는 의지를 밝힌 것"이라면서 "이는 문재인 대통령의 확고한 뜻"이라고 강조했다. {'word': '문', 'start_idx': 11, 'end_idx': 11, 'type': 'PER'} {'word': '관계자', 'start_idx': 2, 'end_idx': 4, 'type': 'POH'}
# per:colleagues      no_relation
# ----------
# ----------
# 588 결국 나중에 가서 카를은 보두앵 1세를 사위로 인정하고 864년 플랑드르 백작에 임명했다. {'word': '카를', 'start_idx': 10, 'end_idx': 11, 'type': 'PER'} {'word': '보두앵 1세', 'start_idx': 14, 'end_idx': 19, 'type': 'PER'}
# per:other_family      per:colleagues
# ----------
# ----------
# 598 이에 정부로부터 그 공훈을 인정받아 국방부 장관표창, 화랑·충무·을지무공훈장을 받았다. {'word': '국방부', 'start_idx': 20, 'end_idx': 22, 'type': 'ORG'} {'word': '정부', 'start_idx': 3, 'end_idx': 4, 'type': 'ORG'}
# org:member_of      no_relation
# ----------
# ----------
# 610 리정혁은 윤세리와 함께 더 있고 싶은 마음에 일부러 길을 헤맸고 이를 눈치 챈 윤세리는 웃었다. {'word': '리정혁', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '윤세리', 'start_idx': 5, 'end_idx': 7, 'type': 'PER'}
# per:spouse      per:colleagues
# ----------
# ----------
# 635 기독교의 성인. 로마 가톨릭에서 축일은 12월 26일이며, 동방 정교회에서 축일은 12월 27일이다. {'word': '로마 가톨릭', 'start_idx': 9, 'end_idx': 14, 'type': 'ORG'} {'word': '기독교', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'}
# org:political/religious_affiliation      no_relation
# ----------
# ----------
# 646 이 언약은 찰스 1세와 윌리엄 로드가 스코틀랜드 교회를 영국의 예배형식과 교회 정치에 따르는 것을 거부한 것이다. {'word': '찰스 1세', 'start_idx': 6, 'end_idx': 10, 'type': 'PER'} {'word': '스코틀랜드', 'start_idx': 21, 'end_idx': 25, 'type': 'LOC'}
# no_relation      per:origin
# ----------
# ----------
# 652 중부해경청에 따르면 최근 3년간 경기도 가평군 등 내수면에서 수상레저 활동 중 5명의 사망사고가 발생하였으며, 이들 대부분은 구명조끼를 착용하지 않은 것으로 확인되었다고 전했다. {'word': '중부해경청', 'start_idx': 0, 'end_idx': 4, 'type': 'ORG'} {'word': '경기도', 'start_idx': 18, 'end_idx': 20, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 664 또한, 글래드 여의도의 뷔페&카페 레스토랑 ‘그리츠’에서는 ‘갈비 가든’ 프로모션을 통해 그리츠 특제 양념으로 조리한 갈비 양념 구이와 돼지고기에 마늘종, 양파 등과 함께 간장과 식초로 간을 한 중국요리 회과육, 최근 떠오르는 식재료인 마라 소스를 활용하여 매콤하고 알싸한 맛을 낸 마라 갈비, 부드럽고 고소한 차돌박이를 넣고 끓인 차돌박이 된장찌개 등 다양한 요리를 선보이며, 고객 2인당 티본 스테이크 1접시를 제공하는 디너 스페셜 이벤트를 진행한다. 가격은 점심은 4만5100원, 저녁은 5만5000원(세금 포함)이다. {'word': '그리츠', 'start_idx': 25, 'end_idx': 27, 'type': 'ORG'} {'word': '갈비 가든', 'start_idx': 34, 'end_idx': 38, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 672 박정희가 죽었을 때, 한국에서 근무한 적이 있던 한 일본인 외교관이 자신의 저서에서 대일본제국 최후의 군인이 죽었다고 평하였다. {'word': '박정희', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '한국', 'start_idx': 12, 'end_idx': 13, 'type': 'LOC'}
# per:origin      per:place_of_death
# ----------
# ----------
# 675 그는 “이란의 솔레이마니 사령관 사망 이후 이라크 내 기대 프로젝트인 유정내 물공급시설, 발전소 등 3개 사업의 발주지연 가능성이 높아진 점이 아쉽다”라고 덧붙였다. {'word': '솔레이마니', 'start_idx': 8, 'end_idx': 12, 'type': 'PER'} {'word': '이라크', 'start_idx': 24, 'end_idx': 26, 'type': 'LOC'}
# no_relation      per:place_of_death
# ----------
# ----------
# 714 전북민중행동은 전주시의 롯데 재벌에 대한 특혜 행정 중단과 해당 상임위의 논의 결과도 무시한 채 전주시의 거수기로 전락해 버린 전주시의회의 롯데 특혜 예산 통과를 강력하게 규탄한다. {'word': '전주시', 'start_idx': 54, 'end_idx': 56, 'type': 'ORG'} {'word': '롯데', 'start_idx': 13, 'end_idx': 14, 'type': 'ORG'}
# no_relation      org:members
# ----------
# ----------
# 724 배우 한윤지 씨는 백송이 하사로 군인들 사이에서 유명하다. {'word': '백송이', 'start_idx': 10, 'end_idx': 12, 'type': 'PER'} {'word': '하사', 'start_idx': 14, 'end_idx': 15, 'type': 'POH'}
# per:alternate_names      per:title
# ----------
# ----------
# 739 이번 산학협력 교류회에서는 △LINC사업단 사업설명 △조선대학교 기술사업화 센터 기술이전 및 사업화 소개 △조선대학교 기술사업화센터 기술이전 및 사업화 상담 부스 운영 △2019 하계 현장실습수기공모전 및 광주 도시재생 우수 아이디어 공모전 시상식 △2019년 사업 3차년도 제1차 자체평가위원회 등이 진행됐다. {'word': 'LINC사업단', 'start_idx': 16, 'end_idx': 22, 'type': 'ORG'} {'word': '조선대학교', 'start_idx': 30, 'end_idx': 34, 'type': 'ORG'}
# no_relation      org:member_of
# ----------
# ----------
# 751 독일을 여행하고 있던 미국인 린지와 제니는 차가 고장나자 길을 잃게 된다. {'word': '제니', 'start_idx': 20, 'end_idx': 21, 'type': 'PER'} {'word': '독일', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# per:place_of_residence      no_relation
# ----------
# ----------
# 777 이번 릴레이 봉사활동 발대식은 광주광역시의 ‘시민참여형 광주천 가꾸기’ 사업에 적극 동참하는 의미로 광주은행은 지난 4월 광주시와 관련 협약을 체결한 가운데 7월부터 본격적인 광주천 정화활동에 나선다. {'word': '광주시', 'start_idx': 68, 'end_idx': 70, 'type': 'ORG'} {'word': '광주광역시', 'start_idx': 17, 'end_idx': 21, 'type': 'ORG'}
# org:alternate_names      org:member_of
# ----------
# ----------
# 780 전운판관이 되었을 때는 부안의 유명한 시인이자 기생인 매창(梅窓)과 교류한다. {'word': '매창', 'start_idx': 30, 'end_idx': 31, 'type': 'PER'} {'word': '부안', 'start_idx': 13, 'end_idx': 14, 'type': 'LOC'}
# per:origin      per:place_of_residence
# ----------
# ----------
# 802 또한 이미 지난 1482년에 7세의 차남 조반니를 성직자의 길을 걷도록 해두었다. {'word': '조반니', 'start_idx': 23, 'end_idx': 25, 'type': 'PER'} {'word': '차남', 'start_idx': 20, 'end_idx': 21, 'type': 'POH'}
# per:parents      no_relation
# ----------
# ----------
# 804 수리논리학의 발전은 20세기의 최초의 수십 년, 특히 괴델 및 타르스키의 저작에 의해서 일어나, 분석 철학이나 철학적 논리학, 특히 1950년대 이후에 양상 논리나 시제 논리, 의무 논리, 적정 논리 등에 영향을 주었다. {'word': '타르스키', 'start_idx': 35, 'end_idx': 38, 'type': 'PER'} {'word': '괴델', 'start_idx': 30, 'end_idx': 31, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 819 해방 직후 한민당의 당수인 송진우와 장덕수, 근로인민당수 여운형 등이 신탁통치의 불가피성을 주장하거나 신탁통치, 미소공위 개최에 찬성하다가 암살당했다. {'word': '장덕수', 'start_idx': 20, 'end_idx': 22, 'type': 'PER'} {'word': '송진우', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 829 광주전남혈액원 관계자는 매년 정기적인 헌혈 행사에 참여해준 전남도교육청 직원들에게 “여러분의 작은 사랑 큰 나눔이 소중한 생명을 살리고 헌혈 활성화 분위기 조성에 큰 도움이 되고 있다”고 감사의 뜻을 전했다. {'word': '광주전남혈액원', 'start_idx': 0, 'end_idx': 6, 'type': 'ORG'} {'word': '전남도교육청', 'start_idx': 33, 'end_idx': 38, 'type': 'ORG'}
# org:members      no_relation
# ----------
# ----------
# 832 《선조수정실록》에 따르면, 동인인 류성룡은 김덕령에게 죄가 있음이 확실하니 다른 죄인이 다다를 때까지 치죄를 신중히 따져가며 하도록 간했으나, 서인이며 윤근수의 형제인 판중추부사 윤두수는 즉시 엄벌에 처할 것을 주장했다. {'word': '류성룡', 'start_idx': 19, 'end_idx': 21, 'type': 'PER'} {'word': '동인', 'start_idx': 15, 'end_idx': 16, 'type': 'POH'}
# per:origin      per:employee_of
# ----------
# ----------
# 842 그러나 Girls´ Generation World Tour - Girls & Peace는 SM 엔터테인먼트의 자사 브랜드화를 위한 하향 평준화 정책 및 아시아 최고 연예 기획사를 목표로 하는 경영 방침으로 말미암아 월드 투어로 포장된 아시아 투어가 되고 말았다. {'word': 'SM 엔터테인먼트', 'start_idx': 50, 'end_idx': 58, 'type': 'ORG'} {'word': '아시아', 'start_idx': 85, 'end_idx': 87, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 859 1999년에는 ‘사로’ ‘생강’ 등 단편영화에서 발군의 실력을 인정받은 정지우 감독의 장편 데뷔작 《해피 엔드》에서 남편(최민식 분)과 정부(주진모 분) 사이의 불륜에 빠진 아내 최보라 역을 맡은 전도연은 옛 애인과 불륜을 저지르는 아이 엄마의 불안하고 복잡하고 예민한 심리를 빼어나게 연기했다. {'word': '최민식', 'start_idx': 68, 'end_idx': 70, 'type': 'PER'} {'word': '감독', 'start_idx': 44, 'end_idx': 45, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 959 민정당 소속으로 제11·12·13대 국회의원에 당선되었으며, 민정당 당무위원 겸 사무총장 등을 거쳐 민정당 당무위원 겸 원내총무를 거쳤다. {'word': '민정당', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '국회의원', 'start_idx': 20, 'end_idx': 23, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 974 장성규 씨는 지난 7월 '카스' 모델이 됐다고 밝혔었다. {'word': '장성규', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '카스', 'start_idx': 14, 'end_idx': 15, 'type': 'POH'}
# per:employee_of      no_relation
# ----------
# ----------
# 985 또한 한전공대 설립 비전으로 광주·전남 시도민의 염원과 대한민국 국민의 기대를 담아 ‘차세대 글로벌 인재를 양성하는 최고의 교육 산실, 한전공대’, ‘지속성장을 위한 혁신생태계 조성, 한전공대’라는 주제를 힘차게 선포했다. {'word': '한전공대', 'start_idx': 3, 'end_idx': 6, 'type': 'ORG'} {'word': '전남', 'start_idx': 19, 'end_idx': 20, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 1006 토트넘 진영에서 공을 잡은 손흥민은 약 75ｍ를 질주하며 무려 6명의 번리 선수를 따돌리고 골망을 흔들었다. {'word': '번리', 'start_idx': 39, 'end_idx': 40, 'type': 'ORG'} {'word': '6명', 'start_idx': 35, 'end_idx': 36, 'type': 'NOH'}
# org:number_of_employees/members      no_relation
# ----------
# ----------
# 1034 한편 김정희 의원은 제11대 전라남도의회 농수산위원회 부위원장, 의회운영위원회 위원으로 활동하면서 도민의 행복한 삶을 위해 성실히 의정활동을 수행하고 있다. {'word': '의회운영위원회', 'start_idx': 36, 'end_idx': 42, 'type': 'ORG'} {'word': '위원', 'start_idx': 44, 'end_idx': 45, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 1110 현재 조선민주주의인민공화국 축구 2부 리그 사이의 승강제는 실시하지 않는다. {'word': '조선민주주의인민공화국', 'start_idx': 3, 'end_idx': 13, 'type': 'ORG'} {'word': '축구', 'start_idx': 15, 'end_idx': 16, 'type': 'POH'}
# org:product      org:members
# ----------
# ----------
# 1124 윰댕과 대도서관의 러브 스토리와 인생 역전 성공 스토리는 7일 오후 9시 MBC '휴먼 다큐 사람이 좋다'에서 공개된다. {'word': '윰댕', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'} {'word': '대도서관', 'start_idx': 4, 'end_idx': 7, 'type': 'PER'}
# no_relation      per:alternate_names
# ----------
# ----------
# 1150 엔딩 후 오박사가 마을에 별장을 두고 있으며, 박사가 머무는 동안 전국 도감의 완성도를 평가받을 수 있다. {'word': '오', 'start_idx': 5, 'end_idx': 5, 'type': 'PER'} {'word': '박사', 'start_idx': 6, 'end_idx': 7, 'type': 'POH'}
# per:alternate_names      no_relation
# ----------
# ----------
# 1157 박용기(朴容琪, 1929년 ~ 2012년)는 예비역 대한민국 육군 대령이다. {'word': '육군', 'start_idx': 34, 'end_idx': 35, 'type': 'ORG'} {'word': '예비역', 'start_idx': 25, 'end_idx': 27, 'type': 'POH'}
# no_relation      org:top_members/employees
# ----------
# ----------
# 1177 36년간 잊었던 태극기가 게양되었고, 일동의 애국가 제창, 이화여전의 환영가 제창, 홍명희의 환영사, 러취 군정장관의 축사 후 김구의 답사와 이승만의 답사가 있었고, 만세삼창으로 환영회는 폐회되었다. {'word': '김구', 'start_idx': 71, 'end_idx': 72, 'type': 'PER'} {'word': '홍명희', 'start_idx': 47, 'end_idx': 49, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 1194 후일 당시 에든버러 대학교의 총장이 흄을 무신론자로 간주하였기 때문이라는 것이 알려졌다. {'word': '에든버러 대학교', 'start_idx': 6, 'end_idx': 13, 'type': 'ORG'} {'word': '흄', 'start_idx': 20, 'end_idx': 20, 'type': 'PER'}
# no_relation      org:top_members/employees
# ----------
# ----------
# 1198 1980년 그랜홈은 미국 시민이 되었다. {'word': '그랜홈', 'start_idx': 6, 'end_idx': 8, 'type': 'PER'} {'word': '미국', 'start_idx': 11, 'end_idx': 12, 'type': 'LOC'}
# per:origin      per:place_of_residence
# ----------
# ----------
# 1210 인천 '주안식구파' 부두목 출신인 유튜버 B씨가 올린 '진짜 조폭과 가짜 조폭 구별법' 영상은 조회 수 100만 달성을 앞둘 정도로 화제를 모으고 있다. {'word': 'B', 'start_idx': 23, 'end_idx': 23, 'type': 'PER'} {'word': '인천', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# no_relation      per:place_of_residence
# ----------
# ----------
# 1233 히틀러유겐트 사단이 캐나다군 선봉 부대 일부를 압박해 3킬로미터 이상 후퇴시켰지만, 노스 노바스코샤 하이랜더 연대 잔존병들은 제25 SS 기갑척탄병 연대를 저지하고 견고한 방어선을 구축했다. {'word': '캐나다군', 'start_idx': 11, 'end_idx': 14, 'type': 'ORG'} {'word': '노스 노바스코샤 하이랜더 연대', 'start_idx': 47, 'end_idx': 62, 'type': 'ORG'}
# no_relation      org:members
# ----------
# ----------
# 1234 그는 2년간 바커의 감독을 맡으며 시즌을 리그 4위와 5위로 마무리하였다. {'word': '바커', 'start_idx': 7, 'end_idx': 8, 'type': 'PER'} {'word': '감독', 'start_idx': 11, 'end_idx': 12, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 1261 부파불교의 설일체유부의 논서 《대비바사론》 제172권에서도 동일한 취지로 말하고 있는데, 《순정리론》보다는 좀 더 자세하다. {'word': '부파불교', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': '대비바사론', 'start_idx': 17, 'end_idx': 21, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 1288 영화는 근로정신대 할머니와 함께 하는 시민모임(대표 이국언)의 요청으로 공무원과 시민을 대상으로 상영하며, 자세한 사항은 시 민주인권과(062-613-2083)에 문의하면 된다. {'word': '민주인권과', 'start_idx': 70, 'end_idx': 74, 'type': 'ORG'} {'word': '이국언', 'start_idx': 29, 'end_idx': 31, 'type': 'PER'}
# no_relation      org:top_members/employees
# ----------
# ----------
# 1289 2015년 6월 8일 덴마크 축구 국가대표팀과의 친선 경기에서 몬테네그로 대표팀 데뷔전을 치렀다. {'word': '축구 국가대표팀', 'start_idx': 16, 'end_idx': 23, 'type': 'ORG'} {'word': '덴마크', 'start_idx': 12, 'end_idx': 14, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 1341 그는 “삼성전기의 천진 공장은 2019년말 완공되어 20년 2분기부터 가동이 시작될 것으로 예상된다”며 “내년은 MLCC 수량이 전년대비 증가하고, 전장향 비중확대로 가격 하락 방어 가능성 높아 매출액 증가 가능성은 높다”고 지적했다. {'word': '삼성전기', 'start_idx': 4, 'end_idx': 7, 'type': 'ORG'} {'word': '천진', 'start_idx': 10, 'end_idx': 11, 'type': 'LOC'}
# no_relation      org:members
# ----------
# ----------
# 1349 세이브더 칠드런이 창립 100 주년을 맞이해 전북지역 초등학교와 중학교 아이들에게 자신에게 상처를 준 말을 쓰고, 그 말을 통해서 느낀 감정을 그림으로 그려서 보여 주는 행사인 전시행사가 22일 전북도교육청에서 열렸다. {'word': '세이브더 칠드런', 'start_idx': 0, 'end_idx': 7, 'type': 'ORG'} {'word': '전북', 'start_idx': 25, 'end_idx': 26, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 1364 곡성군 제7기 생활공감정책 참여단은 전라남도에서 3월 출범식을 갖고 현재 우리 군에서는 차미희 회장님을 비롯하여 5명이 활동을 하고 있다. {'word': '곡성군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '회장', 'start_idx': 53, 'end_idx': 54, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 1366 청조의 보호 하에 달라이 라마 정권이 성립하면서, 5대 달라이 라마로부터 티베트 불교계의 서열2위를 획득했다. {'word': '불교', 'start_idx': 45, 'end_idx': 46, 'type': 'ORG'} {'word': '티베트', 'start_idx': 41, 'end_idx': 43, 'type': 'LOC'}
# org:place_of_headquarters      org:political/religious_affiliation
# ----------
# ----------
# 1400 아르튀르 2세의 집권 시기는 리모주의 마리와 첫 번째 혼인, 스코클랜드 왕비 드뢰의 욜랑드와 두 번째 혼인 등 두 차례의 혼인으로 유명하기도 하다. {'word': '아르튀르 2세', 'start_idx': 0, 'end_idx': 6, 'type': 'PER'} {'word': '리모주', 'start_idx': 16, 'end_idx': 18, 'type': 'LOC'}
# per:spouse      no_relation
# ----------
# ----------
# 1461 전라남도가 ‘청정 전남, 블루 이코노미’ 6대 핵심 프로젝트 가운데 하나인 ‘블루 에너지’ 분야에서 대규모 해상풍력발전단지 조성에 박차를 가하고 있다. {'word': '전라남도', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': '청정 전남, 블루 이코노미', 'start_idx': 7, 'end_idx': 20, 'type': 'POH'}
# no_relation      org:alternate_names
# ----------
# ----------
# 1487 2018년에는 많은 주민들이 최근 살기 힘들다고 말은 하면서 적지 않은 돈이 드는 만수대 TV 설치에 극성이다면서 지역 우체국에서는 핀잔을 주었지만 이에 아랑곳하지 않았으며 외국 영화에 대한 인기가 날이 갈수록 높아지고 있다는 점을 당국도 알고 있다고 지적하고 이 같은 결정은 조선민주주의인민공화국 당국의 의도와는 달리 주민들의 외부 정보에 대한 호기심을 자극하는 방향으로 흘러갈 가능성도 있다. {'word': '우체국', 'start_idx': 67, 'end_idx': 69, 'type': 'ORG'} {'word': '조선민주주의인민공화국', 'start_idx': 155, 'end_idx': 165, 'type': 'ORG'}
# org:place_of_headquarters      org:member_of
# ----------
# ----------
# 1494 들은 "맛녀석 초창기 방송보면 이 정도로 뚱뚱하지 않았음...이 프로도 출연진 건강 좀 챙겨주길", "진짜 어제 재방으로 초창기때 맛녀석 보는데 유민상 님 너무 날씬해서 깜짝놀랐다", "건강을 위해서라도 다이어트 좀 하시길", "주 1회 찍는 건데..다른날 적게 먹고 운동하면 됨. 그냥 다들 먹는 걸 좋아해서 살찌는거임", "심근경색 조심" 등의 반응을 보였다. {'word': '유민상', 'start_idx': 81, 'end_idx': 83, 'type': 'PER'} {'word': '출연진', 'start_idx': 40, 'end_idx': 42, 'type': 'POH'}
# per:employee_of      no_relation
# ----------
# ----------
# 1513 동구는 20일 동명동 ‘아이플렉스(I-PLEX) 광주’에서 동명동 건물주와 상가임차인 간 지역상권 활성화와 지역공동체 지속가능발전을 위한 상생협약을 맺었다고 밝혔다. {'word': '동구', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'} {'word': '동명동', 'start_idx': 8, 'end_idx': 10, 'type': 'LOC'}
# org:members      no_relation
# ----------
# ----------
# 1538 민주당 대통령 후보였던 조병옥의 비서관으로 정계에 입문해 민주당의 공천으로 고향 경북 달성군에서 두 차례 출마했다가 모두 낙선하는 비운을 맛보았고, 2전 3기 끝에 5대 총선에서 당선된 뒤 5대 국회에서는 김영삼과 함께 민주당 구파의 소장파로 활동했다. {'word': '김영삼', 'start_idx': 115, 'end_idx': 117, 'type': 'PER'} {'word': '경북', 'start_idx': 45, 'end_idx': 46, 'type': 'LOC'}
# no_relation      per:place_of_residence
# ----------
# ----------
# 1550 이러한 가운데 5월에 하타노 씨의 거성인 하치조 성이, 8월에 아카이 씨의 거성인 구로이 성이 함락되고, 이어 고립이 심화되게 된 아리오카 성에서는 9월에 성주 아라키 무라시게가 달아나고 10월에 함락되었다. {'word': '아라키 무라시게', 'start_idx': 90, 'end_idx': 97, 'type': 'PER'} {'word': '아리오카 성', 'start_idx': 73, 'end_idx': 78, 'type': 'POH'}
# per:employee_of      per:origin
# ----------
# ----------
# 1601 4일 MBC '놀면 뭐하니' 제작진은 이날 방송에 앞서 미리 일부를 선공개했다. {'word': 'MBC', 'start_idx': 3, 'end_idx': 5, 'type': 'ORG'} {'word': '제작진', 'start_idx': 16, 'end_idx': 18, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 1602 글쓴이는 조 씨와 나눈 카톡 사진을 캡처해 올리며 조 씨는 극우 성향 온라인 커뮤니티 일간베스트(일베) 회원이었으며, SBS 보도 내용과는 다르게 활발하고 말이 많던 친구였다고 주장했다. {'word': '조', 'start_idx': 5, 'end_idx': 5, 'type': 'PER'} {'word': '회원', 'start_idx': 58, 'end_idx': 59, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 1610 국토교통부의 한국철도영업거리표 상 노선 번호는 30213이다. {'word': '국토교통부', 'start_idx': 0, 'end_idx': 4, 'type': 'ORG'} {'word': '한국철도', 'start_idx': 7, 'end_idx': 10, 'type': 'POH'}
# no_relation      org:product
# ----------
# ----------
# 1664 그는 "유치원 때부터 같이 놀았던 친구 재하는 어릴 적 부터 노래를 하고 싶어했다. ... 나는 딱지치기하고 담타고 놀 때 재하는 혼자 그렇게 놀았다. 음악뿐 아니어도 당시 또래들과는 뭔가 달랐다. ... 잠시 서로 연이 끊어지고 대학교 때 원영이형(정원영)의 소개로 만나게 되었는데 재하가 건반 연주자라며 나타난 것이다. 무척 반가웠고 다시 우리는 음악하며 친하게 지내게 되었다."고 회고한다. {'word': '재하', 'start_idx': 159, 'end_idx': 160, 'type': 'PER'} {'word': '정원영', 'start_idx': 140, 'end_idx': 142, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 1672 조지 워싱턴이 대통령에 취임한 1789년 이후 약 10년 간은 미국 역사상 그 어느 때보다 알렉산더 해밀턴이 이끄는 강력한 중앙정부를 만들려는 연방주의자 (Federalist Party)와 토머스 제퍼슨이 이끄는 주의 독립과 자유를 지키려는 반연방주의자 (Anti-Federalism)로 분열과 정치싸움이 심한 때였다. {'word': '알렉산더 해밀턴', 'start_idx': 51, 'end_idx': 58, 'type': 'PER'} {'word': '연방주의자', 'start_idx': 80, 'end_idx': 84, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 1692 이번 임시회에서는 전라남도 제2회 추경예산안과 전남신용보증재단 이사장 후보자 인사 청문회, 도민 생활 편의 증진을 위한 각종 조례안 등 40건의 안건을 처리한다. {'word': '전남신용보증재단', 'start_idx': 26, 'end_idx': 33, 'type': 'ORG'} {'word': '이사장', 'start_idx': 35, 'end_idx': 37, 'type': 'POH'}
# no_relation      org:top_members/employees
# ----------
# ----------
# 1710 3일 국회 보건복지위원회 김광수(전북 전주시 갑, 민주평화당) 의원에 따르면 다른 사람에게 면허증을 대여, 면허가 취소된 의료인에 대해 면허를 재교부받지 못하도록 하는 제재를 강화하는 내용을 담은 '불법 사무장 병원 방지법'이 전날 국회를 통과했다. {'word': '김광수', 'start_idx': 14, 'end_idx': 16, 'type': 'PER'} {'word': '전북 전주시 갑', 'start_idx': 18, 'end_idx': 25, 'type': 'LOC'}
# per:place_of_residence      no_relation
# ----------
# ----------
# 1720 조광한 시장은 이날 오리엔테이션에 참석해, 남양주의 인문학적 자산인 정약용 선생과 동시대의 위인들 및 '신아지구방(新我之舊邦)'에 대한 설명과 함께 사회생활을 시작하는 대학생들에게 "향후 어떤 일을 하게 되더라도 새로운 변화를 위해 최선을 다한다면 좋은 성과가 있을 것"이라며 격려했다. {'word': '정약용', 'start_idx': 38, 'end_idx': 40, 'type': 'PER'} {'word': '선생', 'start_idx': 42, 'end_idx': 43, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 1735 1997년부터 2003년까지 잉글랜드의 더비 카운티 소속으로 뛰었고 2002년에는 선덜랜드로 임대 이적하기도 했지만 단 한 경기도 선발 출전하지 못했다. {'word': '선덜랜드', 'start_idx': 46, 'end_idx': 49, 'type': 'ORG'} {'word': '잉글랜드', 'start_idx': 16, 'end_idx': 19, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 1742 푸코와 마그리트는 시뮬라크르란 단어를 언급한 적은 없다. {'word': '마그리트', 'start_idx': 4, 'end_idx': 7, 'type': 'PER'} {'word': '푸코', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 1753 일본의 이러한 팽창정책은 이른바 대동아공영권을 앞세운 동남아시아 지역 개입으로 이어졌고 결국 태평양 전쟁을 일으키게 되었다. {'word': '일본', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'} {'word': '대동아공영권', 'start_idx': 18, 'end_idx': 23, 'type': 'ORG'}
# no_relation      org:political/religious_affiliation
# ----------
# ----------
# 1775 이후 정무원 부총리에 선임되고 1974년에는 남북조절위평양측공동위원장과 조선로동당 조직지도부장직을 겸직했으며 부총리에 선출되었다. {'word': '정무원', 'start_idx': 3, 'end_idx': 5, 'type': 'ORG'} {'word': '부총리', 'start_idx': 7, 'end_idx': 9, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 1812 사진 속 정우성 씨와 이정재 씨는 남우주연상 트로피를 들고 인증했다. {'word': '이정재', 'start_idx': 12, 'end_idx': 14, 'type': 'PER'} {'word': '정우성', 'start_idx': 5, 'end_idx': 7, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 1831 화랑대논문집은 육군사관학교 교수진의 연구 역량을 확대하고 인문사회학 및 자연과학 분야의 심층 연구 독려를 목적으로 1964년 육사논문집으로 창간되었으며, 2008년 64집 1권을 발간 후 한국군사학논집으로 권호를 이양하고 2008년 11월에 화랑대논문집으로 명칭을 변경하였다. {'word': '육군사관학교', 'start_idx': 8, 'end_idx': 13, 'type': 'ORG'} {'word': '한국군사학논집', 'start_idx': 105, 'end_idx': 111, 'type': 'POH'}
# no_relation      org:product
# ----------
# ----------
# 1841 스타니슬라프 예브그라포비치 페트로프(1939년 9월 7일 ~ 2017년 5월 19일)는 소련 방공군의 장교로, 1983년에 햇빛을 미국이 발사한 ICBM으로 오인한 소련 당국이 이에 맞대응으로 미사일을 발사하려던 것을 막은 일로 유명한 인물이다. {'word': '소련 방공군', 'start_idx': 49, 'end_idx': 54, 'type': 'ORG'} {'word': '소련', 'start_idx': 92, 'end_idx': 93, 'type': 'LOC'}
# org:place_of_headquarters      org:member_of
# ----------
# ----------
# 1846 강진군에 따르면 개인뿐만 아니라 공공기관 비롯해 기업 단체 등에서도 명절선물로 강진 토하젓이 각광을 받으며 택배주문이 쇄도하고 있다. {'word': '강진군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '강진', 'start_idx': 44, 'end_idx': 45, 'type': 'LOC'}
# org:alternate_names      no_relation
# ----------
# ----------
# 1851 인텔은 8080과 8085를 위한 개발 시스템 시리즈를 판매하였는데 Personal Development System이라 불렀다. {'word': '인텔', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'} {'word': '8085', 'start_idx': 10, 'end_idx': 13, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 1858 따라서, 섭관가는 딸을 천황의 후비로 입궁시켜 황자를 낳게 하는 것으로 성립되었는데, 섭관가의 피를 잇지 않은 고산조 천황(後三条天皇)이 즉위하자, 섭관가의 세력은 점차 쇠퇴하게 되었다. {'word': '고산조', 'start_idx': 62, 'end_idx': 64, 'type': 'PER'} {'word': '천황', 'start_idx': 13, 'end_idx': 14, 'type': 'POH'}
# per:alternate_names      per:title
# ----------
# ----------
# 1888 폭스 방송의 임원들이 이 영화를 봤고, 1995년에 임원 브라이언 그레이든이 친지들에게 비디오로 된 크리스마스 카드를 주려고 파커와 스톤에게 두 번째 단편을 의뢰했다. {'word': '파커', 'start_idx': 70, 'end_idx': 71, 'type': 'PER'} {'word': '스톤', 'start_idx': 74, 'end_idx': 75, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 1937 아워홈 관계자는 “올해 A1 멤버십 디너 위크는 할인행사와 함께 더 많은 고객들이 혜택을 누릴 수 있도록 블랙카드 연회비 할인 프로모션도 함께 진행한다”며 “모임이 많은 연말, 소중한 사람들과 함께 파인다이닝에서부터 캐주얼 레스토랑까지 아워홈이 제공하는 다양한 메뉴를 저렴하게 즐겨보시길 바란다”고 말했다. {'word': '아워홈', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': 'A1 멤버십', 'start_idx': 13, 'end_idx': 18, 'type': 'POH'}
# org:product      org:members
# ----------
# ----------
# 1940 (고노 씨는 오치 씨의 일족). 노지마 무라카미 씨는 고노 씨와 우호관계를 유지했지만 신하로 섬기지는 않았다. {'word': '고노', 'start_idx': 30, 'end_idx': 31, 'type': 'ORG'} {'word': '일족', 'start_idx': 13, 'end_idx': 14, 'type': 'POH'}
# per:origin      no_relation
# ----------
# ----------
# 1942 삼국의 영토가 넓어지고 중앙정부의 권력이 지방으로 뻗치면서 삼국은 중국의 군현제를 도입해 운영하기 시작했는데, 각국이 정복하여 세력권에 편입시킨 부족(部族)들의 땅에 성을 쌓고 행정의 중심으로 삼기 시작했고 그것이 나중에 군(郡)이 되었다. {'word': '중앙정부', 'start_idx': 13, 'end_idx': 16, 'type': 'ORG'} {'word': '삼국', 'start_idx': 0, 'end_idx': 1, 'type': 'NOH'}
# no_relation      org:member_of
# ----------
# ----------
# 1945 순간 보스니아 선수들은 주심을 의식하며 집중력을 잃었고 그사이 피터 오뎀윙기는 에메니케의 패스를 골로 연결했다. {'word': '피터 오뎀윙기', 'start_idx': 35, 'end_idx': 41, 'type': 'PER'} {'word': '선수', 'start_idx': 8, 'end_idx': 9, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 1979 2015년 10월 대한민국의 종합격투기 단체 로드 FC에서 진출했으며 데뷔전이 되는 "Road FC 026" 대회에서 최무배를 상대로 1라운드 37초 만에 KO승을 거두었다. {'word': '로드 FC', 'start_idx': 25, 'end_idx': 29, 'type': 'ORG'} {'word': '종합격투기', 'start_idx': 16, 'end_idx': 20, 'type': 'POH'}
# no_relation      org:member_of
# ----------
# ----------
# 1995 (이에 대해서는 후술). 1918년에는 페이튼 마치 소장이 육군 참모총장 취임하여 대장이되었지만, 그 후 1929년까지 육군 대장은 한 명도 나오지 않았다. {'word': '육군', 'start_idx': 67, 'end_idx': 68, 'type': 'ORG'} {'word': '참모총장', 'start_idx': 36, 'end_idx': 39, 'type': 'POH'}
# no_relation      org:members
# ----------
# ----------
# 1997 최 연구원은 “특히 계열사 중 하나금융투자는 IB부문 이익의 대폭적인 확대로 연간 순익이 2803억원을 기록해 84.3%나 증가한 점은 눈여겨봐야 할 대목”이라고 지적했다. {'word': '하나금융투자', 'start_idx': 17, 'end_idx': 22, 'type': 'ORG'} {'word': '최', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 2028 화순군(군수 구충곤)은 지난 13일 도암면 정천마을 취약지역 생활여건 개조사업의 성공적인 추진을 위해 추진위원회(위원장 박규주·이하 추진위원회) 위원과 주민 24명이 선진지를 견학했다고 밝혔다. {'word': '화순군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '위원장', 'start_idx': 63, 'end_idx': 65, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 2055 이번 패밀리 시즌패스 출시와 관련하여 휘닉스 호텔앤드리조트 관계자는 “이번 휘닉스 평창의 컨셉인 스노우 원더랜드와 더불어 가족 단위 고객들을 위한 만족도를 높이기 위한 이번 시즌 전략을 바탕으로 패밀리 시즌패스를 출시했다. 또한, 스키/보드와 더불어 아이들과 온 가족을 위한 스노우빌리지가 곧 오픈할 예정이니 많은 관심을 부탁한다”고 밝혔다. {'word': '휘닉스', 'start_idx': 42, 'end_idx': 44, 'type': 'ORG'} {'word': '평창', 'start_idx': 46, 'end_idx': 47, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 2110 지난 24일 대웅SNT가 광주시 광산구 첨단종합사회복지관의 ‘이웃이 이웃을 돌보는 마을연애사업’에 좋은 쓰임이 되기를 바란다며 투게더광산나눔문화재단을 통해 1,300만 원의 후원금을 전달했다. {'word': '투게더광산나눔문화재단', 'start_idx': 71, 'end_idx': 81, 'type': 'ORG'} {'word': '광주시', 'start_idx': 14, 'end_idx': 16, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 2123 무안군(군수 김산)은 1일 승달문화예술회관 소공연장에서 신규공직자 111명을 대상으로 청렴교육을 실시했다. {'word': '김산', 'start_idx': 7, 'end_idx': 8, 'type': 'PER'} {'word': '공직자', 'start_idx': 33, 'end_idx': 35, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 2126 그럼에도 불구하고, 파나리오테스에 대한 비판은 부분적으로 보통 외국인들에 대한 적개심을 하나로 통합한 루마니아 민족주의의 하나의 초점이었다. {'word': '파나리오테스', 'start_idx': 11, 'end_idx': 16, 'type': 'ORG'} {'word': '루마니아', 'start_idx': 57, 'end_idx': 60, 'type': 'LOC'}
# per:origin      no_relation
# ----------
# ----------
# 2131 김회재 연구원은 “그럼에도 기말 배당 9000원을 기준으로 배당수익률은 3.8%에 달한다”며 “SK텔레콤은 2007~2014년 DPS 9400원, 2015년 이후 DPS 1만원을 유지하고 있다”고 말했다. {'word': '김회재', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': 'SK텔레콤', 'start_idx': 53, 'end_idx': 57, 'type': 'ORG'}
# per:employee_of      no_relation
# ----------
# ----------
# 2146 2014년 2월, 쿠르투아는 리버풀 골키퍼 시몽 미뇰레가 항상 "겸손하고 존경심이 있어야 한다는 것을 그가 기억하여야 한다."라는 발언으로 벨기에 국가대표팀의 분위기에 찬물을 끼얹었다. {'word': '쿠르투아', 'start_idx': 10, 'end_idx': 13, 'type': 'PER'} {'word': '골키퍼', 'start_idx': 20, 'end_idx': 22, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 2170 훈련 이외에도 선수들은 유럽 축구 최고의 무대인 UEFA 챔피언스리그(리옹 vs 제니트)와 프랑스 최고의 라이벌전(리옹 vs 파리 생제르망) 경기 등을 관람하며 유럽 축구를 직접 보고 느낄 수 있는 시간도 가질 예정이다. {'word': '파리 생제르망', 'start_idx': 70, 'end_idx': 76, 'type': 'ORG'} {'word': '유럽', 'start_idx': 90, 'end_idx': 91, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 2175 그러나 전쟁이 끝난 뒤 남편 조지 6세의 건강이 급격히 나빠지면서 그녀는 51살의 나이에 남편과 사별했다. 가장 위험하고도 어렵던 시기에 에드워드 8세가 2번이나 이혼경력이 있는 미국인 여성 월리스 심프슨과의 결혼 문제로 무책임하게도 대영제국 왕위를 버림으로 왕위를 승계한 자신의 남편이 전쟁을 겪으며 쇠약해 졌다고 생각한 그녀는 윈저 공작 내외와 충돌이 잦았다. {'word': '조지 6세', 'start_idx': 16, 'end_idx': 20, 'type': 'PER'} {'word': '에드워드 8세', 'start_idx': 77, 'end_idx': 83, 'type': 'PER'}
# per:children      no_relation
# ----------
# ----------
# 2184 서울에서 태어나 경기도 광명시에서 성장한 박은지는 건국대학교 재학 시절이던 2003년 월드 미스 유니버시티 대회에 출전했으며, 본선 무대까지 진출했다. {'word': '박은지', 'start_idx': 23, 'end_idx': 25, 'type': 'PER'} {'word': '경기도', 'start_idx': 9, 'end_idx': 11, 'type': 'LOC'}
# per:place_of_birth      per:place_of_residence
# ----------
# ----------
# 2187 오후 7시 30분 독일 황제는 다시 전문을 보내 16사단은 룩셈부르크의 국경을 넘지 말 것을 명령하나 총사령관인 몰트케의 반대로 이 명령은 취소되고 8월 2일 16사단은 룩셈부르크로 진격해 오후에는 이미 룩셈부르크 전역이 독일 제4군의 영향권 안에 들게 된다. {'word': '몰트케', 'start_idx': 63, 'end_idx': 65, 'type': 'PER'} {'word': '독일', 'start_idx': 124, 'end_idx': 125, 'type': 'LOC'}
# per:origin      no_relation
# ----------
# ----------
# 2190 1783년 크림 반도를 합병한 예카테리나 2세는 "크림의 여차르(Tsaritsa)" 대신 그리스화된 "케르소네소스 타우리카의 여차르"를 칭했다. {'word': '예카테리나 2세', 'start_idx': 17, 'end_idx': 24, 'type': 'PER'} {'word': '크림 반도', 'start_idx': 6, 'end_idx': 10, 'type': 'LOC'}
# per:origin      per:place_of_residence
# ----------
# ----------
# 2237 2018년 아우디그룹은 아우디 브랜드 181만 2천여대, 람보르기니 스포츠카 5천 750대, 두카티 모터사이클 5만 3천 4대를 판매했으며, 592억 유로의 매출을 기록했다. {'word': '아우디그룹', 'start_idx': 6, 'end_idx': 10, 'type': 'ORG'} {'word': '람보르기니', 'start_idx': 32, 'end_idx': 36, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 2248 뤼티는 코르델린의 변호사가 되었고, 두 사람은 가까운 친구가 되었다. {'word': '코르델린', 'start_idx': 4, 'end_idx': 7, 'type': 'PER'} {'word': '뤼티', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 2249 메릴랜드주의 퍼스트 레이디로서 호건 여사는 자신의 모교 메릴랜드 예술 전문 대학교에서 부속 기능의 회원으로서 지속적으로 강의하였다. {'word': '호건', 'start_idx': 17, 'end_idx': 18, 'type': 'PER'} {'word': '여사', 'start_idx': 20, 'end_idx': 21, 'type': 'POH'}
# per:spouse      per:title
# ----------
# ----------
# 2259 오진 천황, 히메노카미, 진구 황후를 모시고 있다. {'word': '오진', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'} {'word': '천황', 'start_idx': 3, 'end_idx': 4, 'type': 'POH'}
# per:alternate_names      per:title
# ----------
# ----------
# 2263 군 관계자는 “앞으로도 젊은 엄마들이 각종 정보와 의견 교환은 물론 육아 스트레스 해소를 위해 참석할 수 있는 고흥사랑 수다방을 운영할 것이며 저출산 극복을 위해 어려움을 함께 나누며 지역 실정에 맞는 결혼, 출산, 양육정책 개발에 힘쓰도록 하겠다”고 밝혔다. {'word': '군', 'start_idx': 0, 'end_idx': 0, 'type': 'ORG'} {'word': '고흥사랑 수다방', 'start_idx': 62, 'end_idx': 69, 'type': 'POH'}
# org:members      no_relation
# ----------
# ----------
# 2275 강인규 시장은 인사말을 통해 “목표를 향해 꾸준히 노력해 나주와 대한민국 발전을 선도하고, 인성과 실력을 갖춘 우수 인재로 성장해주길 바란다”고 격려하며, “앞으로도 보편적 교육 복지 향상과 지역인재 육성을 위해 시민이 체감할 수 있는 다양한 교육 시책을 추진하겠다”고 말했다. {'word': '강인규', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '나주', 'start_idx': 32, 'end_idx': 33, 'type': 'ORG'}
# per:employee_of      per:place_of_residence
# ----------
# ----------
# 2277 광주시 서구(구청장 서대석)는 지난 23일 주택건설사업장에 대한 지역 전문건설회사 협력업체 참여 확대를 위해 HDC현대산업개발(주)과 양해각서를 체결했다. {'word': '서대석', 'start_idx': 11, 'end_idx': 13, 'type': 'PER'} {'word': '광주시', 'start_idx': 0, 'end_idx': 2, 'type': 'LOC'}
# per:employee_of      per:place_of_residence
# ----------
# ----------
# 2286 박종대 연구원은 “특히 중국에서 ‘후’는 점포수, 인터넷 사이트 증가 없이 기존점 성장률 만으로 40%가량 성장세를 시현했다는 점은 압도적인 브랜드력을 상징한다”라며 “‘후’는 지난해 2조원, 올해 매출액은 2조6000억원에 이를 것으로 예상된다”라고 전했다. {'word': '후', 'start_idx': 19, 'end_idx': 19, 'type': 'ORG'} {'word': '중국', 'start_idx': 13, 'end_idx': 14, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 2314 베네딕토 16세는 추기경들이 교황 선출을 위한 콘클라베 시작 일시를 앞당기는 것을 허용하는 자의교서를 2월 25일 발표했다. {'word': '베네딕토 16세', 'start_idx': 0, 'end_idx': 7, 'type': 'PER'} {'word': '교황', 'start_idx': 16, 'end_idx': 17, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 2321 부산항만공사는 지난 달 27일과 이번 달 11일, 두 차례에 걸쳐 부산지역 취약계층 아동과 독거노인에게 마스크․손소독제 등을 지원하기 위해 각각 1천만원, 5백만원을 기부한 바 있다. {'word': '부산항만공사', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '부산', 'start_idx': 37, 'end_idx': 38, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 2345 또한 군은 임산부 건강을 위한 태교교실․산후교실, 아빠와 함께하는 요리교실, 직장맘 고충상담, 임신부 체험 등의 다양한 육아프로그램도 함께 운영할 예정이다. {'word': '군', 'start_idx': 3, 'end_idx': 3, 'type': 'ORG'} {'word': '육아프로그램', 'start_idx': 67, 'end_idx': 72, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 2367 전남대병원 공공보건의료사업실과 광주이주민건강센터가 공동 추진하는 이번 검진에는 의사·간호사·행정직원 등이 파견된다. {'word': '광주이주민건강센터', 'start_idx': 17, 'end_idx': 25, 'type': 'ORG'} {'word': '간호사', 'start_idx': 47, 'end_idx': 49, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 2372 강인규 나주시장은 “음주운전은 실수가 아닌 악습관에서 비롯된 범죄 행위와 다르지 않다”며, “공직자 음주운전 완전 근절을 위한 철저한 사전 방지 교육, 캠페인은 물론, 적발 시 강력한 처벌을 통해 시민에게 신뢰받는 청렴한 공직사회 조성에 최선을 다해가겠다”고 전했다. {'word': '강인규', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '공직자', 'start_idx': 52, 'end_idx': 54, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 2423 덴지 천황의 총신인 후지와라노 가마타리의 차남으로, 후히토의 자손만이 덴지 천황에게 받은 후지와라 씨를 사용하고 태정관까지 오를 수 있었기 때문에 실질적인 후지와라 씨의 선조로 여겨지고 있다. {'word': '후지와라', 'start_idx': 87, 'end_idx': 90, 'type': 'ORG'} {'word': '차남', 'start_idx': 23, 'end_idx': 24, 'type': 'POH'}
# per:children      no_relation
# ----------
# ----------
# 2427 태영호 전 영국 주재 북한 공사는 11일 "남북한 통일 문제는 특정 정권이나 정파만의 전유물이 될 수 없고, 5000만 대한민국 국민, 2500만 북한 주민 모두의 것이어야 한다"며 4·15총선 출마의사를 밝혔다. {'word': '태영호', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '대한민국', 'start_idx': 67, 'end_idx': 70, 'type': 'LOC'}
# per:origin      per:place_of_residence
# ----------
# ----------
# 2449 결국 보잉 본사에서는 2019년 12월 16일 부로 보잉 737 MAX의 생산을 일시중단한다고 발표했으며, CEO인 데니스 뮐렌버그는 며칠 후 전격 해임됐다. {'word': '보잉', 'start_idx': 3, 'end_idx': 4, 'type': 'ORG'} {'word': 'CEO', 'start_idx': 60, 'end_idx': 62, 'type': 'POH'}
# no_relation      org:top_members/employees
# ----------
# ----------
# 2465 그 후 27살의 여주인공 캐시가 헤일샴이라는 기숙학교에서 보낸 어린시절, 학교를 떠난 후와 성인이 되고 나서의 이야기를 마치 추억을 더듬듯이 말하는 내레이션으로 그 장을 연다. {'word': '캐시', 'start_idx': 14, 'end_idx': 15, 'type': 'PER'} {'word': '주인공', 'start_idx': 10, 'end_idx': 12, 'type': 'POH'}
# per:alternate_names      per:title
# ----------
# ----------
# 2503 핀란드 국적의 IOC위원은 2명이 있다. {'word': 'IOC', 'start_idx': 8, 'end_idx': 10, 'type': 'ORG'} {'word': '위원', 'start_idx': 11, 'end_idx': 12, 'type': 'POH'}
# no_relation      org:top_members/employees
# ----------
# ----------
# 2512 외질은 대니 웰벡이 추가 시간에 머리로 넣은 골을 프리킥으로 도와 17번째 프리미어리그 도움을 기록했고, 아스널은 선두 레스터 시티와의 2월 14일 경기에서 2-1로 역전승을 거두었다. {'word': '대니 웰벡', 'start_idx': 4, 'end_idx': 8, 'type': 'PER'} {'word': '아스널', 'start_idx': 59, 'end_idx': 61, 'type': 'ORG'}
# per:employee_of      no_relation
# ----------
# ----------
# 2521 한편 베네치아는 지중해에서 최대의 경쟁 상대인 제노바 공화국과 전쟁에 돌입했다. {'word': '베네치아', 'start_idx': 3, 'end_idx': 6, 'type': 'ORG'} {'word': '지중해', 'start_idx': 9, 'end_idx': 11, 'type': 'LOC'}
# no_relation      org:member_of
# ----------
# ----------
# 2557 덕종(德宗) 2년에는 다시 대광(大匡) · 내사령(內史令)이 추증되었다. {'word': '德宗', 'start_idx': 3, 'end_idx': 4, 'type': 'PER'} {'word': '덕종', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'}
# per:alternate_names      org:alternate_names
# ----------
# ----------
# 2559 제17 보병 연대는 일오누아와 샹베리 요새를 공략 한 후 몬트리올 교외에 있던 다른 2개 사단과 합류했다. {'word': '보병 연대', 'start_idx': 4, 'end_idx': 8, 'type': 'ORG'} {'word': '제17', 'start_idx': 0, 'end_idx': 2, 'type': 'NOH'}
# no_relation      org:number_of_employees/members
# ----------
# ----------
# 2618 S-400은 3종류의 미사일을 창작하고 있으며, 터키는 나토 회원국으로서는 최초 구매국이 되었다. {'word': '나토', 'start_idx': 31, 'end_idx': 32, 'type': 'ORG'} {'word': '터키', 'start_idx': 27, 'end_idx': 28, 'type': 'LOC'}
# org:members      no_relation
# ----------
# ----------
# 2644 나주시(시장 강인규)가 전라남도가 주관하는 '2019 문화가 있는 날' 공모사업에 선정돼, 관내 초등학생들을 위한 문화공연 깜짝 선물보따리를 준비했다. {'word': '전라남도', 'start_idx': 13, 'end_idx': 16, 'type': 'ORG'} {'word': '시장', 'start_idx': 4, 'end_idx': 5, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 2657 평가원에 따르면 올 수능 응시원서 접수기간은 오는 22일부터 9월 6일까지 16일간이다. {'word': '평가원', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '수능', 'start_idx': 11, 'end_idx': 12, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 2753 장병완 의원(광주 동·남구갑)은 17일 광주시, 전국아파트입주자대표회의연합회 광주시지부(서상기 지부장)와 대한주택관리사협회 광주시회(이상운 회장) 등과 함께 ‘광주시 공동주택관리규약 준칙’의 현실적인 개정을 이끌어냈다고 밝혔다. {'word': '서상기', 'start_idx': 49, 'end_idx': 51, 'type': 'PER'} {'word': '장병완', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 2834 정호윤 연구원은 “엔씨소프트는 이번 사태로 인한 실적 악화가 아직까지는 나타나고 있지 않으며 1분기는 ‘리니지2M’과 ‘리니지M’의 흥행이 견조하게 이어질 전망”이라며 “1분기 매출액은 전년 동기대비 91.1% 늘어난 6857억원, 영업이익은 272.1% 증가한 2958억원의 호실적을 기록할 것”이라고 전망했다. {'word': '엔씨소프트', 'start_idx': 10, 'end_idx': 14, 'type': 'ORG'} {'word': '정호윤', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 2858 이춘희 세종시장이 17일 " KTX세종역 설치는 꼭 필요하다고 생각해 추진하겠다"고 말했다. {'word': '이춘희', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '세종', 'start_idx': 4, 'end_idx': 5, 'type': 'LOC'}
# per:employee_of      per:place_of_residence
# ----------
# ----------
# 2878 제목은 원제에서 "Mama"를 제외한 〈That's All Right〉로, 엘비스 프레슬리, 스코티와 빌로 공연자가 기록되어 있다. {'word': '엘비스 프레슬리', 'start_idx': 42, 'end_idx': 49, 'type': 'PER'} {'word': "That's All Right", 'start_idx': 22, 'end_idx': 37, 'type': 'POH'}
# no_relation      per:product
# ----------
# ----------
# 2886 한편 청와대 국민청원에선 조 후보자를 둘러싼 의견이 극단으로 치닫는 양상을 보이고 있다. {'word': '청와대', 'start_idx': 3, 'end_idx': 5, 'type': 'ORG'} {'word': '국민청원', 'start_idx': 7, 'end_idx': 10, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 2910 '척탄병들'에는 리햐르트 바그너도 곡을 붙였는데 바그너는 1840년과 1841년을 파리에 거주했었고 그는 궁핍한 경제적 여건 속의 이 파리 시절에 하이네와 프란츠 리스트를 알게 됐다. {'word': '바그너', 'start_idx': 27, 'end_idx': 29, 'type': 'PER'} {'word': '파리', 'start_idx': 75, 'end_idx': 76, 'type': 'LOC'}
# no_relation      per:place_of_residence
# ----------
# ----------
# 2922 헝가리의 왕이 된 마티아스는 오스트리아의 주민들에게 종교적 자유를 주었다. {'word': '마티아스', 'start_idx': 10, 'end_idx': 13, 'type': 'PER'} {'word': '오스트리아', 'start_idx': 16, 'end_idx': 20, 'type': 'LOC'}
# no_relation      per:origin
# ----------
# ----------
# 2924 미샤 2020 봄 컬렉션은 건축 아카이브로부터의 영감을 받아 오랜 시간 쌓아온 미샤의 테일러링 아카이브를 담아 디자인됐다. {'word': '미샤', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'} {'word': '2020 봄', 'start_idx': 3, 'end_idx': 8, 'type': 'DAT'}
# org:product      no_relation
# ----------
# ----------
# 2961 한때 그의 다섯째 아들 도디 알파예드는 이전 찰스 왕세자의 부인이던 다이애나 비의 연인이었으나 1997년 프랑스 파리에서 함께 교통사고로 숨졌다. {'word': '도디 알파예드', 'start_idx': 13, 'end_idx': 19, 'type': 'PER'} {'word': '프랑스', 'start_idx': 59, 'end_idx': 61, 'type': 'LOC'}
# no_relation      per:place_of_death
# ----------
# ----------
# 2985 국자감에는 공자를 위시한 유교 성현들을 제사 지내기 위한 장소인 문묘와 학생들에게 강의를 하기 위한 학당이 별도로 있었다는 것이다. {'word': '공자', 'start_idx': 6, 'end_idx': 7, 'type': 'PER'} {'word': '유교', 'start_idx': 14, 'end_idx': 15, 'type': 'POH'}
# org:political/religious_affiliation      no_relation
# ----------
# ----------
# 2999 그러나 아카네와 란마가 약혼자 관계라는 사실을 알고 나서는 더욱 더 란마를 이길려고 갖은 노력을 다한다. {'word': '아카네', 'start_idx': 4, 'end_idx': 6, 'type': 'PER'} {'word': '란마', 'start_idx': 9, 'end_idx': 10, 'type': 'PER'}
# no_relation      per:spouse
# ----------
# ----------
# 3022 북쪽에는 최전선 배치 부대인 국군 제1사단이 있었다. {'word': '국군', 'start_idx': 16, 'end_idx': 17, 'type': 'ORG'} {'word': '북쪽', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# org:place_of_headquarters      no_relation
# ----------
# ----------
# 3030 오늘날 러시아의 프스코프 지역에서 태어났으며, 903년경에 프스코프에서 키예프 루스의 2대 대공인 이고르 류리코비치와 결혼했다. {'word': '이고르 류리코비치', 'start_idx': 55, 'end_idx': 63, 'type': 'PER'} {'word': '프스코프', 'start_idx': 9, 'end_idx': 12, 'type': 'LOC'}
# no_relation      per:place_of_residence
# ----------
# ----------
# 3035 텔레그램 'n번방' 운영자 갓갓이 '박사방'에 들어왔다. {'word': '갓갓', 'start_idx': 15, 'end_idx': 16, 'type': 'PER'} {'word': 'n번방', 'start_idx': 6, 'end_idx': 8, 'type': 'POH'}
# per:product      no_relation
# ----------
# ----------
# 3084 이 군사제도는 장군이었던 8주국・12대장군은 서위, 그리고 이후의 북주(北周) 왕조에서도 유력자로써 가계를 유지하였고, 수(隋) 왕조의 양씨(楊氏)는 대장군, 당 왕조의 이씨(李氏)는 주국이라는 가계를 가지고 있었다. {'word': '이씨', 'start_idx': 95, 'end_idx': 96, 'type': 'ORG'} {'word': '당', 'start_idx': 89, 'end_idx': 89, 'type': 'DAT'}
# per:origin      no_relation
# ----------
# ----------
# 3101 2019년 1월 3일 대전과 계약이 만료된 김찬희가 부천 FC로 이적하였으며, 고명석은 수원 삼성으로 이적하였다. {'word': '김찬희', 'start_idx': 24, 'end_idx': 26, 'type': 'PER'} {'word': '대전', 'start_idx': 12, 'end_idx': 13, 'type': 'ORG'}
# per:employee_of      no_relation
# ----------
# ----------
# 3164 1792년 8월 10일 , 프랑스 혁명 정부는 국왕 루이 16세 체포권을 정지시켰다. {'word': '정부', 'start_idx': 22, 'end_idx': 23, 'type': 'ORG'} {'word': '프랑스 혁명', 'start_idx': 15, 'end_idx': 20, 'type': 'POH'}
# org:member_of      no_relation
# ----------
# ----------
# 3186 부산청 관계자는 “선거를 공정하고 깨끗하게 치르기 위해서는 경찰의 노력뿐만 아니라 국민의 적극적인 신고와 제보가 중요하다"고 강조하며, "선거 관련 불법행위를 알게 된 경우 112 또는 가까운 경찰관서에 적극적으로 신고해달라"고 당부했다. {'word': '부산청', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '경찰', 'start_idx': 33, 'end_idx': 34, 'type': 'ORG'}
# org:member_of      org:top_members/employees
# ----------
# ----------
# 3202 이날 open-day에는 김학실, 김익주 광주광역시의회 의원을 비롯하여 배홍석 광산구의회 의장, 김은단 광산구의회 부의장, 김재호, 강장훈, 이영훈, 유영종 구의원 등 지역 정치권 인사들은 물론 각계각층의 주요 인사들이 대거 참석했다. {'word': '김학실', 'start_idx': 14, 'end_idx': 16, 'type': 'PER'} {'word': '김익주', 'start_idx': 19, 'end_idx': 21, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 3225 광주대 대학일자리센터는 재학생들의 취업역량 향상을 위해 19개 학과 650명의 자격증 취득을 목표로, 오는 12월까지 맞춤 자격증반 프로그램을 운영할 방침이다. {'word': '광주대 대학일자리센터', 'start_idx': 0, 'end_idx': 10, 'type': 'ORG'} {'word': '재학생', 'start_idx': 13, 'end_idx': 15, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 3301 이명박 대통령이 발표한 '세종시 수정안'을 둘러싸고 한나라당의 친이계와 친박계가 충돌했다. {'word': '이명박', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '세종시', 'start_idx': 14, 'end_idx': 16, 'type': 'LOC'}
# no_relation      per:product
# ----------
# ----------
# 3317 ‘다산안전대상’은 전라남도가 도입한 안전 평가로 다산 정약용 선생이 목민심서에서 강조한 재난 예방·대비·대응·복구 등 재난관리에 대한 애민사상을 도내 각 기관·단체가 적극적으로 실천하여 ‘안전전남’을 실현하기 위해 만들어졌다. {'word': '다산 정약용', 'start_idx': 27, 'end_idx': 32, 'type': 'PER'} {'word': '선생', 'start_idx': 34, 'end_idx': 35, 'type': 'POH'}
# per:alternate_names      per:title
# ----------
# ----------
# 3321 순천시관계자는 “발효식품산업지원센터는 순천지역 뿐 아니라 남해안권역에서 생산되는 농산물을 활용한 발효식품의 개발과 시제품 제조, 기능성분석, 마케팅 지원 뿐 아니라 영세 농가들의 창업지원을 통해 지역의 발효식품산업 발전에 크게 도움이 될 것이다”며“건립을 위한 준비 단계부터 내실 있게 추진해 지역경제 활성화가 농촌에서부터 시작되는 활력제가 되도록 하겠다”고 밝혔다. {'word': '순천시', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '발효식품', 'start_idx': 54, 'end_idx': 57, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 3328 민주당 홍익표 수석대변인은 논평에서 "공수처 법안의 국회 통과는 검찰개혁과 공정하고 정의로운 국가를 향한 역사적 진전의 순간으로 기록될 것"이라면서 "검찰 개혁은 이제부터 시작"이라고 말했다. {'word': '국회', 'start_idx': 29, 'end_idx': 30, 'type': 'ORG'} {'word': '홍익표', 'start_idx': 4, 'end_idx': 6, 'type': 'PER'}
# org:top_members/employees      no_relation
# ----------
# ----------
# ...
# ----------
# 6732 혜자는 삼론학(三論學)을 위시하여 《법화경》·《유마경(維摩經)》·《승만경》과 같은 난숙한 발달을 보인 대승경전을 가르쳤는데, 후일 성덕태자가 불교정신을 뒷받침으로 한 정치를 베풀 때 이러한 불교정신이 통치 이념으로 중요한 역할을 하였을 뿐 아니라 일본 문화 발전에도 큰 전환점을 가져다 주었다. {'word': '불교', 'start_idx': 79, 'end_idx': 80, 'type': 'ORG'} {'word': '법화경', 'start_idx': 20, 'end_idx': 22, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 6746 인천에서 출생하였으며 지난날 한때 경기도 시흥에서 잠시 유아기를 보낸 적이 있는 그녀는 훗날 2012년부터 2014년까지 일본에서 퓨리티의 멤버로 활동하였으나, 대한민국에서는 데뷔도 못한 채, 2년 만에 팀이 해체되었다. {'word': '퓨리티', 'start_idx': 73, 'end_idx': 75, 'type': 'PER'} {'word': '2014년', 'start_idx': 60, 'end_idx': 64, 'type': 'DAT'}
# no_relation      org:dissolved
# ----------
# ----------
# 6774 김유화 예비후보는 MBC 아나운서 출신으로 복지TV 전남방송 사장, 5․6대 여수시 의원, 더불어민주당 전국여성지방의원협의회 상임대표, 전국 사회적경제 지방의원협의회 공동대표, 문재인후보 전남국민참여운동본부 공동위원장, 노무현재단 전남지역위원회 공동대표 등을 지냈으며, 현 대통령직속 국가균형발전위원회 국민소통특별위원으로 활동하고 있다. {'word': '전남국민참여운동본부', 'start_idx': 105, 'end_idx': 114, 'type': 'ORG'} {'word': '공동위원장', 'start_idx': 116, 'end_idx': 120, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 6780 기독교인들은 예수가 강생한 하느님 즉, 하느님의 현현(Epiphany)이라고 믿는다. {'word': '예수', 'start_idx': 7, 'end_idx': 8, 'type': 'PER'} {'word': '하느님', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'}
# no_relation      per:alternate_names
# ----------
# ----------
# 6787 2010년 6·2 지방선거에서 한명숙 서울시장후보 공동선거대책위원장을 맡았고, 민주통합당 민주정책연구원 이사, 한국미래발전연구원 이사, 사람사는 세상 노무현재단 운영위원, 국민시대 공동대표 등을 역임했다. {'word': '한명숙', 'start_idx': 17, 'end_idx': 19, 'type': 'PER'} {'word': '서울', 'start_idx': 21, 'end_idx': 22, 'type': 'LOC'}
# no_relation      per:place_of_residence
# ----------
# ----------
# 6800 명현관 해남군수는 “군민을 위해 적극적인 행정을 펼치는 공무원은 철저히 우대하고, 소극행정을 하는 공무원에게는 엄중조치를 함으로써, 군정에 대한 신뢰도를 높이고 군민이 체감할 수 있는 한 단계 높은 행정서비스를 제공하겠다”고 말했다. {'word': '명현관', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '공무원', 'start_idx': 31, 'end_idx': 33, 'type': 'POH'}
# no_relation      per:title
# ----------
# ----------
# 6804 1964년 5월 3일 BBC 인터뷰에서, 앨런 덜레스 CIA 국장은 "재임 중 CIA의 해외 활동으로서 가장 성공을 거둔 것은 5·16 군사 정변이었다"고 말했다. {'word': 'CIA', 'start_idx': 30, 'end_idx': 32, 'type': 'ORG'} {'word': '국장', 'start_idx': 34, 'end_idx': 35, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 6805 조선일보사의 취체역 사장을 지냈으며 1953년 코리아타임스를 인수했다. {'word': '조선일보사', 'start_idx': 0, 'end_idx': 4, 'type': 'ORG'} {'word': '사장', 'start_idx': 11, 'end_idx': 12, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 6880 2015년 6월 30일, 앞서 밀란과의 계약을 5월에 해지했던 호비뉴는 계약 만료로 "물고기 군단"을 떠났다. {'word': '호비뉴', 'start_idx': 35, 'end_idx': 37, 'type': 'PER'} {'word': '밀란', 'start_idx': 17, 'end_idx': 18, 'type': 'ORG'}
# per:employee_of      no_relation
# ----------
# ----------
# 6893 지난 2일 오전 일본은 아베 신조 총리 주재로 열린 각의(국무회의)에서 한국을 수출우대국가 명단, 이른바 '화이트 리스트' 대상 국가에서 제외하는 수출무역관리령 개정안을 의결했다. {'word': '국무회의', 'start_idx': 32, 'end_idx': 35, 'type': 'ORG'} {'word': '일본', 'start_idx': 9, 'end_idx': 10, 'type': 'LOC'}
# org:place_of_headquarters      org:member_of
# ----------
# ----------
# 6895 전남 함평군(군수 권한대행 나윤수)이 제4회 전라남도 마을숲 콘테스트에서 대상을 수상했다. {'word': '나윤수', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'} {'word': '전남', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# per:employee_of      per:place_of_residence
# ----------
# ----------
# 6913 태풍 나비(태풍 번호: 0514, JTWC 지정 번호: 14W, 국제명: NABI, 필리핀 기상청 지정 이름: Jolina)는 2005년에 발생한 제14호 태풍으로 2005년 8월 29일에 발생하여 2005년 9월 8일 일본 삿포로 동북동쪽 약 710 km 부근 해상에서 온대저기압으로 변질되어 소멸하였다. {'word': '필리핀 기상청', 'start_idx': 47, 'end_idx': 53, 'type': 'ORG'} {'word': 'JTWC', 'start_idx': 19, 'end_idx': 22, 'type': 'ORG'}
# no_relation      org:alternate_names
# ----------
# ----------
# 6932 LG유플러스는 서울 금천에 있는 고객센터 근무자들 중 일부를 서울 방배, 수원, 과천 지역으로 분산 배치하는 것을 검토하고 있다. {'word': 'LG유플러스', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '근무자', 'start_idx': 23, 'end_idx': 25, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 6958 황교안 미래통합당 대표가 한선교 미래한국당의 비례 대표 후보 '공천 쿠데타'에 해법을 찾지 못한 채 속앓이를 계속하고 있다. {'word': '한선교', 'start_idx': 14, 'end_idx': 16, 'type': 'PER'} {'word': '미래통합당', 'start_idx': 4, 'end_idx': 8, 'type': 'ORG'}
# no_relation      per:employee_of
# ----------
# ----------
# 6982 이적 일 년째에는 그런대로 성적을 냈지만, 이 년째에는 세비야의 감독인 후안 데 라모스 감독이 팀을 떠남과 동시에 출장 기회가 격감했고, 그 때문에 2008년 2월, 디나모 모스크바로 이적하게 되었다. {'word': '세비야', 'start_idx': 31, 'end_idx': 33, 'type': 'ORG'} {'word': '감독', 'start_idx': 49, 'end_idx': 50, 'type': 'POH'}
# no_relation      org:top_members/employees
# ----------
# ----------
# 7015 마지막 발언 기회를 얻은 것은 스캇 브로셔스 미국 감독. 브로셔스 감독은 "다른팀 감독들과 마찬가지로 난 굉장히 흥분해 있다. 계속해서 좋은 플레이를 할 수 있도록 노력하겠다"며 "한국전에 전력을 다할 것"이라고 예고했다. {'word': '브로셔스', 'start_idx': 32, 'end_idx': 35, 'type': 'PER'} {'word': '미국', 'start_idx': 25, 'end_idx': 26, 'type': 'LOC'}
# per:employee_of      per:origin
# ----------
# ----------
# 7017 지난달 31일 방송된 MBC 예능 프로그램 '나 혼자 산다'에서 한혜진 씨는 무지개 회원들과 함께 영상을 보며 이야기를 나눴다. {'word': '한혜진', 'start_idx': 36, 'end_idx': 38, 'type': 'PER'} {'word': '무지개', 'start_idx': 43, 'end_idx': 45, 'type': 'LOC'}
# per:employee_of      no_relation
# ----------
# ----------
# 7030 1988년 11월 전태일의 분신 자살을 기념하기 위한 '전태일 정신 계승 전국 노동자 대회'가 서울에서 개최되어 매년 11월 전국 노동자대회가 열리고 있다. {'word': '전태일', 'start_idx': 10, 'end_idx': 12, 'type': 'PER'} {'word': '서울', 'start_idx': 53, 'end_idx': 54, 'type': 'LOC'}
# no_relation      per:place_of_death
# ----------
# ----------
# 7079 박영만 소장 자료인 묘법연화경의 형태사항을 살펴보면, 표지는 능화문(菱花紋)이 없는 것으로 개장되어 있다. {'word': '박영만', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '묘법연화경', 'start_idx': 11, 'end_idx': 15, 'type': 'POH'}
# per:product      org:product
# ----------
# ----------
# 7083 산업계, 학계, 공공기관 전문가들이 수열에너지 조기 안착과 활성화를 위해 ‘수열에너지 사업 지원단(이하 수열사업 지원단)’ 첫 회의를 25일 가졌다. {'word': '수열사업 지원단', 'start_idx': 58, 'end_idx': 65, 'type': 'ORG'} {'word': '전문가', 'start_idx': 14, 'end_idx': 16, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 7095 앤유는 스포츠유나이티드를 118억 원에 양수하기로 했다고 알려졌다. {'word': '앤유', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'} {'word': '스포츠유나이티드', 'start_idx': 4, 'end_idx': 11, 'type': 'ORG'}
# org:members      no_relation
# ----------
# ----------
# 7100 유식유가행파와 법상종의 교학에 따르면, 현행(現行)이란 아뢰야식에 함장된 법의 종자가 인연이 갖추어짐에 따라 의 법으로 나타나는 것을 말한다. {'word': '법상종', 'start_idx': 8, 'end_idx': 10, 'type': 'ORG'} {'word': '교학', 'start_idx': 13, 'end_idx': 14, 'type': 'POH'}
# org:product      org:political/religious_affiliation
# ----------
# ----------
# 7141 대학 4학년 때인 2015년에는 대한민국 광주광역시에서 개최된 하계 유니버시아드 야구 일본 대표팀 선수로 발탁됐다. {'word': '일본 대표팀', 'start_idx': 48, 'end_idx': 53, 'type': 'ORG'} {'word': '대한민국', 'start_idx': 18, 'end_idx': 21, 'type': 'LOC'}
# org:place_of_headquarters      no_relation
# ----------
# ----------
# 7143 5년 만에 한국시리즈 무대를 밟게 된 키움 히어로즈가 엔트리는 물론 '벌떼야구'로 불리는 불펜 운용도 그대로 이어간다. {'word': '키움 히어로즈', 'start_idx': 21, 'end_idx': 27, 'type': 'ORG'} {'word': '한국시리즈', 'start_idx': 6, 'end_idx': 10, 'type': 'POH'}
# no_relation      org:member_of
# ----------
# ----------
# 7178 영광군은 선발된 소수 학생을 대상으로 실시하던 해외연수 사업을 2016년부터 중학교 3학년 전체로 확대하여 학생들의 견문을 넓히고 학우들과의 특별한 추억으로 한 층 성장할 수 있는 계기를 제공해 왔다. {'word': '영광군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '해외연수 사업', 'start_idx': 26, 'end_idx': 32, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 7188 또한 “향후 5년간 정책금융에서 100조 원, 민간금융에서 70조 원을 한국판 뉴딜 프로젝트와 기업에 투입할 것”이라며 “정부의 마중물 역할과 정책금융의 적극적 기여, 여기에 민간의 협조까지 더하게 됨으로써 ‘한국판 뉴딜’을 힘있게 추진할 물적 기반이 마련된 것”이라고 말했다. {'word': '정부', 'start_idx': 68, 'end_idx': 69, 'type': 'ORG'} {'word': '한국판 뉴딜', 'start_idx': 117, 'end_idx': 122, 'type': 'POH'}
# no_relation      org:product
# ----------
# ----------
# 7198 A씨는 그러면서 차라리 자신이 고유정과 해외여행을 가서 죽었더라면 아들이 죽지 않지 않았을 것이라고 했다. {'word': '고유정', 'start_idx': 17, 'end_idx': 19, 'type': 'PER'} {'word': 'A', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'}
# per:spouse      no_relation
# ----------
# ----------
# 7225 순천시는 다중이용시설 대형화재를 가정해 순천소방서, 순천경찰서 등 13개 기관․단체등 시민 300여 명이 참여했으며 특히 민간기업과 단체, 시민체험단이 함께하는 시민 참여형 훈련으로 드론과 인명구조견을 투입해 현장 합동 수색을 전개했다. {'word': '순천소방서', 'start_idx': 22, 'end_idx': 26, 'type': 'ORG'} {'word': '순천시', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'}
# org:place_of_headquarters      org:member_of
# ----------
# ----------
# 7270 공연에 관한 브라이언 메이와 로저 테일러의 인터뷰(28분 분량), 투어 관계자들과의 인터뷰(19분 분량), 공연에 관한 다큐멘터리(30분 분량), 지금은 철거된 웸블리 스타디움을 기념하는 영상(5분 분량)으로 구성되어 있다. {'word': '로저 테일러', 'start_idx': 16, 'end_idx': 21, 'type': 'PER'} {'word': '브라이언 메이', 'start_idx': 7, 'end_idx': 13, 'type': 'PER'}
# per:colleagues      no_relation
# ----------
# ----------
# 7272 욕실 곰팡이가 심해지자 안방에서 함께 잠을 자던 A씨 부부와 6살, 7살 아이는 졸지에 각방 생활을 해야 하는 '이산가족'이 됐다. {'word': 'A', 'start_idx': 27, 'end_idx': 27, 'type': 'PER'} {'word': '이산가족', 'start_idx': 63, 'end_idx': 66, 'type': 'POH'}
# per:alternate_names      no_relation
# ----------
# ----------
# 7308 17세기에서 19세기동안 반불감정은 주로 유럽대륙에서 경쟁관계에 있던 영국과의 사이에서 일어났으며, 현재는 외교적 마찰이 빈번한 미국에서 현저하다. {'word': '영국', 'start_idx': 39, 'end_idx': 40, 'type': 'ORG'} {'word': '유럽', 'start_idx': 23, 'end_idx': 24, 'type': 'LOC'}
# org:place_of_headquarters      org:member_of
# ----------
# ----------
# 7325 이 의원은 이와 관련, "충주시민들이 겪고 있는 어려움을 해소하고 삶의 질을 높이는 시설을 만들기 위한 사업비 확보에 신경을 썼다"고 밝혔다. {'word': '이', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '충주', 'start_idx': 14, 'end_idx': 15, 'type': 'LOC'}
# no_relation      per:place_of_residence
# ----------
# ----------
# 7326 이날 진정무 청장은 ‘경남 치안의 현황과 경남 경찰의 역할’을 주제로 특강을 진행했으며, 특강에는 '21세기형 새로운 리더십' 교양강좌 수강생 200여 명이 참석해 성황을 이뤘다. {'word': '진정무', 'start_idx': 3, 'end_idx': 5, 'type': 'PER'} {'word': '경찰', 'start_idx': 26, 'end_idx': 27, 'type': 'ORG'}
# no_relation      per:title
# ----------
# ----------
# 7327 그룹 ITZY(있지) 예지가 새 앨범 '있지 미'(IT'z ME)의 개인 티저를 공개했다. {'word': '예지', 'start_idx': 12, 'end_idx': 13, 'type': 'PER'} {'word': '있지', 'start_idx': 8, 'end_idx': 9, 'type': 'PER'}
# per:alternate_names      per:employee_of
# ----------
# ----------
# 7335 특히 차남 지치부노미야의 비였던 세쓰코(勢津子) 비를 마음에 들어하여 서로 친교가 깊었고, 매년 3월 3일 히나마쓰리마다 세쓰코 비가 시집올 때 가져온 히나 인형을 저택에 장식해놓고 그것을 데이메이 황후에게 보이곤 했다고 한다. {'word': '데이메이', 'start_idx': 106, 'end_idx': 109, 'type': 'PER'} {'word': '세쓰코', 'start_idx': 68, 'end_idx': 70, 'type': 'PER'}
# no_relation      per:spouse
# ----------
# ----------
# 7342 LG유플러스가 오는 7월 일본 올림픽을 관람하는 5G 고객들을 위해 국내 통신사 중 최초로 일본 5G 로밍 테스트를 성공적으로 마쳤다고 10일 밝혔다. {'word': 'LG유플러스', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '고객', 'start_idx': 30, 'end_idx': 31, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 7367 바르바로스 하이레딘 파샤(터키어: Barbaros Hayreddin Paşa, ~ 1546년 7월 4일)는 오스만 출신의 해적(Cossair)으로 훗날 오스만 해군의 제독이 되었다. {'word': '오스만 해군', 'start_idx': 85, 'end_idx': 90, 'type': 'ORG'} {'word': '오스만', 'start_idx': 60, 'end_idx': 62, 'type': 'LOC'}
# org:place_of_headquarters      no_relation
# ----------
# ----------
# 7390 이러한 하느님의 모습은 루카복음 전체에 등장하는 예수님의 말씀으로 확대되고 있으며, 이는 주로 당시의 삶의 자리에서는 주류세력들과 소외된 자에게 관심을 가지고 있는 루카의 신학적 관점을 담고 있음을 대변하고 있는 것이다. {'word': '예수', 'start_idx': 27, 'end_idx': 28, 'type': 'PER'} {'word': '하느님', 'start_idx': 4, 'end_idx': 6, 'type': 'PER'}
# no_relation      per:alternate_names
# ----------
# ----------
# 7391 스푸트니크의 존재는 소련이 미국 본토까지 닿을 수 있는 강력한 미사일을 소유하고 있을지도 모른다는 증거이기도 했다. {'word': '소련', 'start_idx': 11, 'end_idx': 12, 'type': 'ORG'} {'word': '스푸트니크', 'start_idx': 0, 'end_idx': 4, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 7413 그의 문집은 외손 국포 강박이 정리했고, 강박의 손자 강세륜과 강세백이 재정리하여 간행하였고, 이서우의 직계 후손들에게 전해주었다. {'word': '국포 강박', 'start_idx': 10, 'end_idx': 14, 'type': 'PER'} {'word': '외손', 'start_idx': 7, 'end_idx': 8, 'type': 'POH'}
# per:title      per:other_family
# ----------
# ----------
# 7418 이날 대책회의에는 청와대 노영민 비서실장, 김상조 정책실장, 정의용 국가안보실장 등 3실장과 수석 보좌관 등이 참석했다. {'word': '청와대', 'start_idx': 10, 'end_idx': 12, 'type': 'ORG'} {'word': '국가안보실장', 'start_idx': 38, 'end_idx': 43, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 7468 무쓰 아이즈 번 제9대 번주이며 교토 수호직을 역임했다. {'word': '무쓰 아이즈 번', 'start_idx': 0, 'end_idx': 7, 'type': 'ORG'} {'word': '번주', 'start_idx': 13, 'end_idx': 14, 'type': 'POH'}
# org:top_members/employees      per:title
# ----------
# ----------
# 7490 김 연구원은 “PRASAC의 자산증가율은 2017년 40%, 2018년 36%이며, 수익성도 매우 높아 30% 정도의 자기자본이익률(ROE)과 3% 후반대의 총자산순이익률(ROA)을 보이고 있다”라고 판단했다. {'word': 'PRASAC', 'start_idx': 8, 'end_idx': 13, 'type': 'ORG'} {'word': '김', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 7574 숙종의 초비 인경왕후가 죽은 후 1년 후에 숙종의 모후인 명성왕후 김씨와 외가 친척인 송시열의 추천으로 왕비로 뽑힌다. {'word': '명성왕후', 'start_idx': 32, 'end_idx': 35, 'type': 'PER'} {'word': '인경왕후', 'start_idx': 7, 'end_idx': 10, 'type': 'PER'}
# per:other_family      no_relation
# ----------
# ----------
# 7575 그러나 민정당 계열 대부분은 대표 경험이 없는 하토야마보다는, 민정당의 마지막 총재였던 마치다 다다하루가 대표로 어울린다는 의견이 우세해, 결국 민정당 계열은 마치다를 총재로 옹립해 일본진보당을 결성하면서 구상은 좌절되었다. {'word': '하토야마', 'start_idx': 26, 'end_idx': 29, 'type': 'PER'} {'word': '대표', 'start_idx': 59, 'end_idx': 60, 'type': 'POH'}
# per:title      no_relation
# ----------
# ----------
# 7577 데 리트와 호날두는 각각 네덜란드, 포르투갈 국가대표 선수로 출전했다. {'word': '호날두', 'start_idx': 6, 'end_idx': 8, 'type': 'PER'} {'word': '데 리트', 'start_idx': 0, 'end_idx': 3, 'type': 'PER'}
# no_relation      per:colleagues
# ----------
# ----------
# 7649 그룹 크레용팝 출신 BJ 엘린(김민영)이 그의 열혈팬에 한 '로맨스 스캠'을 모두 인정하고 사과한 이후 근황을 전했다. {'word': 'BJ 엘린', 'start_idx': 11, 'end_idx': 15, 'type': 'PER'} {'word': '크레용팝', 'start_idx': 3, 'end_idx': 6, 'type': 'ORG'}
# per:origin      per:employee_of
# ----------
# ----------
# 7658 증조부 엄성의 두 부인 중 누가 할아버지 엄석구의 생모인지 여부는 불확실하다. {'word': '엄성', 'start_idx': 4, 'end_idx': 5, 'type': 'PER'} {'word': '증조부', 'start_idx': 0, 'end_idx': 2, 'type': 'POH'}
# per:alternate_names      per:parents
# ----------
# ----------
# 7663 인촌 김성수와 기업인 김연수의 친할아버지로 김성수 집안의 가계를 실질적으로 일으킨 사람이라 한다. {'word': '김성수', 'start_idx': 24, 'end_idx': 26, 'type': 'PER'} {'word': '김연수', 'start_idx': 12, 'end_idx': 14, 'type': 'PER'}
# per:other_family      per:siblings
# ----------
# ----------
# 7682 김 예비후보는“나주와 화순을 유기적으로 연계하고 한전, 에너지밸리, 에너지클러스트 등 연관된 산업생태계를 활용할 경우, 세계에너지엑스포 유치가 불가능한 일은 아니다”라면서“엑스포 유치와 함께 도시재생 프로젝트 등 다양한 사회적 인프라를 구축하는 작업이야말로 혁신적인 지역발전을 담보하는 변곡점”이라고 의미를 부여했다. {'word': '한전', 'start_idx': 27, 'end_idx': 28, 'type': 'ORG'} {'word': '나주', 'start_idx': 8, 'end_idx': 9, 'type': 'LOC'}
# no_relation      org:place_of_headquarters
# ----------
# ----------
# 7700 전라남도는 지난 2월 현장 서류평가와 전문가 심사 등을 통해 17개 시군 30개 운영마을·농가를 최종 선정했다. {'word': '전라남도', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': '17개', 'start_idx': 34, 'end_idx': 36, 'type': 'NOH'}
# no_relation      org:number_of_employees/members
# ----------
# ----------
# 7709 고레에다 히로카즈 감독이 신작의 주인공이자 프랑스의 전설적인 여배우 카트린 드뇌브와의 일화들을 통해 영화를 둘러싼 풍부한 이야깃거리를 제공했다. {'word': '고레에다 히로카즈', 'start_idx': 0, 'end_idx': 8, 'type': 'PER'} {'word': '카트린 드뇌브', 'start_idx': 38, 'end_idx': 44, 'type': 'POH'}
# no_relation      per:colleagues
# ----------
# ----------
# 7712 네이버는 주로 인공지능(AI) 기술을 활용한 부작용 최소화에 주력하고 있으며, 카카오는 문제가 되는 서비스를 잠정 폐지하고 플랫폼 전반을 전면 개편할 방침이다. {'word': '네이버', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': 'AI', 'start_idx': 13, 'end_idx': 14, 'type': 'POH'}
# org:product      no_relation
# ----------
# ----------
# 7721 박완주 의원은 “공공시설과 국유지를 정원으로 조성하여 천안시민께 녹색휴식 공간을 제공하는 사업에 선정 돼 기쁘다”며 “많은 시민이 이용하는 시설에 미세먼지 저감과 공기질 개선에 기여할 수 있는 생활밀착형 숲 조성사업이 확대되어 언제, 어디서나 정원에 접근할 수 있도록 더욱 노력하겠다” 말했다. {'word': '박완주', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '천안', 'start_idx': 30, 'end_idx': 31, 'type': 'LOC'}
# no_relation      per:place_of_residence
# ----------
# ----------
# 7727 송진우는 김구의 충칭 임정의 통치권 주장을 미군정에서 도저히 받아들이지 않을 것이라고 판단했던 것이다. {'word': '김구', 'start_idx': 5, 'end_idx': 6, 'type': 'PER'} {'word': '충칭', 'start_idx': 9, 'end_idx': 10, 'type': 'LOC'}
# per:employee_of      per:place_of_residence
# ----------
# ----------
# 7737 잉글랜드 성공회의 성인이기도 하며, 성공회에서는 8월 13일을 나이팅게일의 축일로 지키고 있다. {'word': '성공회', 'start_idx': 20, 'end_idx': 22, 'type': 'ORG'} {'word': '성인', 'start_idx': 10, 'end_idx': 11, 'type': 'POH'}
# org:top_members/employees      no_relation
# ----------
# ----------
# 7748 그러자 다윗은 [[요압]] 대신 요압의 어머니 [[스루야]]의 자매 [[나하스]]의 딸 [[아비가일]]과 혼인 관계인 [[이드라]]의 아들 [[아마사]]를 내세웠다. {'word': '나하스', 'start_idx': 40, 'end_idx': 42, 'type': 'PER'} {'word': '다윗', 'start_idx': 4, 'end_idx': 5, 'type': 'PER'}
# no_relation      per:siblings
# ----------

# %%
stratified2400.head(20)
# Out:
#     id                 pred_label  \
# 0    0                org:product
# 1    1        per:alternate_names
# 2    2                no_relation
# 3    3                no_relation
# 4    4                no_relation
# 5    5                no_relation
# 6    6            per:employee_of
# 7    7                 per:spouse
# 8    8                org:members
# 9    9  org:top_members/employees
# 10  10                no_relation
# 11  11              org:dissolved
# 12  12                no_relation
# 13  13                no_relation
# 14  14         per:place_of_death
# 15  15             per:colleagues
# 16  16        per:alternate_names
# 17  17                no_relation
# 18  18                no_relation
# 19  19                org:product
#
#                                                 probs  \
# 0   [0.019941575825214386, 0.0061255375854671005, ...
# 1   [0.020341246481984855, 0.006818882189691067, 0...
# 2   [0.8270676493644715, 0.005647766962647439, 0.0...
# 3   [0.8194640994071961, 0.005572580266743899, 0.0...
# 4   [0.8192532300949097, 0.020057712309062482, 0.0...
# 5   [0.5561467111110687, 0.014892110414803029, 0.0...
# 6   [0.004590904386714101, 0.005028023943305015, 0...
# 7   [0.004261318501085043, 0.005627437587827444, 0...
# 8   [0.06856937296688558, 0.004291673982515932, 0....
# 9   [0.017836375348269942, 0.8004513263702393, 0.0...
# 10  [0.8193185687065124, 0.019102205708622932, 0.0...
# 11  [0.005355551047250629, 0.0027337850537151103, ...
# 12  [0.7301719069480895, 0.007459127344191074, 0.0...
# 13  [0.8224461197853089, 0.006393218971788885, 0.0...
# 14  [0.34544071108102803, 0.004840943915769458, 0....
# 15  [0.14359748624265195, 0.0039948377758264545, 0...
# 16  [0.003891981625929475, 0.00495252013206482, 0....
# 17  [0.6562986336648464, 0.004511583875864745, 0.0...
# 18  [0.6973117768764496, 0.005231942422688007, 0.0...
# 19  [0.002912805369123817, 0.0046405385248363025, ...
#
#                                               softmax
# 0   [0.03251477 0.03206863 0.03321457 0.06783082 0...
# 1   [0.03273989 0.03230015 0.03228652 0.03238122 0...
# 2   [0.07268277 0.03196637 0.03198696 0.03199513 0...
# 3   [0.07215424 0.03197373 0.03201606 0.03200916 0...
# 4   [0.07213955 0.03244047 0.03194541 0.03198827 0...
# 5   [0.0558964  0.03253269 0.03277838 0.03228482 0...
# 6   [0.03191318 0.03192713 0.03193821 0.03194467 0...
# 7   [0.03188375 0.03192734 0.03190362 0.03190656 0...
# 8   [0.03407387 0.03195259 0.07095851 0.03197259 0...
# 9   [0.03239253 0.07084842 0.0322063  0.03208625 0...
# 10  [0.07214409 0.03240942 0.03198    0.03204348 0...
# 11  [0.0318452  0.03176181 0.03173324 0.03178996 0...
# 12  [0.06620496 0.03213811 0.03220249 0.03426682 0...
# 13  [0.07236119 0.0319962  0.03200227 0.03199319 0...
# 14  [0.04535973 0.03226635 0.03236722 0.03236173 0...
# 15  [0.03681832 0.03202103 0.03203445 0.0320461  0...
# 16  [0.03187621 0.03191003 0.03193104 0.03190617 0...
# 17  [0.06160895 0.03210527 0.03210857 0.03216255 0...
# 18  [0.06412538 0.03209693 0.03225721 0.03211799 0...
# 19  [0.03184103 0.03189609 0.03188065 0.07470145 0...

# %%
entity2_1600= pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_1600/final/submission_final_roberta_large_end.csv')

# %%
entity2_1600.head()
# Out:
#    id           pred_label                                              probs  \
# 0   0          org:product  [0.022050623409450056, 0.005498564522713423, 0...
# 1   1  per:alternate_names  [0.023388843052089214, 0.005454227607697249, 0...
# 2   2          no_relation  [0.8222221970558168, 0.0054425175301730635, 0....
# 3   3          no_relation  [0.632249766588211, 0.007157895714044571, 0.00...
# 4   4          no_relation  [0.602174985408783, 0.2230789192020893, 0.0082...
#
#                                              softmax
# 0  [0.03263743 0.03210166 0.03795215 0.06382626 0...
# 1  [0.03280855 0.03222538 0.03221842 0.03233109 0...
# 2  [0.07234563 0.03196608 0.03202682 0.0319951  0...
# 3  [0.06018959 0.0322142  0.03222701 0.03216753 0...
# 4  [0.05843229 0.03999573 0.03226461 0.03220862 0...

# %%
print(cnt)
print(cnt2)
print(cnt3)
# Out:
# 392
# 638
# 837

# %%
# cnt2 = 0
# for idx, (ks, strs) in enumerate(zip(kfold['pred_label'], entity2_1600['pred_label'])):
#     if ks != strs:
#         print('-'*10)
#         print(idx, test_csv['sentence'][idx],test_csv['subject_entity'][idx], test_csv['object_entity'][idx])
#         print(ks, ' '*4, strs)
#         print('-'*10)
#         cnt2+= 1
cnt3 = 0
for idx, (ks, strs, ent) in enumerate(zip(kfold['pred_label'], stratified2400['pred_label'], entity2_1600['pred_label'])):
    if not(ks == strs == ent):
        print('-'*10)
        print(idx, test_csv['sentence'][idx],test_csv['subject_entity'][idx], test_csv['object_entity'][idx])
        print(ks, ' '*4, strs, ' '*4, ent)
        print('-'*10)
        cnt3+= 1
# Out:
# ----------
# 17 무령왕의 왕위를 계승한 성왕(재위 523 ~ 554년)도 일본과의 우호관계를 이어갔다. {'word': '무령왕', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '554년', 'start_idx': 25, 'end_idx': 28, 'type': 'DAT'}
# no_relation      no_relation      per:date_of_death
# ----------
# ----------
# 36 엘사 분장을 하고 빅스 포스터를 보며 자신의 사진을 가리키는가 하면, 가슴 속에 숨겨 뒀던 당근을 꺼내 올라프에게 먹이는 듯한 제스처를 한다. {'word': '엘사', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'} {'word': '빅스', 'start_idx': 10, 'end_idx': 11, 'type': 'POH'}
# no_relation      no_relation      per:employee_of
# ----------
# ----------
# 59 초기에는 대부분의 경우 '탈퇴'라는 표현을 사용하였지만(결성 당시부터 나카자와 졸업까지의 모닝구무스메。의 역사가 게재되어 있는 ASAYAN 공식 사이트 등에서는 지금도 탈퇴라는 표현으로 통일되어 있다.) 2001년 이후에는 공식적으로 주로 졸업이라는 표현을 쓰게 되어('졸업 메모리얼' 굿즈 등), 과거 멤버에 대해서도 졸업이라는 표현으로 통일한 경우도 많다(콘서트 MC에서의 '졸업 멤버' 호칭 등). {'word': 'ASAYAN', 'start_idx': 71, 'end_idx': 76, 'type': 'ORG'} {'word': '나카자와', 'start_idx': 39, 'end_idx': 42, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 67 교사정치기본권찾기연대(공동대표 강신만, 곽노현)와 전교조전남지부(지부장 김기중), 한국교원노조 전남본부(본부장 박종출), 전남전문상담교사노동조합(위원장 김우영)은 오는 18일 오후 2시 나주빛가람호텔 대회의실에서 교원, 학부모, 시민 등 200여 명이 참가한 가운데 ‘민주시민교육 원칙 합의와 교원정치기본권 보장’ 전남교육공동체 원탁토론회를 공동 개최한다. {'word': '전교조전남지부', 'start_idx': 28, 'end_idx': 34, 'type': 'ORG'} {'word': '위원장', 'start_idx': 81, 'end_idx': 83, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 79 드와이트 라이먼 무디(Dwight Lyman Moody, 드와이트 라이먼 무디, 1837년 2월 5일 ~ 1899년12월 22일)은 미국의 침례교 평신도 설교자이다. {'word': '침례교', 'start_idx': 78, 'end_idx': 80, 'type': 'ORG'} {'word': '미국', 'start_idx': 74, 'end_idx': 75, 'type': 'LOC'}
# org:place_of_headquarters      per:religion      org:place_of_headquarters
# ----------
# ----------
# 80 이와 관련해 지난 23일 YTN라디오 '노영희의 출발 새아침'에 출연한 이수정 경기대 범죄심리학과 교수는 "실수로 n번방에 들어갔다고 하는 것은 믿기 어려운 변명으로 보인다"고 밝혔다. {'word': '경기대 범죄심리학과', 'start_idx': 44, 'end_idx': 53, 'type': 'ORG'} {'word': '교수', 'start_idx': 55, 'end_idx': 56, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      per:title
# ----------
# ----------
# 93 LG전자가 글로벌 자동차 업체 GM의 프리미엄 브랜드 ‘캐딜락’에 플라스틱 OLED(P-OLED) 기반 디지털 콕핏 시스템을 세계 최초로 공급한다고 6일 밝혔다. {'word': 'GM', 'start_idx': 17, 'end_idx': 18, 'type': 'ORG'} {'word': '캐딜락', 'start_idx': 31, 'end_idx': 33, 'type': 'POH'}
# org:product      org:members      org:product
# ----------
# ----------
# 97 이경자 정의당 국회의원 예비후보는 포스코 측에 조속한 시일 내 노조의 면담요청에 응하고 전면적인 안전보건 진단을 실시할 것을 제안한다. {'word': '정의당', 'start_idx': 4, 'end_idx': 6, 'type': 'ORG'} {'word': '후보', 'start_idx': 15, 'end_idx': 16, 'type': 'POH'}
# org:top_members/employees      no_relation      org:top_members/employees
# ----------
# ----------
# 99 2008년 2월 2일에 실시된 러시아 대통령 선거에서 그의 후계자로 알려진 메드베데프가 70% 득표로 당선되었다. {'word': '메드베데프', 'start_idx': 42, 'end_idx': 46, 'type': 'PER'} {'word': '후계자', 'start_idx': 33, 'end_idx': 35, 'type': 'POH'}
# per:title      no_relation      per:title
# ----------
# ----------
# 108 공단 강병흥 세종지부장은 “앞으로도 세종시 이전 공무원의 일·가정양립 지원을 위해 공무원과 자녀들이 함께할 수 있는 다채로운 복지프로그램을 마련할 계획이다”고 말했다. {'word': '강병흥', 'start_idx': 3, 'end_idx': 5, 'type': 'PER'} {'word': '공무원', 'start_idx': 27, 'end_idx': 29, 'type': 'POH'}
# no_relation      per:title      no_relation
# ----------
# ----------
# 110 졸업생 여러분을 모교가 응원하듯, 여러분의 전남대학교를 늘 가슴에 품고 사랑하십시오. {'word': '전남대학교', 'start_idx': 24, 'end_idx': 28, 'type': 'ORG'} {'word': '졸업생', 'start_idx': 0, 'end_idx': 2, 'type': 'POH'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 122 7일 윰댕은 자신의 유튜브 채널을 통해 대도서관과 만나기 전 결혼했었던 사실과 아이가 하나 있다고 밝혔다. {'word': '윰댕', 'start_idx': 3, 'end_idx': 4, 'type': 'PER'} {'word': '대도서관', 'start_idx': 22, 'end_idx': 25, 'type': 'PER'}
# no_relation      no_relation      per:spouse
# ----------
# ----------
# 124 한편 에버르는 연적을 죽이려고 했으나 판드가 쿠 훌린을 얼마나 사랑하는지 목격하고는 그냥 쿠 훌린을 그녀에게 넘겨주기로 마음먹는다. {'word': '판드', 'start_idx': 21, 'end_idx': 22, 'type': 'PER'} {'word': '쿠 훌린', 'start_idx': 25, 'end_idx': 28, 'type': 'PER'}
# no_relation      per:colleagues      no_relation
# ----------
# ----------
# 125 당시 아버지 직업은 교도관, 법무부 공무원이었다. {'word': '법무부', 'start_idx': 16, 'end_idx': 18, 'type': 'ORG'} {'word': '교도관', 'start_idx': 11, 'end_idx': 13, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 138 광주시 광산구 신창동 관계자는 “휘현 단원들은 늦게 가야금을 시작했지만, 그동안 ‘ACC와 함께하는 광주음악제’를 비롯해 거리 버스킹 등 수많은 무대에서 내공을 쌓아왔기에 탄탄한 공연을 펼칠 것으로 자신한다”며 “첫 공연을 축하하고, 더 많은 시민이 주민자치 프로그램에서 출발해 끼와 재능을 계발해서 지역사회와 공유할 수 있도록 지원하겠다”고 밝혔다. {'word': '휘현', 'start_idx': 18, 'end_idx': 19, 'type': 'PER'} {'word': '신창동', 'start_idx': 8, 'end_idx': 10, 'type': 'ORG'}
# per:employee_of      org:place_of_headquarters      org:place_of_headquarters
# ----------
# ----------
# 163 11월 12일에는 평화민주당을 창당해 대표 겸 13대 대통령 후보로 선출된 이후 야당 후보였던 김영삼과 후보 단일화를 이루지 못한 채 12월 16일에 제13대 대통령 선거에 출마했지만, 노태우와 김영삼에게 밀려 611만 표를 얻고 낙선했다. {'word': '김영삼', 'start_idx': 53, 'end_idx': 55, 'type': 'PER'} {'word': '노태우', 'start_idx': 104, 'end_idx': 106, 'type': 'PER'}
# no_relation      per:colleagues      per:colleagues
# ----------
# ----------
# 171 스페인 왕위 계승 전쟁에 휘말려, 1714년 바르셀로나 공방전에서 패배한 카탈루냐는 카스티야 왕국의 영토가 되었다. {'word': '카탈루냐', 'start_idx': 41, 'end_idx': 44, 'type': 'ORG'} {'word': '스페인', 'start_idx': 0, 'end_idx': 2, 'type': 'LOC'}
# org:member_of      no_relation      no_relation
# ----------
# ----------
# 175 2008년 경선에서는 그의 풍부한 상원에서의 경험에도 불구하고 버락 오바마와 힐러리 클린턴에 밀려 일찌감치 경선을 포기했다. {'word': '상원', 'start_idx': 19, 'end_idx': 20, 'type': 'ORG'} {'word': '버락 오바마', 'start_idx': 35, 'end_idx': 40, 'type': 'PER'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 187 이날 유인나 씨는 데뷔 때부터 함께 일해온 매니저를 위해 사회자로 나섰다. {'word': '유인나', 'start_idx': 3, 'end_idx': 5, 'type': 'PER'} {'word': '매니저', 'start_idx': 24, 'end_idx': 26, 'type': 'PER'}
# per:colleagues      per:colleagues      no_relation
# ----------
# ----------
# 192 'YG 환장의 콤비' 양현석X승리가 입건됐다. {'word': 'YG', 'start_idx': 1, 'end_idx': 2, 'type': 'ORG'} {'word': '양현석', 'start_idx': 12, 'end_idx': 14, 'type': 'PER'}
# per:employee_of      org:top_members/employees      org:top_members/employees
# ----------
# ----------
# 199 각각 1947년과 1950년에 코치직으로 활동하여 보스턴 마라톤에서 우승한 마라토너 서윤복과 함기용의 코치로 활동해 이들을 훈련시켰고, 1992년 바르셀로나 올림픽 마라톤에서 우승한 황영조는 손기정이 자신의 정신적 지주였다고 밝혔다. {'word': '황영조', 'start_idx': 102, 'end_idx': 104, 'type': 'PER'} {'word': '코치', 'start_idx': 57, 'end_idx': 58, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 201 춘신군은 아래에 식객(食客) 3천 인을 모아 거느리고 있었는데, 상객(上客)은 모두 구슬로 장식한 신발을 신고 있었다고 한다. {'word': '춘신군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '식객', 'start_idx': 9, 'end_idx': 10, 'type': 'POH'}
# per:colleagues      per:colleagues      no_relation
# ----------
# ----------
# 204 미국 육군 전투복(ACU)에 부착하는 성조기는 실제 성조기와는 방향이 반대로 되어 있는데 이것은 병사들이 성조기와 함께 전진한다는 느낌을 주기 위해서다. {'word': '육군', 'start_idx': 3, 'end_idx': 4, 'type': 'ORG'} {'word': 'ACU', 'start_idx': 10, 'end_idx': 12, 'type': 'POH'}
# org:product      org:product      org:alternate_names
# ----------
# ----------
# 209 LG유플러스는 ▲멸종위기 동식물 ▲가상 현실 증강 현실 ▲토목과 건축 ▲카메라 ▲기생충 ▲익충과 해충 등 총 6권을 원작에 기반해 3D 애니메이션과 음향효과를 주어 마치 원작에 들어와 있는 듯한 실감형 콘텐츠로 탈바꿈시켰다. {'word': 'LG유플러스', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '카메라', 'start_idx': 40, 'end_idx': 42, 'type': 'POH'}
# org:product      no_relation      org:product
# ----------
# ----------
# 214 문재인 대통령이 김정은 북한 국무위원장을 오는 25일 부산에서 열리는 한·아세안 특별정상회의에 초청했지만 북한이 21일 '정중히' 거절했다. {'word': '문재인', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '김정은', 'start_idx': 9, 'end_idx': 11, 'type': 'PER'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 234 지난 3.1절 여운형 선생 등 54명의 사회주의 계열 독립투사 서훈에 이어 주요한 사회주의 활동가들에 대해 재조명해 뒤늦게 서훈이 추서되었다. {'word': '여운형', 'start_idx': 8, 'end_idx': 10, 'type': 'PER'} {'word': '사회주의', 'start_idx': 22, 'end_idx': 25, 'type': 'POH'}
# no_relation      per:religion      no_relation
# ----------
# ----------
# 238 순천시가 서면 판교리 용계산 ‘기적의 숲’에 조성 예정인 산림레포츠단지의 '2021년 아시아 산악자전거 컨티넨탈 챔피온십'대회 유치를 위해 업무협약식을 가졌다. {'word': '순천시', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '서면', 'start_idx': 5, 'end_idx': 6, 'type': 'LOC'}
# no_relation      no_relation      org:members
# ----------
# ----------
# 242 그 리고 그의 가족들은 닉이 너무 빨리 사랑에 빠지는것을 못마땅해한다. 가끔 케빈의 터무니 없는 행동에 참을성을 잃기도 하지만 닉은 멤버들 중에서는 가장 진지하다. {'word': '케빈', 'start_idx': 43, 'end_idx': 44, 'type': 'PER'} {'word': '닉', 'start_idx': 13, 'end_idx': 13, 'type': 'PER'}
# no_relation      per:colleagues      per:colleagues
# ----------
# ----------
# 259 bhc치킨은 오는 22일까지 BSR(bhcCSR) 공식 블로그와 페이스북을 통해 봉사활동 추천 댓글 이벤트를 펼친다. {'word': 'bhc치킨', 'start_idx': 0, 'end_idx': 4, 'type': 'ORG'} {'word': 'bhcCSR', 'start_idx': 20, 'end_idx': 25, 'type': 'ORG'}
# no_relation      org:alternate_names      org:alternate_names
# ----------
# ----------
# 276 장흥군 장동면 기관사회단체 제암회(회장 김광재)는 지난 19일 안중근 의사를 모신 해동사를 방문해 참배하고 환경정화 활동을 펼쳤다. {'word': '김광재', 'start_idx': 22, 'end_idx': 24, 'type': 'PER'} {'word': '장흥군', 'start_idx': 0, 'end_idx': 2, 'type': 'LOC'}
# per:employee_of      per:employee_of      per:place_of_residence
# ----------
# ----------
# 281 강진군귀농인협의회(회장 김옥환)는 강진군의 전폭적인 지원을 통해 9개월 코스의 실용 유기농 전문가 과정, 귀농 선후배 멘토링 지원, 귀농인 강진 문화 탐방 등 강진에 정착하는 신규 농업인들의 애로사항 해결과 조기 정착을 위해 다양한 교육 과정 및 소통의 시간을 함께하고 있다. {'word': '강진군', 'start_idx': 19, 'end_idx': 21, 'type': 'ORG'} {'word': '강진', 'start_idx': 89, 'end_idx': 90, 'type': 'LOC'}
# org:place_of_headquarters      org:place_of_headquarters      org:alternate_names
# ----------
# ----------
# 291 지난 12일 샤이니 멤버 태민은 인스타그램에 "멤버들 나 오늘 투어 잘 마쳤어! 보고 싶다~"라는 글을 남기며 사진을 게재했다. {'word': '샤이니', 'start_idx': 7, 'end_idx': 9, 'type': 'PER'} {'word': '멤버', 'start_idx': 26, 'end_idx': 27, 'type': 'POH'}
# per:employee_of      no_relation      no_relation
# ----------
# ----------
# 295 광양시와 (사)국가무형문화재기능협회(이사장 박종군), 문화재청 국립무형유산원(원장 김연수)에서 주최하고 (사)국가무형문화재기능협회와 광양문화원(원장 김종호)이 주관하는 이번 특별전은 12. 6.(금)까지 3개월간 진행된다. {'word': '광양문화원', 'start_idx': 74, 'end_idx': 78, 'type': 'ORG'} {'word': '이사장', 'start_idx': 20, 'end_idx': 22, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 298 아랍에미리트의 관광업은 급격하게 성장하고 있고, 정부 차원에서도 대대적으로 투자하는 분야들 중 하나이다. {'word': '정부', 'start_idx': 27, 'end_idx': 28, 'type': 'ORG'} {'word': '아랍에미리트', 'start_idx': 0, 'end_idx': 5, 'type': 'LOC'}
# org:place_of_headquarters      org:member_of      org:place_of_headquarters
# ----------
# ----------
# 317 로마 속주 트라키아의 수도로 번창했으며 371년 발렌스 황제가 아드리아노폴리스 전투에서 고트족과 싸우다 전사하였다. {'word': '발렌스', 'start_idx': 27, 'end_idx': 29, 'type': 'PER'} {'word': '로마', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# per:place_of_death      per:place_of_death      no_relation
# ----------
# ----------
# 339 영국은 한국전쟁 때 미국에 이어 두 번째로 가장 큰 규모의 UN 소속의 UN군을 파견한 바 있다. {'word': 'UN', 'start_idx': 33, 'end_idx': 34, 'type': 'ORG'} {'word': '영국', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'}
# no_relation      org:place_of_headquarters      no_relation
# ----------
# ----------
# 351 2019 대한민국통합의학박람회 개막식이 7일 오후 장흥군 안양면 통합의학박람회장에서 열린 가운데 김영록 전라남도지사, 정종순 장흥군수, 마재주 박람회추진위원장, 김한종 도이회 부의장 등 참석자들이 개막 퍼포먼스를 하고 있다. {'word': '김한종', 'start_idx': 90, 'end_idx': 92, 'type': 'PER'} {'word': '마재주', 'start_idx': 76, 'end_idx': 78, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 352 장병완 의원은 5일 열린 정무위 전체회의 의사진행 발언을 통해 “지난 번 전체회의에서 5.18유공자단체 공법단체 지정법 통과를 간곡히 호소한 바 있다. 안타깝게도 법안1소위에서 논의조차 해 보지 못했다”고 밝히며 “교섭단체 간사로서 양당 간사를 비롯한 미래통합당 의원님들께 보훈처 소관 법률안 심사를 호소했으나 2월 국회에서는 보훈처 소관 법률안을 처리하지 못한다는 답변을 받았을 뿐이다”고 말했다. {'word': '미래통합당', 'start_idx': 141, 'end_idx': 145, 'type': 'ORG'} {'word': '장병완', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 383 어떤 상황에서도 “너무 좋아”라고 말하는 무한 긍정남 강하늘과 셰프 못지 않은 요리 실력을 겸비한 안재홍, 그리고 허당미와 끼가 동시에 넘치는 막내 옹성우의 모습은 예고만으로도 기대감을 더하고 있다. {'word': '안재홍', 'start_idx': 55, 'end_idx': 57, 'type': 'PER'} {'word': '강하늘', 'start_idx': 30, 'end_idx': 32, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 391 최종 계급은 육군 원수. 동부전선에서는 물론, 노르망디 상륙작전 이후의 서부전선에서도 방어전으로 명성을 쌓았으며 독일 제3국 최고의 방어전 지휘관이며 제2차 세계 대전 최고의 방어전 지휘관이다. {'word': '육군', 'start_idx': 7, 'end_idx': 8, 'type': 'ORG'} {'word': '지휘관', 'start_idx': 78, 'end_idx': 80, 'type': 'POH'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 393 옥스퍼드 대학교 명예 박사학위를 비롯한 수많은 학위와 미국의 자유의 훈장, 프랑스의 레종 도뇌르 훈장 등 온갖 상훈, 영국의 명예 기사작위까지도 있다. {'word': '옥스퍼드 대학교', 'start_idx': 0, 'end_idx': 7, 'type': 'ORG'} {'word': '영국', 'start_idx': 66, 'end_idx': 67, 'type': 'LOC'}
# no_relation      org:place_of_headquarters      org:place_of_headquarters
# ----------
# ----------
# 404 또한 유비를 행대사마 영사례교위로 추천했으며 유비는 유장을 행진서대장군(行鎭西大將軍) 영익주목으로 추천하였다. {'word': '유장', 'start_idx': 29, 'end_idx': 30, 'type': 'PER'} {'word': '유비', 'start_idx': 25, 'end_idx': 26, 'type': 'PER'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 409 1930년대~1940년대 방응모에게서 장학금을 지원받은 학생 모임인 서중회의 회원들의 그의 인물평은 "첫 인상은 좀 깡마른 모습이었으나 의지가 강한 인물"이라는 평을 남기기도 했다. {'word': '서중회', 'start_idx': 38, 'end_idx': 40, 'type': 'ORG'} {'word': '방응모', 'start_idx': 14, 'end_idx': 16, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 431 전북 김제시가 '김제시 행정기구 설치 조례 일부개정조례안'(이하 조직개편안)과 '지방공무원 정원 조례 일부개정안(이하 정원 조례 개정안)'을 추진하는 과정에서 1일, 김제시의회 의원 간담회 보고 안건에 또다시 등장하면서 김주택 의원이 강한 불만을 쏟아 냈다. {'word': '김주택', 'start_idx': 123, 'end_idx': 125, 'type': 'PER'} {'word': '김제시', 'start_idx': 3, 'end_idx': 5, 'type': 'ORG'}
# no_relation      per:employee_of      no_relation
# ----------
# ----------
# 435 이 영화의 제작사 케이퍼필름 안수현 대표는 조승우를 선택한 이유에 대하여 "김원봉의 경우 고민을 많이 할 수 밖에 없었다. 젊은 층에선 김원봉이란 인물을 알지 못하는 경우도 많더라. 독립운동을 풍미했던 대단한 인물이라는 점을 부각시키기 위해선 그 만큼 '임팩트' 강한 배우가 필요했다."라고 밝혔다. {'word': '김원봉', 'start_idx': 42, 'end_idx': 44, 'type': 'PER'} {'word': '조승우', 'start_idx': 24, 'end_idx': 26, 'type': 'PER'}
# per:alternate_names      no_relation      per:alternate_names
# ----------
# ----------
# 445 알렉은 다넬과 미스티, 토드를 '광대 삼남매'라고 부른다. {'word': '미스티', 'start_idx': 8, 'end_idx': 10, 'type': 'PER'} {'word': '알렉', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 458 이날 샘 해밍턴은 벤틀리와 윌리엄을 데리고 이영자를 찾았다. {'word': '벤틀리', 'start_idx': 10, 'end_idx': 12, 'type': 'PER'} {'word': '윌리엄', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 473 전남 순천이 고향인 김창수 서장은 1999년 제11기 소방간부후보생으로 입문해 전남소방교육대장, 전남소방본부 구조구급과장 등 주요요직을 두루 거쳤으며, 특히, 직원 상호 간 배려와 소통을 바탕으로 탁월한 업무 추진력과 통솔력을 겸비한 지휘관으로 인정받고 있다. {'word': '김창수', 'start_idx': 11, 'end_idx': 13, 'type': 'PER'} {'word': '구조구급과장', 'start_idx': 61, 'end_idx': 66, 'type': 'POH'}
# no_relation      per:title      no_relation
# ----------
# ----------
# 484 시롤라는 1925년에서 1927년 사이에는 미국 공산당의 코민테른 대표를 겸임했다. {'word': '시롤라', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '코민테른', 'start_idx': 32, 'end_idx': 35, 'type': 'ORG'}
# no_relation      no_relation      per:employee_of
# ----------
# ----------
# 495 나해수 진안군수 권한대행은 "정월대보름 행사는 한해의 액운을 쫒아내고 풍년이 들도록 기원하는 우리민족 고유의 전통행사이지만 신종 코로나바이러스가 확산되는 상황에서 군민들의 안전과 건강을 최우선으로 고려해 취소하기로 결정했다"고 밝혔다. {'word': '나해수', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '군수', 'start_idx': 6, 'end_idx': 7, 'type': 'POH'}
# no_relation      per:title      per:title
# ----------
# ----------
# 499 경기 고양시(시장 이재준)가 ㈜하나은행, 경기신용보증재단과 함께 ‘소상공인 특례보증 매칭 출연 협약’을 맺고 소상공인들을 위한 신용보증 지원 사업에 나섰다. {'word': '경기신용보증재단', 'start_idx': 23, 'end_idx': 30, 'type': 'ORG'} {'word': '이재준', 'start_idx': 10, 'end_idx': 12, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 511 11세기 교회의 대분열 이후 분리된 로마교회는 서방교회로 형성되었고, 동방교회와 분리되어 교황중심주의 형태로 지속되었다. {'word': '로마교회', 'start_idx': 20, 'end_idx': 23, 'type': 'ORG'} {'word': '서방', 'start_idx': 26, 'end_idx': 27, 'type': 'LOC'}
# org:alternate_names      org:alternate_names      org:place_of_headquarters
# ----------
# ----------
# 514 김유화 예비후보는 “문재인 대통령이 수석보좌관회의에서 과감한 정책적 상상력을 요구한 만큼 정부는 절박한 상황에 비상한 해법을 국민에게 내놓아야 한다”며 “정부 지원이 세제 혜택 등의 간접지원보다 일부 고소득자를 제외한 국민에게 일정 금액의 재난기본소득이나 긴급생활자금 등 직접 지원을 해야 하며 국회와 정부는 심도 있게 논의하여 추경에 포함해 주기를 바란다”고 직접 지원을 요구했다. {'word': '김유화', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '대통령', 'start_idx': 15, 'end_idx': 17, 'type': 'POH'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 518 노산대군은 세종의 적장손이고 문종의 적장자이니 옳고, 세조는 세종대왕의 차남으로 왕통을 이었으니 옳다는 것이었다. {'word': '세조', 'start_idx': 30, 'end_idx': 31, 'type': 'PER'} {'word': '문종', 'start_idx': 16, 'end_idx': 17, 'type': 'PER'}
# per:other_family      per:parents      per:parents
# ----------
# ----------
# 520 숀은 레논의 35번째 생일이었던 1975년 10월 9일 제왕 절개를 통해 출생했다. {'word': '숀', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '레논', 'start_idx': 3, 'end_idx': 4, 'type': 'PER'}
# per:parents      per:alternate_names      per:alternate_names
# ----------
# ----------
# 534 정명훈은 18세에 런던에서 줄리니가 연주하는 베토벤 교향곡 제7번을 듣고 작품의 핵심을 짚어내는 연주에 깊은 감명을 받았으며 마리아 쿠르초의 소개로 무대 뒤에서 그를 만났다. {'word': '줄리니', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'} {'word': '정명훈', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# no_relation      per:colleagues      per:colleagues
# ----------
# ----------
# 552 그러나 각별히 사랑했던 효전성황후의 죽음에 깊이 애도한 도광제는 효전성황후의 상례를 마친 뒤에도 황후를 책립치 않아 결국 도광제가 서거하기까지 6년 간 황후의 자리는 공석이 되었다. {'word': '효전성황후', 'start_idx': 36, 'end_idx': 40, 'type': 'PER'} {'word': '황후', 'start_idx': 54, 'end_idx': 55, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 553 이 시장은 지난 2018년 7월 제7호 태풍 ‘쁘라삐룬’의 북상에 따라 취임식을 전격 취소하고 태풍대비 비상체제를 진두지휘하는 것으로 민선7기 5대 양주시장 취임 첫 업무를 시작했다. {'word': '이', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '양주', 'start_idx': 83, 'end_idx': 84, 'type': 'LOC'}
# per:place_of_residence      per:place_of_residence      per:employee_of
# ----------
# ----------
# 565 호남권 선대위는 수석 대변인에 장세일 전남도의원을 선임했다. {'word': '선대위', 'start_idx': 4, 'end_idx': 6, 'type': 'ORG'} {'word': '수석 대변인', 'start_idx': 9, 'end_idx': 14, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 587 이 관계자는 이어 "문 대통령을 비롯해 청와대는 코로나19 대응에 매진하겠다는 의지를 밝힌 것"이라면서 "이는 문재인 대통령의 확고한 뜻"이라고 강조했다. {'word': '문', 'start_idx': 11, 'end_idx': 11, 'type': 'PER'} {'word': '관계자', 'start_idx': 2, 'end_idx': 4, 'type': 'POH'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 588 결국 나중에 가서 카를은 보두앵 1세를 사위로 인정하고 864년 플랑드르 백작에 임명했다. {'word': '카를', 'start_idx': 10, 'end_idx': 11, 'type': 'PER'} {'word': '보두앵 1세', 'start_idx': 14, 'end_idx': 19, 'type': 'PER'}
# per:other_family      per:colleagues      per:colleagues
# ----------
# ----------
# 598 이에 정부로부터 그 공훈을 인정받아 국방부 장관표창, 화랑·충무·을지무공훈장을 받았다. {'word': '국방부', 'start_idx': 20, 'end_idx': 22, 'type': 'ORG'} {'word': '정부', 'start_idx': 3, 'end_idx': 4, 'type': 'ORG'}
# org:member_of      no_relation      org:member_of
# ----------
# ----------
# 610 리정혁은 윤세리와 함께 더 있고 싶은 마음에 일부러 길을 헤맸고 이를 눈치 챈 윤세리는 웃었다. {'word': '리정혁', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '윤세리', 'start_idx': 5, 'end_idx': 7, 'type': 'PER'}
# per:spouse      per:colleagues      per:spouse
# ----------
# ----------
# 635 기독교의 성인. 로마 가톨릭에서 축일은 12월 26일이며, 동방 정교회에서 축일은 12월 27일이다. {'word': '로마 가톨릭', 'start_idx': 9, 'end_idx': 14, 'type': 'ORG'} {'word': '기독교', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'}
# org:political/religious_affiliation      no_relation      no_relation
# ----------
# ----------
# 646 이 언약은 찰스 1세와 윌리엄 로드가 스코틀랜드 교회를 영국의 예배형식과 교회 정치에 따르는 것을 거부한 것이다. {'word': '찰스 1세', 'start_idx': 6, 'end_idx': 10, 'type': 'PER'} {'word': '스코틀랜드', 'start_idx': 21, 'end_idx': 25, 'type': 'LOC'}
# no_relation      per:origin      per:origin
# ----------
# ----------
# 648 제주용암수 국내 판매를 놓고 제주도와 빚은 마찰을 매듭지은 오리온이 한숨을 돌리기도 전에 예상 못한 암초를 만났다. {'word': '제주도', 'start_idx': 16, 'end_idx': 18, 'type': 'ORG'} {'word': '제주', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# no_relation      no_relation      org:alternate_names
# ----------
# ----------
# 652 중부해경청에 따르면 최근 3년간 경기도 가평군 등 내수면에서 수상레저 활동 중 5명의 사망사고가 발생하였으며, 이들 대부분은 구명조끼를 착용하지 않은 것으로 확인되었다고 전했다. {'word': '중부해경청', 'start_idx': 0, 'end_idx': 4, 'type': 'ORG'} {'word': '경기도', 'start_idx': 18, 'end_idx': 20, 'type': 'LOC'}
# no_relation      org:place_of_headquarters      org:place_of_headquarters
# ----------
# ----------
# 659 현장에서 부하에게 상냥하게 얘기하는 등의 응양스러움도 겸비하고 있었지만, 사신 박사와 사이가 나쁘고, 자신의 재임 중에 그가 일본에 방문했을 때는, 협력적인 표정을 보이면서 서로 서로 견제하고 있었다. {'word': '사신', 'start_idx': 41, 'end_idx': 42, 'type': 'PER'} {'word': '박사', 'start_idx': 44, 'end_idx': 45, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 664 또한, 글래드 여의도의 뷔페&카페 레스토랑 ‘그리츠’에서는 ‘갈비 가든’ 프로모션을 통해 그리츠 특제 양념으로 조리한 갈비 양념 구이와 돼지고기에 마늘종, 양파 등과 함께 간장과 식초로 간을 한 중국요리 회과육, 최근 떠오르는 식재료인 마라 소스를 활용하여 매콤하고 알싸한 맛을 낸 마라 갈비, 부드럽고 고소한 차돌박이를 넣고 끓인 차돌박이 된장찌개 등 다양한 요리를 선보이며, 고객 2인당 티본 스테이크 1접시를 제공하는 디너 스페셜 이벤트를 진행한다. 가격은 점심은 4만5100원, 저녁은 5만5000원(세금 포함)이다. {'word': '그리츠', 'start_idx': 25, 'end_idx': 27, 'type': 'ORG'} {'word': '갈비 가든', 'start_idx': 34, 'end_idx': 38, 'type': 'POH'}
# org:product      no_relation      org:product
# ----------
# ----------
# 672 박정희가 죽었을 때, 한국에서 근무한 적이 있던 한 일본인 외교관이 자신의 저서에서 대일본제국 최후의 군인이 죽었다고 평하였다. {'word': '박정희', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '한국', 'start_idx': 12, 'end_idx': 13, 'type': 'LOC'}
# per:origin      per:place_of_death      per:origin
# ----------
# ----------
# 675 그는 “이란의 솔레이마니 사령관 사망 이후 이라크 내 기대 프로젝트인 유정내 물공급시설, 발전소 등 3개 사업의 발주지연 가능성이 높아진 점이 아쉽다”라고 덧붙였다. {'word': '솔레이마니', 'start_idx': 8, 'end_idx': 12, 'type': 'PER'} {'word': '이라크', 'start_idx': 24, 'end_idx': 26, 'type': 'LOC'}
# no_relation      per:place_of_death      no_relation
# ----------
# ----------
# 682 1971년 미국 맨해튼으로 이주한 뒤로 체류 전반에 걸쳐 논란이 되는 정치적 및 평화 운동을 전개했으며 그의 베트남 전쟁에 대한 비판은 리처드 닉슨 행정부가 그를 추방하기 위한 오랜 시도를 낳았고, 한편 그가 작곡한 곡들은 반전쟁 운동의 앤섬으로 채택되거나 더 큰 반문화를 구축하는데 일조한다. {'word': '리처드 닉슨', 'start_idx': 76, 'end_idx': 81, 'type': 'PER'} {'word': '미국', 'start_idx': 6, 'end_idx': 7, 'type': 'LOC'}
# per:place_of_residence      per:place_of_residence      per:origin
# ----------
# ----------
# 689 중계방송에 출연한 타이 보타우 PGA투어 국제부문사장은 더CJ컵이 성공 이유에 대해 “CJ의 모든 관계 조직이 최고의 대회를 만들기 위해 최선의 노력을 기울인 결과”라며 “한국 팬들의 골프에 대한 열정과 음식, 호텔 등 CJ의 특별한 환대가 세계 최고의 선수들을 다시 이 대회로 모이게 하는 이유”라고 말했다. {'word': 'CJ', 'start_idx': 123, 'end_idx': 124, 'type': 'ORG'} {'word': 'PGA투어', 'start_idx': 17, 'end_idx': 21, 'type': 'POH'}
# no_relation      no_relation      org:member_of
# ----------
# ----------
# 695 "StarCraft II" 에서 Kerrigan은 Terran Dominion 식민지에 대한 공격을 시작합니다. {'word': 'Kerrigan', 'start_idx': 18, 'end_idx': 25, 'type': 'ORG'} {'word': 'StarCraft II', 'start_idx': 1, 'end_idx': 12, 'type': 'POH'}
# no_relation      no_relation      org:product
# ----------
# ----------
# 700 도교육청은 이날 발표한 인사를 통해 본청 교육복지과장에 정덕원 곡성교육지원과장, 전남교육연구정보원장에 정경모 도교육청 유초등인사팀 장학관, 전남국제교육원장에 고미영 국제교육원 국제교육부장, (주민추천)나주교육지원청교육장에 김영길 함평교육지원과장, 영광교육지원청교육장에 허호 도교육청 교육복지과장, (주민추천)장성교육지원청교육장에 최미숙 진원초 교장, 신안교육지원청교육장에 김재흥 미력초 교장을 각각 임용했다. {'word': '영광교육지원청', 'start_idx': 138, 'end_idx': 144, 'type': 'ORG'} {'word': '교육장', 'start_idx': 179, 'end_idx': 181, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 703 그는 “고려아연은 전기차용 동박을 생산 판매할 계획이며, 장기적으로는 전기차 폐배터리 재활용 산업에 진출할 전망”이라며 “현재 주가는 PBR 1.1배, PER 12배로 성장 기대감을 주가는 충분히 반영하지 못하고 있다고 판단된다”라고 밝혔다. {'word': '고려아연', 'start_idx': 4, 'end_idx': 7, 'type': 'ORG'} {'word': '배터리', 'start_idx': 44, 'end_idx': 46, 'type': 'POH'}
# no_relation      no_relation      org:product
# ----------
# ----------
# 704 그는 곧 위키미디어 재단을 설립해 위키백과 이외의 다른 위키 프로젝트들과 위키백과의 엔진인 미디어위키가 개선될 수 있도록 했다. {'word': '위키미디어 재단', 'start_idx': 5, 'end_idx': 12, 'type': 'ORG'} {'word': '위키백과', 'start_idx': 41, 'end_idx': 44, 'type': 'POH'}
# no_relation      no_relation      org:product
# ----------
# ----------
# 714 전북민중행동은 전주시의 롯데 재벌에 대한 특혜 행정 중단과 해당 상임위의 논의 결과도 무시한 채 전주시의 거수기로 전락해 버린 전주시의회의 롯데 특혜 예산 통과를 강력하게 규탄한다. {'word': '전주시', 'start_idx': 54, 'end_idx': 56, 'type': 'ORG'} {'word': '롯데', 'start_idx': 13, 'end_idx': 14, 'type': 'ORG'}
# no_relation      org:members      no_relation
# ----------
# ----------
# 724 배우 한윤지 씨는 백송이 하사로 군인들 사이에서 유명하다. {'word': '백송이', 'start_idx': 10, 'end_idx': 12, 'type': 'PER'} {'word': '하사', 'start_idx': 14, 'end_idx': 15, 'type': 'POH'}
# per:alternate_names      per:title      per:title
# ----------
# ----------
# 726 송 군수는 ”나도 공직자 출신이고, 또 선배 공직자로서 인사기록 카드에 징계기록의 불명예를 남기는 것은 모든 공무원이 제일 싫어하는 것”이라며 “(직원이 유포자라 하더라도) 징계보다는 잠시 밖에 있다 조용해지면 들어오는 것이 나을 수도 있다”면서 징계를 할 생각은 없음을 시사했다. {'word': '송', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '공무원', 'start_idx': 61, 'end_idx': 63, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 739 이번 산학협력 교류회에서는 △LINC사업단 사업설명 △조선대학교 기술사업화 센터 기술이전 및 사업화 소개 △조선대학교 기술사업화센터 기술이전 및 사업화 상담 부스 운영 △2019 하계 현장실습수기공모전 및 광주 도시재생 우수 아이디어 공모전 시상식 △2019년 사업 3차년도 제1차 자체평가위원회 등이 진행됐다. {'word': 'LINC사업단', 'start_idx': 16, 'end_idx': 22, 'type': 'ORG'} {'word': '조선대학교', 'start_idx': 30, 'end_idx': 34, 'type': 'ORG'}
# no_relation      org:member_of      no_relation
# ----------
# ----------
# 749 인포웍스는 지능형 모빌리티 센서와 솔루션을 개발·공급하는 기업으로 올해 1월에는 국내 최초로 인공신경망(NPU) 기반 인공지능 엣지 컴퓨터 개발보드 ‘REX Basic’을 출시하며 업계의 주목을 받는 등 인공지능 하드웨어와 소프트웨어 플랫폼 개발 역량을 모두 보유하고 있는 기업으로 평가받고 있다. {'word': '인포웍스', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': 'NPU', 'start_idx': 58, 'end_idx': 60, 'type': 'POH'}
# org:product      org:product      no_relation
# ----------
# ----------
# 751 독일을 여행하고 있던 미국인 린지와 제니는 차가 고장나자 길을 잃게 된다. {'word': '제니', 'start_idx': 20, 'end_idx': 21, 'type': 'PER'} {'word': '독일', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# per:place_of_residence      no_relation      per:place_of_residence
# ----------
# ----------
# 763 이정찬, 이영규 당선자는 “당당한 노동조합 남원시지부의 힘찬 전진 조합원 여러분과 함께 만들어가겠습니다”라는 제목으로 당선 인사를 내부 전자망에 올려 앞으로 남원시지부를 어떻게 이끌 것인가에 대하여 강한 의지와 각오를 밝혔다. {'word': '이영규', 'start_idx': 5, 'end_idx': 7, 'type': 'PER'} {'word': '이정찬', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 772 그는 “현대모비스는 금번 실적 컨퍼런스 콜을 통해 CO2 규제가 큰 폭으로 강화되는 유럽 지역에서 전동화 부품 현지공급 계획을 발표했다. 전동화 부분은 2019년에 발표된 충주공장 확장, 울산공장 신축에 이어 매우 빠른 행보가 펼쳐지고 있는 것으로 판단된다”라며 “특히 슬로박과 체코에 각각 BSA 및 배터리 조립라인 신설을 통해 현대기아차향 xEV로 매출이 발생할 예정”이라고 언급했다. {'word': '현대기아차', 'start_idx': 185, 'end_idx': 189, 'type': 'ORG'} {'word': '배터리', 'start_idx': 169, 'end_idx': 171, 'type': 'POH'}
# no_relation      no_relation      org:product
# ----------
# ----------
# 777 이번 릴레이 봉사활동 발대식은 광주광역시의 ‘시민참여형 광주천 가꾸기’ 사업에 적극 동참하는 의미로 광주은행은 지난 4월 광주시와 관련 협약을 체결한 가운데 7월부터 본격적인 광주천 정화활동에 나선다. {'word': '광주시', 'start_idx': 68, 'end_idx': 70, 'type': 'ORG'} {'word': '광주광역시', 'start_idx': 17, 'end_idx': 21, 'type': 'ORG'}
# org:alternate_names      org:member_of      org:alternate_names
# ----------
# ----------
# 780 전운판관이 되었을 때는 부안의 유명한 시인이자 기생인 매창(梅窓)과 교류한다. {'word': '매창', 'start_idx': 30, 'end_idx': 31, 'type': 'PER'} {'word': '부안', 'start_idx': 13, 'end_idx': 14, 'type': 'LOC'}
# per:origin      per:place_of_residence      per:origin
# ----------
# ----------
# 802 또한 이미 지난 1482년에 7세의 차남 조반니를 성직자의 길을 걷도록 해두었다. {'word': '조반니', 'start_idx': 23, 'end_idx': 25, 'type': 'PER'} {'word': '차남', 'start_idx': 20, 'end_idx': 21, 'type': 'POH'}
# per:parents      no_relation      per:parents
# ----------
# ----------
# 804 수리논리학의 발전은 20세기의 최초의 수십 년, 특히 괴델 및 타르스키의 저작에 의해서 일어나, 분석 철학이나 철학적 논리학, 특히 1950년대 이후에 양상 논리나 시제 논리, 의무 논리, 적정 논리 등에 영향을 주었다. {'word': '타르스키', 'start_idx': 35, 'end_idx': 38, 'type': 'PER'} {'word': '괴델', 'start_idx': 30, 'end_idx': 31, 'type': 'PER'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 819 해방 직후 한민당의 당수인 송진우와 장덕수, 근로인민당수 여운형 등이 신탁통치의 불가피성을 주장하거나 신탁통치, 미소공위 개최에 찬성하다가 암살당했다. {'word': '장덕수', 'start_idx': 20, 'end_idx': 22, 'type': 'PER'} {'word': '송진우', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 829 광주전남혈액원 관계자는 매년 정기적인 헌혈 행사에 참여해준 전남도교육청 직원들에게 “여러분의 작은 사랑 큰 나눔이 소중한 생명을 살리고 헌혈 활성화 분위기 조성에 큰 도움이 되고 있다”고 감사의 뜻을 전했다. {'word': '광주전남혈액원', 'start_idx': 0, 'end_idx': 6, 'type': 'ORG'} {'word': '전남도교육청', 'start_idx': 33, 'end_idx': 38, 'type': 'ORG'}
# org:members      no_relation      no_relation
# ----------
# ----------
# 832 《선조수정실록》에 따르면, 동인인 류성룡은 김덕령에게 죄가 있음이 확실하니 다른 죄인이 다다를 때까지 치죄를 신중히 따져가며 하도록 간했으나, 서인이며 윤근수의 형제인 판중추부사 윤두수는 즉시 엄벌에 처할 것을 주장했다. {'word': '류성룡', 'start_idx': 19, 'end_idx': 21, 'type': 'PER'} {'word': '동인', 'start_idx': 15, 'end_idx': 16, 'type': 'POH'}
# per:origin      per:employee_of      per:employee_of
# ----------
# ----------
# 838 성인이 된 후 덕만(이요원 분), 김유신(엄태웅 분)과 함께 미실에 맞서지만 이후 미실이 자신의 친엄마라는 사실을 알고 혼란에 빠지는 캐릭터다. {'word': '미실', 'start_idx': 46, 'end_idx': 47, 'type': 'PER'} {'word': '김유신', 'start_idx': 19, 'end_idx': 21, 'type': 'PER'}
# no_relation      no_relation      per:other_family
# ----------
# ----------
# 842 그러나 Girls´ Generation World Tour - Girls & Peace는 SM 엔터테인먼트의 자사 브랜드화를 위한 하향 평준화 정책 및 아시아 최고 연예 기획사를 목표로 하는 경영 방침으로 말미암아 월드 투어로 포장된 아시아 투어가 되고 말았다. {'word': 'SM 엔터테인먼트', 'start_idx': 50, 'end_idx': 58, 'type': 'ORG'} {'word': '아시아', 'start_idx': 85, 'end_idx': 87, 'type': 'LOC'}
# no_relation      org:place_of_headquarters      org:place_of_headquarters
# ----------
# ----------
# 859 1999년에는 ‘사로’ ‘생강’ 등 단편영화에서 발군의 실력을 인정받은 정지우 감독의 장편 데뷔작 《해피 엔드》에서 남편(최민식 분)과 정부(주진모 분) 사이의 불륜에 빠진 아내 최보라 역을 맡은 전도연은 옛 애인과 불륜을 저지르는 아이 엄마의 불안하고 복잡하고 예민한 심리를 빼어나게 연기했다. {'word': '최민식', 'start_idx': 68, 'end_idx': 70, 'type': 'PER'} {'word': '감독', 'start_idx': 44, 'end_idx': 45, 'type': 'POH'}
# per:title      no_relation      no_relation
# ----------
# ----------
# 880 CJ올리브영은 올해 20주년을 맞아 새롭게 명명한 ‘올리브영다움’ 조직문화 카드를 전 임직원에게 배포했다고 18일 밝혔다. {'word': 'CJ올리브영', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '20주년', 'start_idx': 11, 'end_idx': 14, 'type': 'DAT'}
# no_relation      no_relation      org:founded
# ----------
# ----------
# 891 2007년 1월 곤살레스는 로스 앤젤레스에서 메누도(Menudo) 제작 오디션을 봤다. {'word': '곤살레스', 'start_idx': 9, 'end_idx': 12, 'type': 'PER'} {'word': '메누도', 'start_idx': 25, 'end_idx': 27, 'type': 'POH'}
# no_relation      no_relation      per:product
# ----------
# ----------
# 892 매지컬 트리는 크게 주인공인 아파치와 주인공의 부모님으로 나뉜다. {'word': '아파치', 'start_idx': 16, 'end_idx': 18, 'type': 'PER'} {'word': '주인공', 'start_idx': 11, 'end_idx': 13, 'type': 'POH'}
# per:alternate_names      per:alternate_names      per:title
# ----------
# ----------
# 919 중종이 명하여 세 정승과 해당되는 조(曹)를 불러 이것을 의논하고 먼저 본도(本道)에 밀지(密旨)를 내리고 또 무기를 보내 이지방을 파견하여 틈을 엿보아 법에 따라 처치하려고 하였다. {'word': '중종', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'} {'word': '조', 'start_idx': 19, 'end_idx': 19, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 959 민정당 소속으로 제11·12·13대 국회의원에 당선되었으며, 민정당 당무위원 겸 사무총장 등을 거쳐 민정당 당무위원 겸 원내총무를 거쳤다. {'word': '민정당', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '국회의원', 'start_idx': 20, 'end_idx': 23, 'type': 'POH'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 974 장성규 씨는 지난 7월 '카스' 모델이 됐다고 밝혔었다. {'word': '장성규', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '카스', 'start_idx': 14, 'end_idx': 15, 'type': 'POH'}
# per:employee_of      no_relation      no_relation
# ----------
# ----------
# 975 양평군은 민선 7기 공약사항 중 하나인 ‘양평 드론특구 조성’ 사업 추진에 따라 관내 드론 문화의 저변확대를 위한 ‘드론 체험 및 교육장 조성사업’을 경기도와 협업추진 중에 있으며 드론 페스티벌, 사진 공모전, 드론 테스트베드 조성 등 드론 산업 육성을 위한 사업을 다각적으로 검토 중에 있다. {'word': '양평군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '경기도', 'start_idx': 84, 'end_idx': 86, 'type': 'ORG'}
# org:member_of      org:member_of      no_relation
# ----------
# ----------
# 980 이 필름들은 조필린 글로브에서 인화를 하였고, 인화된 사진들은 많은 사람들에게 널리 알려진 배로와 파커, 그리고 존슨이 서로에게 총을 겨누며 익살을 떨고 있는 사진들이다. {'word': '배로', 'start_idx': 51, 'end_idx': 52, 'type': 'PER'} {'word': '파커', 'start_idx': 55, 'end_idx': 56, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 985 또한 한전공대 설립 비전으로 광주·전남 시도민의 염원과 대한민국 국민의 기대를 담아 ‘차세대 글로벌 인재를 양성하는 최고의 교육 산실, 한전공대’, ‘지속성장을 위한 혁신생태계 조성, 한전공대’라는 주제를 힘차게 선포했다. {'word': '한전공대', 'start_idx': 3, 'end_idx': 6, 'type': 'ORG'} {'word': '전남', 'start_idx': 19, 'end_idx': 20, 'type': 'LOC'}
# no_relation      org:place_of_headquarters      org:place_of_headquarters
# ----------
# ----------
# 990 3. 마지막으로 유시민 이사장과 김경록 차장의 개인적인 대화록이 유출돼, 현재 거의 모든 언론사가 이 파일을 확보하고 있다는 점 또한 고려하였습니다. {'word': '유시민', 'start_idx': 9, 'end_idx': 11, 'type': 'PER'} {'word': '김경록', 'start_idx': 18, 'end_idx': 20, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 992 이처럼 구장과 대학야구 연맹의 관계가 깊은 곳은 일본 전국을 통틀어서도 유일하다고 볼 수 있다. {'word': '야구 연맹', 'start_idx': 10, 'end_idx': 14, 'type': 'ORG'} {'word': '대학', 'start_idx': 8, 'end_idx': 9, 'type': 'ORG'}
# no_relation      no_relation      org:members
# ----------
# ----------
# 995 안대희는 검사 출신임에도 불구하고, 대법원에서 대법관을 역임하였다. {'word': '안대희', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '검사', 'start_idx': 5, 'end_idx': 6, 'type': 'POH'}
# per:title      per:title      no_relation
# ----------
# ----------
# 1006 토트넘 진영에서 공을 잡은 손흥민은 약 75ｍ를 질주하며 무려 6명의 번리 선수를 따돌리고 골망을 흔들었다. {'word': '번리', 'start_idx': 39, 'end_idx': 40, 'type': 'ORG'} {'word': '6명', 'start_idx': 35, 'end_idx': 36, 'type': 'NOH'}
# org:number_of_employees/members      no_relation      no_relation
# ----------
# ----------
# 1023 코헛은 미국 캘리포니아 카멜(Carmel)이라는 도시를 휴가지로서 제일 좋아하였다. {'word': '코헛', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'} {'word': '미국', 'start_idx': 4, 'end_idx': 5, 'type': 'LOC'}
# no_relation      no_relation      org:place_of_headquarters
# ----------
# ----------
# 1030 2016년, 조승우는 뮤지컬 《스위니 토드》의 타이틀롤 이발사 스위니 토드를 맡아 공연을 하였다. {'word': '조승우', 'start_idx': 7, 'end_idx': 9, 'type': 'PER'} {'word': '스위니 토드', 'start_idx': 17, 'end_idx': 22, 'type': 'POH'}
# per:alternate_names      per:alternate_names      no_relation
# ----------
# ----------
# 1034 한편 김정희 의원은 제11대 전라남도의회 농수산위원회 부위원장, 의회운영위원회 위원으로 활동하면서 도민의 행복한 삶을 위해 성실히 의정활동을 수행하고 있다. {'word': '의회운영위원회', 'start_idx': 36, 'end_idx': 42, 'type': 'ORG'} {'word': '위원', 'start_idx': 44, 'end_idx': 45, 'type': 'POH'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 1071 주 의원은 또한 Massport가 MBTA에서 페리를 인수 할 것을 제안했다. {'word': '주', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '의원', 'start_idx': 2, 'end_idx': 3, 'type': 'POH'}
# per:title      per:title      no_relation
# ----------
# ----------
# 1106 도쿄 YMCA 본부 급습을 지휘한 선우갑은 송계백, 최팔용을 비롯한 사건의 주동자들을 밀고하여 체포하는 데에 큰 공을 세웠다. {'word': '도쿄 YMCA', 'start_idx': 0, 'end_idx': 6, 'type': 'ORG'} {'word': '선우갑', 'start_idx': 19, 'end_idx': 21, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 1110 현재 조선민주주의인민공화국 축구 2부 리그 사이의 승강제는 실시하지 않는다. {'word': '조선민주주의인민공화국', 'start_idx': 3, 'end_idx': 13, 'type': 'ORG'} {'word': '축구', 'start_idx': 15, 'end_idx': 16, 'type': 'POH'}
# org:product      org:members      no_relation
# ----------
# ----------
# 1124 윰댕과 대도서관의 러브 스토리와 인생 역전 성공 스토리는 7일 오후 9시 MBC '휴먼 다큐 사람이 좋다'에서 공개된다. {'word': '윰댕', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'} {'word': '대도서관', 'start_idx': 4, 'end_idx': 7, 'type': 'PER'}
# no_relation      per:alternate_names      per:spouse
# ----------
# ----------
# 1136 결국, 새로운 기호를 찾지 못하고 체코는 일방적으로 체코슬로바키아의 국기(법 제3조에 대해 1992명 중에 542명이 이 헌법 법률을 무시하고 없애기로 결정했다.)에서 변경된 의미로 체코슬로바키아 국기를 사용한다. {'word': '체코', 'start_idx': 19, 'end_idx': 20, 'type': 'ORG'} {'word': '체코슬로바키아', 'start_idx': 29, 'end_idx': 35, 'type': 'LOC'}
# no_relation      no_relation      org:alternate_names
# ----------
# ----------
# 1141 마리나키스는 회장 임기 원년에 팬들 사이에서 인기 있는 에르네스토 발베르데를 감독으로 재선임했고, (발베르데는 1기에서처럼 2기에도 성공을 거두었다) 국제적으로 큰 영향을 끼치는 선수들인 알베르트 리에라, 아리엘 이바가사, 케빈 미라야스, 마르코 판텔리치, 그리고 프랑수아 모데스토를 영입했다. {'word': '에르네스토 발베르데', 'start_idx': 31, 'end_idx': 40, 'type': 'PER'} {'word': '아리엘 이바가사', 'start_idx': 115, 'end_idx': 122, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 1150 엔딩 후 오박사가 마을에 별장을 두고 있으며, 박사가 머무는 동안 전국 도감의 완성도를 평가받을 수 있다. {'word': '오', 'start_idx': 5, 'end_idx': 5, 'type': 'PER'} {'word': '박사', 'start_idx': 6, 'end_idx': 7, 'type': 'POH'}
# per:alternate_names      no_relation      per:title
# ----------
# ----------
# 1157 박용기(朴容琪, 1929년 ~ 2012년)는 예비역 대한민국 육군 대령이다. {'word': '육군', 'start_idx': 34, 'end_idx': 35, 'type': 'ORG'} {'word': '예비역', 'start_idx': 25, 'end_idx': 27, 'type': 'POH'}
# no_relation      org:top_members/employees      no_relation
# ----------
# ----------
# 1162 제나라도 정나라를 돕기 위해 정문공 14년에 회합을 열었고 정문공 17년(기원전 656년)에 초나라의 우익 채를 침공하고 마침내 초나라로 쳐들어갔다. {'word': '정문공', 'start_idx': 33, 'end_idx': 35, 'type': 'PER'} {'word': '정나라', 'start_idx': 5, 'end_idx': 7, 'type': 'LOC'}
# per:origin      per:origin      no_relation
# ----------
# ----------
# 1177 36년간 잊었던 태극기가 게양되었고, 일동의 애국가 제창, 이화여전의 환영가 제창, 홍명희의 환영사, 러취 군정장관의 축사 후 김구의 답사와 이승만의 답사가 있었고, 만세삼창으로 환영회는 폐회되었다. {'word': '김구', 'start_idx': 71, 'end_idx': 72, 'type': 'PER'} {'word': '홍명희', 'start_idx': 47, 'end_idx': 49, 'type': 'PER'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 1181 한국동서발전(주)(사장 박일준)와 강원도 등이 합작 설립한 태백가덕산풍력발전(주)(대표 홍동표)는 3일(화) 사회적 책임이행 및 저소득가구의 지원을 위하여 연탄 3,000장을 후원하였다고 밝혔다. {'word': '박일준', 'start_idx': 13, 'end_idx': 15, 'type': 'PER'} {'word': '홍동표', 'start_idx': 49, 'end_idx': 51, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 1183 이 곡은 빌보드에서 가장 핫한 가수 ‘빌리 아일리시’의 곡으로, 앞서 펼쳐진 베를린 마우어 파크 버스킹에서 준비했던 곡이다. {'word': '빌보드', 'start_idx': 5, 'end_idx': 7, 'type': 'ORG'} {'word': '가수', 'start_idx': 17, 'end_idx': 18, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 1194 후일 당시 에든버러 대학교의 총장이 흄을 무신론자로 간주하였기 때문이라는 것이 알려졌다. {'word': '에든버러 대학교', 'start_idx': 6, 'end_idx': 13, 'type': 'ORG'} {'word': '흄', 'start_idx': 20, 'end_idx': 20, 'type': 'PER'}
# no_relation      org:top_members/employees      no_relation
# ----------
# ----------
# 1198 1980년 그랜홈은 미국 시민이 되었다. {'word': '그랜홈', 'start_idx': 6, 'end_idx': 8, 'type': 'PER'} {'word': '미국', 'start_idx': 11, 'end_idx': 12, 'type': 'LOC'}
# per:origin      per:place_of_residence      per:origin
# ----------
# ----------
# 1205 그리고 보포드 형제와 대립한 세력은 헨리의 중상모략에 노력했다. {'word': '보포드', 'start_idx': 4, 'end_idx': 6, 'type': 'PER'} {'word': '헨리', 'start_idx': 20, 'end_idx': 21, 'type': 'PER'}
# no_relation      no_relation      per:siblings
# ----------
# ----------
# 1206 장성택은 과거에는 김정남의 후계 옹립을 도왔지만 나중에 둘 사이에 거리가 생겼다. {'word': '김정남', 'start_idx': 10, 'end_idx': 12, 'type': 'PER'} {'word': '장성택', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# per:colleagues      per:colleagues      no_relation
# ----------
# ----------
# 1210 인천 '주안식구파' 부두목 출신인 유튜버 B씨가 올린 '진짜 조폭과 가짜 조폭 구별법' 영상은 조회 수 100만 달성을 앞둘 정도로 화제를 모으고 있다. {'word': 'B', 'start_idx': 23, 'end_idx': 23, 'type': 'PER'} {'word': '인천', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# no_relation      per:place_of_residence      per:origin
# ----------
# ----------
# 1233 히틀러유겐트 사단이 캐나다군 선봉 부대 일부를 압박해 3킬로미터 이상 후퇴시켰지만, 노스 노바스코샤 하이랜더 연대 잔존병들은 제25 SS 기갑척탄병 연대를 저지하고 견고한 방어선을 구축했다. {'word': '캐나다군', 'start_idx': 11, 'end_idx': 14, 'type': 'ORG'} {'word': '노스 노바스코샤 하이랜더 연대', 'start_idx': 47, 'end_idx': 62, 'type': 'ORG'}
# no_relation      org:members      org:members
# ----------
# ----------
# 1234 그는 2년간 바커의 감독을 맡으며 시즌을 리그 4위와 5위로 마무리하였다. {'word': '바커', 'start_idx': 7, 'end_idx': 8, 'type': 'PER'} {'word': '감독', 'start_idx': 11, 'end_idx': 12, 'type': 'POH'}
# no_relation      per:title      per:title
# ----------
# ----------
# 1247 환조(丸彫)로 된 단독상(單獨像)은 많지 않으나 북 프랑스, 라인 연안, 스칸디나비아 등을 중심으로 채색목각(彩色木刻)의 성모자상과 십자가에 못박힌 그리스도의 상이 만들어졌다. {'word': '丸彫', 'start_idx': 3, 'end_idx': 4, 'type': 'PER'} {'word': '환조', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'}
# no_relation      no_relation      per:alternate_names
# ----------
# ----------
# 1261 부파불교의 설일체유부의 논서 《대비바사론》 제172권에서도 동일한 취지로 말하고 있는데, 《순정리론》보다는 좀 더 자세하다. {'word': '부파불교', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': '대비바사론', 'start_idx': 17, 'end_idx': 21, 'type': 'POH'}
# org:product      no_relation      org:product
# ----------
# ----------
# 1275 하나금융투자는 30일 농심에 대해 3분기 국내시장은 저조한 실적을 거뒀으나 해외시장의 견조한 성장세로 이를 상쇄했다. {'word': '하나금융투자', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '농심', 'start_idx': 12, 'end_idx': 13, 'type': 'ORG'}
# no_relation      no_relation      org:members
# ----------
# ----------
# 1288 영화는 근로정신대 할머니와 함께 하는 시민모임(대표 이국언)의 요청으로 공무원과 시민을 대상으로 상영하며, 자세한 사항은 시 민주인권과(062-613-2083)에 문의하면 된다. {'word': '민주인권과', 'start_idx': 70, 'end_idx': 74, 'type': 'ORG'} {'word': '이국언', 'start_idx': 29, 'end_idx': 31, 'type': 'PER'}
# no_relation      org:top_members/employees      org:top_members/employees
# ----------
# ----------
# 1289 2015년 6월 8일 덴마크 축구 국가대표팀과의 친선 경기에서 몬테네그로 대표팀 데뷔전을 치렀다. {'word': '축구 국가대표팀', 'start_idx': 16, 'end_idx': 23, 'type': 'ORG'} {'word': '덴마크', 'start_idx': 12, 'end_idx': 14, 'type': 'LOC'}
# no_relation      org:place_of_headquarters      org:place_of_headquarters
# ----------
# ----------
# 1300 박 당선인은 금융노조 KB국민은행지부 위원장, 금융노조 전국은행산업노동조합협의회 의장, KB금융그룹 노동조합협의회 의장을 지냈다. {'word': '금융노조 전국은행산업노동조합협의회', 'start_idx': 26, 'end_idx': 43, 'type': 'ORG'} {'word': '박', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 1304 그가 이적하기 전 팀의 1루는 이숭용, 장영석, 오재일, 조중근이 번갈아 맡았으나, 트레이드로 영입한 그가 1루수로 완전히 정착했다. {'word': '이숭용', 'start_idx': 17, 'end_idx': 19, 'type': 'PER'} {'word': '조중근', 'start_idx': 32, 'end_idx': 34, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 1314 프레데리고의 이러한 시도는 유럽에서 기존에는 존재하지 않았던 인간형을 만들어내려는 것이었으며, 카스틸리오네가 아닌 프레데리고에서 ‘학자 기사’라는 인간형이 완성되었다. {'word': '프레데리고', 'start_idx': 0, 'end_idx': 4, 'type': 'PER'} {'word': '학자', 'start_idx': 73, 'end_idx': 74, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 1316 869년 9월 9일 대머리 카를은 메츠에서 로타링기아의 전체의 왕으로 선언했다. {'word': '메츠', 'start_idx': 19, 'end_idx': 20, 'type': 'ORG'} {'word': '카를', 'start_idx': 15, 'end_idx': 16, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 1328 반면, 『매송론』(梅松論)에 묘사되어 있는, 다타라하마 전투(多々良浜の戦い) 당시에 전투에 임한 다카우지의 출정 모습이 본 초상와 흡사하고, 교토로 개선하는 다카우지가 이때의 모습을 화공에게 그리게 하였다는 기록도 남아 있어 역시 「기마무사상」이 아시카가 다카우지의 초상화가 맞지 않겠느냐는 의견도 있다. {'word': '다카우지', 'start_idx': 54, 'end_idx': 57, 'type': 'PER'} {'word': '교토', 'start_idx': 79, 'end_idx': 80, 'type': 'LOC'}
# per:place_of_residence      per:place_of_residence      no_relation
# ----------
# ----------
# 1337 이때의 변화는 단치 교명의 변경 외 기존 학장 체제에서 총장 체제로의 전환이 이루어졌으며, 이에 총장 체제의 첫 총장은 서울법대를 졸업하고 동력자원부 장관(現 산업통상자원부 장관)을 역임하였던 최동규 당시 한국수자원공사 이사장을 선출하였다. {'word': '산업통상자원부', 'start_idx': 89, 'end_idx': 95, 'type': 'ORG'} {'word': '장관', 'start_idx': 84, 'end_idx': 85, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 1340 한편 지역 혁신가는 대통령직속 국가균형발전위원회(이하 균형위)가 선정하는 '교육‧복지, 문화‧관광, 마을‧환경, 산업‧기술 등 다양한 분야에서 혁신적인 사고로 새로운 가치를 창조하고 지역을 변화시켜 나가는 인재를 칭한다. {'word': '국가균형발전위원회', 'start_idx': 17, 'end_idx': 25, 'type': 'ORG'} {'word': '지역 혁신가', 'start_idx': 3, 'end_idx': 8, 'type': 'POH'}
# no_relation      no_relation      org:product
# ----------
# ----------
# 1341 그는 “삼성전기의 천진 공장은 2019년말 완공되어 20년 2분기부터 가동이 시작될 것으로 예상된다”며 “내년은 MLCC 수량이 전년대비 증가하고, 전장향 비중확대로 가격 하락 방어 가능성 높아 매출액 증가 가능성은 높다”고 지적했다. {'word': '삼성전기', 'start_idx': 4, 'end_idx': 7, 'type': 'ORG'} {'word': '천진', 'start_idx': 10, 'end_idx': 11, 'type': 'LOC'}
# no_relation      org:members      org:members
# ----------
# ----------
# 1342 한편, LH는 도시재생 전문인력 양성과 이를 위한 교육과정 및 전문자격 제도 등의 마련을 위해 지난 5월 ‘도시재생 전문가 양성 방안 연구용역’을 시행했고, 이번 공청회에서 그동안 연구된 중간결과를 공유하며 참석한 전문가들의 의견을 수렴했다. {'word': 'LH', 'start_idx': 4, 'end_idx': 5, 'type': 'ORG'} {'word': '도시재생 전문가 양성 방안 연구용역', 'start_idx': 60, 'end_idx': 78, 'type': 'POH'}
# org:product      org:product      no_relation
# ----------
# ----------
# 1349 세이브더 칠드런이 창립 100 주년을 맞이해 전북지역 초등학교와 중학교 아이들에게 자신에게 상처를 준 말을 쓰고, 그 말을 통해서 느낀 감정을 그림으로 그려서 보여 주는 행사인 전시행사가 22일 전북도교육청에서 열렸다. {'word': '세이브더 칠드런', 'start_idx': 0, 'end_idx': 7, 'type': 'ORG'} {'word': '전북', 'start_idx': 25, 'end_idx': 26, 'type': 'LOC'}
# no_relation      org:place_of_headquarters      org:place_of_headquarters
# ----------
# ----------
# 1364 곡성군 제7기 생활공감정책 참여단은 전라남도에서 3월 출범식을 갖고 현재 우리 군에서는 차미희 회장님을 비롯하여 5명이 활동을 하고 있다. {'word': '곡성군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': '회장', 'start_idx': 53, 'end_idx': 54, 'type': 'POH'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 1366 청조의 보호 하에 달라이 라마 정권이 성립하면서, 5대 달라이 라마로부터 티베트 불교계의 서열2위를 획득했다. {'word': '불교', 'start_idx': 45, 'end_idx': 46, 'type': 'ORG'} {'word': '티베트', 'start_idx': 41, 'end_idx': 43, 'type': 'LOC'}
# org:place_of_headquarters      org:political/religious_affiliation      org:place_of_headquarters
# ----------
# ----------
# 1369 이와 함께 스베토슬라프의 누이는 노가이의 아들 차카와 결혼했다. {'word': '스베토슬라프', 'start_idx': 6, 'end_idx': 11, 'type': 'PER'} {'word': '차카', 'start_idx': 26, 'end_idx': 27, 'type': 'POH'}
# no_relation      no_relation      per:spouse
# ----------
# ----------
# 1398 여운형이 통일 국가의 지도자가 됐어야 했다고 주장하기도 하는데, 그러면 건국일은 언제가 되는지, 건국일이 1945년 8월 15일 이전이 되는지, 이후가 되는지에 대해 언급을 해야 한다. {'word': '여운형', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '지도자', 'start_idx': 12, 'end_idx': 14, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 1400 아르튀르 2세의 집권 시기는 리모주의 마리와 첫 번째 혼인, 스코클랜드 왕비 드뢰의 욜랑드와 두 번째 혼인 등 두 차례의 혼인으로 유명하기도 하다. {'word': '아르튀르 2세', 'start_idx': 0, 'end_idx': 6, 'type': 'PER'} {'word': '리모주', 'start_idx': 16, 'end_idx': 18, 'type': 'LOC'}
# per:spouse      no_relation      per:spouse
# ----------
# ----------
# 1412 박재범 씨가 SNS에 글을 남기자 동료 연예인들과 팬들의 응원이 이어졌다. {'word': '박재범', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '연예인', 'start_idx': 22, 'end_idx': 24, 'type': 'POH'}
# per:title      per:title      no_relation
# ----------
# ----------
# 1422 2집 활동을 끝으로 정대욱, 이상문, 김태윤이 탈퇴하고 이석원은 회사원이 되었다. {'word': '김태윤', 'start_idx': 21, 'end_idx': 23, 'type': 'PER'} {'word': '정대욱', 'start_idx': 11, 'end_idx': 13, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 1442 지난 10월 한서희 씨와 정다은 씨는 동성연애 사실을 인정, 부인하며 크게 주목받았다. {'word': '한서희', 'start_idx': 7, 'end_idx': 9, 'type': 'PER'} {'word': '정다은', 'start_idx': 14, 'end_idx': 16, 'type': 'PER'}
# no_relation      no_relation      per:spouse
# ----------
# ----------
# 1444 천차오민 대만 국방 장관은 2004 년, 천수이볜 전 대통령의 총격 사건에 대해 사과했다. {'word': '국방', 'start_idx': 8, 'end_idx': 9, 'type': 'ORG'} {'word': '장관', 'start_idx': 11, 'end_idx': 12, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 1445 한편, 티켓베이는 지난 2015년 6월 론칭한 뮤지컬, 콘서트, 스포츠, 여행, 레저 등 다양한 카테고리의 티켓과 굿즈를 판매하고 구매할 수 있는 C2C 서비스다. {'word': '티켓베이', 'start_idx': 4, 'end_idx': 7, 'type': 'ORG'} {'word': '뮤지컬', 'start_idx': 26, 'end_idx': 28, 'type': 'POH'}
# no_relation      no_relation      org:product
# ----------
# ----------
# 1461 전라남도가 ‘청정 전남, 블루 이코노미’ 6대 핵심 프로젝트 가운데 하나인 ‘블루 에너지’ 분야에서 대규모 해상풍력발전단지 조성에 박차를 가하고 있다. {'word': '전라남도', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': '청정 전남, 블루 이코노미', 'start_idx': 7, 'end_idx': 20, 'type': 'POH'}
# no_relation      org:alternate_names      no_relation
# ----------
# ----------
# 1487 2018년에는 많은 주민들이 최근 살기 힘들다고 말은 하면서 적지 않은 돈이 드는 만수대 TV 설치에 극성이다면서 지역 우체국에서는 핀잔을 주었지만 이에 아랑곳하지 않았으며 외국 영화에 대한 인기가 날이 갈수록 높아지고 있다는 점을 당국도 알고 있다고 지적하고 이 같은 결정은 조선민주주의인민공화국 당국의 의도와는 달리 주민들의 외부 정보에 대한 호기심을 자극하는 방향으로 흘러갈 가능성도 있다. {'word': '우체국', 'start_idx': 67, 'end_idx': 69, 'type': 'ORG'} {'word': '조선민주주의인민공화국', 'start_idx': 155, 'end_idx': 165, 'type': 'ORG'}
# org:place_of_headquarters      org:member_of      org:place_of_headquarters
# ----------
# ----------
# 1492 전라남도교육청(교육감 장석웅)은 전남 도내 모든 유·초·중·고등학교로 하여금 2월 셋째 주에서 넷째 주 사이에 교육공동체 협의를 통해 3~5일 간 일정을 잡아‘새학년 집중준비기간’을 운영하도록 했다. {'word': '장석웅', 'start_idx': 12, 'end_idx': 14, 'type': 'PER'} {'word': '전남', 'start_idx': 18, 'end_idx': 19, 'type': 'LOC'}
# per:employee_of      per:employee_of      per:place_of_residence
# ----------
# ----------
# 1494 들은 "맛녀석 초창기 방송보면 이 정도로 뚱뚱하지 않았음...이 프로도 출연진 건강 좀 챙겨주길", "진짜 어제 재방으로 초창기때 맛녀석 보는데 유민상 님 너무 날씬해서 깜짝놀랐다", "건강을 위해서라도 다이어트 좀 하시길", "주 1회 찍는 건데..다른날 적게 먹고 운동하면 됨. 그냥 다들 먹는 걸 좋아해서 살찌는거임", "심근경색 조심" 등의 반응을 보였다. {'word': '유민상', 'start_idx': 81, 'end_idx': 83, 'type': 'PER'} {'word': '출연진', 'start_idx': 40, 'end_idx': 42, 'type': 'POH'}
# per:employee_of      no_relation      no_relation
# ----------
# ----------
# ...
# ----------
# ----------
# 7241 김태완(金泰完, 1971년 6월 1일 ~)은 전 축구 선수출신 축구 지도자이다. {'word': '김태완', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '선수', 'start_idx': 30, 'end_idx': 31, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 7253 기업은행 노조는 지난 3일 윤 행장이 선임된 이후 '낙하산 인사'로 규정짓고 출근 저지 투쟁을 벌여왔다. {'word': '윤', 'start_idx': 15, 'end_idx': 15, 'type': 'PER'} {'word': '기업은행 노조', 'start_idx': 0, 'end_idx': 6, 'type': 'ORG'}
# no_relation      no_relation      per:employee_of
# ----------
# ----------
# 7254 라본티의 저주는 1972년 독일 가르미슈파르텐키르헨에서 열렸던 에어 캐나다 실버 브룸 대회(현재의 세계 컬링 선수권 대회) 결승전에서, 미국 팀의 스킵인 로버트 라본티(Robert LaBonte)가 실수한 것을 노려 우승한 캐나다가 1980년 대회에서 우승할 때까지 세계 컬링 선수권 대회에서 계속 우승하지 못한 불운을 일컫는 말이다. {'word': '로버트 라본티', 'start_idx': 86, 'end_idx': 92, 'type': 'PER'} {'word': '스킵', 'start_idx': 82, 'end_idx': 83, 'type': 'POH'}
# per:alternate_names      per:alternate_names      per:title
# ----------
# ----------
# 7257 엘리자베스 2세가 뉴질랜드의 군주이며, 뉴질랜드의 총독이 여왕을 대신하는데, 현재 총독은 팻시 레디이다. {'word': '엘리자베스 2세', 'start_idx': 0, 'end_idx': 7, 'type': 'PER'} {'word': '총독', 'start_idx': 28, 'end_idx': 29, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 7266 로희는 엄마와 로린이가 노는 모습을 부럽다는 듯 따라해 보이기도 했다. {'word': '로희', 'start_idx': 0, 'end_idx': 1, 'type': 'PER'} {'word': '로린', 'start_idx': 8, 'end_idx': 9, 'type': 'PER'}
# per:siblings      per:siblings      per:parents
# ----------
# ----------
# 7267 군은 당초 3월 13일로 예정되어 있던 제75회 식목일 행사를 코로나 19가 심각단계로 격상됨에 따라 확산을 차단하기 위해 전면 취소하고, 관계 직원들만 서호면 장동마을 뒷산에 금년 조림사업 착수식을 가질 예정이다. {'word': '군', 'start_idx': 0, 'end_idx': 0, 'type': 'ORG'} {'word': '서호면', 'start_idx': 86, 'end_idx': 88, 'type': 'LOC'}
# no_relation      no_relation      org:members
# ----------
# ----------
# 7270 공연에 관한 브라이언 메이와 로저 테일러의 인터뷰(28분 분량), 투어 관계자들과의 인터뷰(19분 분량), 공연에 관한 다큐멘터리(30분 분량), 지금은 철거된 웸블리 스타디움을 기념하는 영상(5분 분량)으로 구성되어 있다. {'word': '로저 테일러', 'start_idx': 16, 'end_idx': 21, 'type': 'PER'} {'word': '브라이언 메이', 'start_idx': 7, 'end_idx': 13, 'type': 'PER'}
# per:colleagues      no_relation      per:colleagues
# ----------
# ----------
# 7272 욕실 곰팡이가 심해지자 안방에서 함께 잠을 자던 A씨 부부와 6살, 7살 아이는 졸지에 각방 생활을 해야 하는 '이산가족'이 됐다. {'word': 'A', 'start_idx': 27, 'end_idx': 27, 'type': 'PER'} {'word': '이산가족', 'start_idx': 63, 'end_idx': 66, 'type': 'POH'}
# per:alternate_names      no_relation      no_relation
# ----------
# ----------
# 7274 키릴로스는 당시 알렉산드리아의 국제적인 분위기 속에서 다른 기독교 종파와 유대교 및 이교도들과의 투쟁에 나섰다. {'word': '키릴로스', 'start_idx': 0, 'end_idx': 3, 'type': 'PER'} {'word': '기독교', 'start_idx': 33, 'end_idx': 35, 'type': 'ORG'}
# per:religion      per:religion      no_relation
# ----------
# ----------
# 7282 예를 들어 1949년 제14연대장 오동기 등이 연루된 인민해방군 사건이나, 1950년 남로당 이강국의 연인이라는 김수임을 체포해 처형한 사건, 소총을 관 속에 숨겨 대구로 이동하던 불순 분자들을 적발한 사건, 부산 정치 파동의 빌미가 된 부산 금정산 공비 사건 등이 있다. {'word': '김수임', 'start_idx': 63, 'end_idx': 65, 'type': 'PER'} {'word': '부산', 'start_idx': 133, 'end_idx': 134, 'type': 'POH'}
# per:place_of_death      per:place_of_death      no_relation
# ----------
# ----------
# 7298 김구용(金九容, 1338년 ~ 1384년)은 고려 후기의 문신으로 김방경의 고손자이다. {'word': '김구용', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '김방경', 'start_idx': 37, 'end_idx': 39, 'type': 'PER'}
# per:parents      per:parents      per:other_family
# ----------
# ----------
# 7308 17세기에서 19세기동안 반불감정은 주로 유럽대륙에서 경쟁관계에 있던 영국과의 사이에서 일어났으며, 현재는 외교적 마찰이 빈번한 미국에서 현저하다. {'word': '영국', 'start_idx': 39, 'end_idx': 40, 'type': 'ORG'} {'word': '유럽', 'start_idx': 23, 'end_idx': 24, 'type': 'LOC'}
# org:place_of_headquarters      org:member_of      no_relation
# ----------
# ----------
# 7311 위너 멤버 강승윤 씨가 국기 다는 법에 맞춰 태극기 사진을 올렸다. {'word': '위너', 'start_idx': 0, 'end_idx': 1, 'type': 'ORG'} {'word': '멤버', 'start_idx': 3, 'end_idx': 4, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      per:title
# ----------
# ----------
# 7325 이 의원은 이와 관련, "충주시민들이 겪고 있는 어려움을 해소하고 삶의 질을 높이는 시설을 만들기 위한 사업비 확보에 신경을 썼다"고 밝혔다. {'word': '이', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '충주', 'start_idx': 14, 'end_idx': 15, 'type': 'LOC'}
# no_relation      per:place_of_residence      no_relation
# ----------
# ----------
# 7326 이날 진정무 청장은 ‘경남 치안의 현황과 경남 경찰의 역할’을 주제로 특강을 진행했으며, 특강에는 '21세기형 새로운 리더십' 교양강좌 수강생 200여 명이 참석해 성황을 이뤘다. {'word': '진정무', 'start_idx': 3, 'end_idx': 5, 'type': 'PER'} {'word': '경찰', 'start_idx': 26, 'end_idx': 27, 'type': 'ORG'}
# no_relation      per:title      no_relation
# ----------
# ----------
# 7327 그룹 ITZY(있지) 예지가 새 앨범 '있지 미'(IT'z ME)의 개인 티저를 공개했다. {'word': '예지', 'start_idx': 12, 'end_idx': 13, 'type': 'PER'} {'word': '있지', 'start_idx': 8, 'end_idx': 9, 'type': 'PER'}
# per:alternate_names      per:employee_of      per:employee_of
# ----------
# ----------
# 7328 김성찬 함평군수 예비후보는 교통 취약지역 마을 주민들의 불편을 해소하기 위해 도입된 100원 행복택시 제도의 지원대상과 범위를 확대 운영하겠다는 공약을 발표했다. {'word': '김성찬', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '군수', 'start_idx': 6, 'end_idx': 7, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 7331 1904년 11월 1일 성균관 박사(판임관 6등)에 임명되었고 1908년 10월 호남학회 평의원을 역임했다. {'word': '성균관', 'start_idx': 13, 'end_idx': 15, 'type': 'ORG'} {'word': '박사', 'start_idx': 17, 'end_idx': 18, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 7335 특히 차남 지치부노미야의 비였던 세쓰코(勢津子) 비를 마음에 들어하여 서로 친교가 깊었고, 매년 3월 3일 히나마쓰리마다 세쓰코 비가 시집올 때 가져온 히나 인형을 저택에 장식해놓고 그것을 데이메이 황후에게 보이곤 했다고 한다. {'word': '데이메이', 'start_idx': 106, 'end_idx': 109, 'type': 'PER'} {'word': '세쓰코', 'start_idx': 68, 'end_idx': 70, 'type': 'PER'}
# no_relation      per:spouse      per:spouse
# ----------
# ----------
# 7342 LG유플러스가 오는 7월 일본 올림픽을 관람하는 5G 고객들을 위해 국내 통신사 중 최초로 일본 5G 로밍 테스트를 성공적으로 마쳤다고 10일 밝혔다. {'word': 'LG유플러스', 'start_idx': 0, 'end_idx': 5, 'type': 'ORG'} {'word': '고객', 'start_idx': 30, 'end_idx': 31, 'type': 'POH'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 7367 바르바로스 하이레딘 파샤(터키어: Barbaros Hayreddin Paşa, ~ 1546년 7월 4일)는 오스만 출신의 해적(Cossair)으로 훗날 오스만 해군의 제독이 되었다. {'word': '오스만 해군', 'start_idx': 85, 'end_idx': 90, 'type': 'ORG'} {'word': '오스만', 'start_idx': 60, 'end_idx': 62, 'type': 'LOC'}
# org:place_of_headquarters      no_relation      no_relation
# ----------
# ----------
# 7376 미국 의회와 행정부 사이에서 한국의 인권문제 때문에 군사원조를 중단해야 하는 사안에 대한 논의가 진행 중일 때도 한국 정부는 인권문제 때문이라는 단서만 빼준다면 더 많은 군사원조 삭감도 받아들일 수 있다고 제시했다. {'word': '행정부', 'start_idx': 7, 'end_idx': 9, 'type': 'ORG'} {'word': '미국', 'start_idx': 0, 'end_idx': 1, 'type': 'LOC'}
# org:member_of      org:member_of      org:place_of_headquarters
# ----------
# ----------
# 7390 이러한 하느님의 모습은 루카복음 전체에 등장하는 예수님의 말씀으로 확대되고 있으며, 이는 주로 당시의 삶의 자리에서는 주류세력들과 소외된 자에게 관심을 가지고 있는 루카의 신학적 관점을 담고 있음을 대변하고 있는 것이다. {'word': '예수', 'start_idx': 27, 'end_idx': 28, 'type': 'PER'} {'word': '하느님', 'start_idx': 4, 'end_idx': 6, 'type': 'PER'}
# no_relation      per:alternate_names      no_relation
# ----------
# ----------
# 7391 스푸트니크의 존재는 소련이 미국 본토까지 닿을 수 있는 강력한 미사일을 소유하고 있을지도 모른다는 증거이기도 했다. {'word': '소련', 'start_idx': 11, 'end_idx': 12, 'type': 'ORG'} {'word': '스푸트니크', 'start_idx': 0, 'end_idx': 4, 'type': 'POH'}
# org:product      no_relation      no_relation
# ----------
# ----------
# 7413 그의 문집은 외손 국포 강박이 정리했고, 강박의 손자 강세륜과 강세백이 재정리하여 간행하였고, 이서우의 직계 후손들에게 전해주었다. {'word': '국포 강박', 'start_idx': 10, 'end_idx': 14, 'type': 'PER'} {'word': '외손', 'start_idx': 7, 'end_idx': 8, 'type': 'POH'}
# per:title      per:other_family      per:other_family
# ----------
# ----------
# 7418 이날 대책회의에는 청와대 노영민 비서실장, 김상조 정책실장, 정의용 국가안보실장 등 3실장과 수석 보좌관 등이 참석했다. {'word': '청와대', 'start_idx': 10, 'end_idx': 12, 'type': 'ORG'} {'word': '국가안보실장', 'start_idx': 38, 'end_idx': 43, 'type': 'POH'}
# org:top_members/employees      no_relation      org:top_members/employees
# ----------
# ----------
# 7450 조씨가 한영외고에 다닐 때 학교 친구 2명과 함께 '나비의 날개에서 발견한 광자 결정 구조의 제작 및 측정'이라는 연구 과제를 수행해 한국물리학회가 주는 장려상을 받은 데 대해서도 의혹이 일고 있다. {'word': '조', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '2명', 'start_idx': 21, 'end_idx': 22, 'type': 'NOH'}
# per:colleagues      per:colleagues      no_relation
# ----------
# ----------
# 7454 그 말을 듣던 이경규 씨가 강호동 씨에게 "길게 녹화해서 사람 하나 살린 것"이라고 말하자, 박하선 씨도 "맞다. 제가 집안을 일으켰다"고 답하며 고마움을 전했다. {'word': '강호동', 'start_idx': 15, 'end_idx': 17, 'type': 'PER'} {'word': '이경규', 'start_idx': 8, 'end_idx': 10, 'type': 'PER'}
# per:colleagues      per:colleagues      no_relation
# ----------
# ----------
# 7468 무쓰 아이즈 번 제9대 번주이며 교토 수호직을 역임했다. {'word': '무쓰 아이즈 번', 'start_idx': 0, 'end_idx': 7, 'type': 'ORG'} {'word': '번주', 'start_idx': 13, 'end_idx': 14, 'type': 'POH'}
# org:top_members/employees      per:title      per:title
# ----------
# ----------
# 7490 김 연구원은 “PRASAC의 자산증가율은 2017년 40%, 2018년 36%이며, 수익성도 매우 높아 30% 정도의 자기자본이익률(ROE)과 3% 후반대의 총자산순이익률(ROA)을 보이고 있다”라고 판단했다. {'word': 'PRASAC', 'start_idx': 8, 'end_idx': 13, 'type': 'ORG'} {'word': '김', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'}
# org:top_members/employees      no_relation      org:top_members/employees
# ----------
# ----------
# 7496 하지만 연봉 문제로 대전 구단과 마찰을 빚게 되었고 결국 주장으로 선임된 지 얼마 되지 않아 2009년 시즌 직전에 대전과 상호 간에 계약을 해지하고 현역에서 물러났다. {'word': '대전 구단', 'start_idx': 11, 'end_idx': 15, 'type': 'ORG'} {'word': '주장', 'start_idx': 32, 'end_idx': 33, 'type': 'POH'}
# org:top_members/employees      org:top_members/employees      no_relation
# ----------
# ----------
# 7518 김철민 씨는 당시 페이스북에 올린 글에서 "오늘 아침 9시 폐암 말기 판정을 받았습니다. 이별을 해야 하기에 슬픔의 눈물이 앞을 가리네요"라며 "한편으론 먼저 이별을 하신 부모님과 형님을 다시 만날 수 있다는 생각을 하니 그리 슬프지만은 않습니다"라고 말했다. {'word': '페이스북', 'start_idx': 10, 'end_idx': 13, 'type': 'ORG'} {'word': '김철민', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'}
# no_relation      no_relation      org:top_members/employees
# ----------
# ----------
# 7520 김동진의 배신으로 동대문패는 분노하였고 동대문패 간부들은 KLO부대와 정양원들을 제거하자고 제의했으나 이정재는 거절했고 자신을 죽일 기회는 있었으나 저들은 자신을 죽이지 않았기에 이일을 덮어두기로 했고 김동진을 제거할 계획을 세운다. {'word': '정양원', 'start_idx': 39, 'end_idx': 41, 'type': 'ORG'} {'word': '이정재', 'start_idx': 57, 'end_idx': 59, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 7574 숙종의 초비 인경왕후가 죽은 후 1년 후에 숙종의 모후인 명성왕후 김씨와 외가 친척인 송시열의 추천으로 왕비로 뽑힌다. {'word': '명성왕후', 'start_idx': 32, 'end_idx': 35, 'type': 'PER'} {'word': '인경왕후', 'start_idx': 7, 'end_idx': 10, 'type': 'PER'}
# per:other_family      no_relation      per:other_family
# ----------
# ----------
# 7575 그러나 민정당 계열 대부분은 대표 경험이 없는 하토야마보다는, 민정당의 마지막 총재였던 마치다 다다하루가 대표로 어울린다는 의견이 우세해, 결국 민정당 계열은 마치다를 총재로 옹립해 일본진보당을 결성하면서 구상은 좌절되었다. {'word': '하토야마', 'start_idx': 26, 'end_idx': 29, 'type': 'PER'} {'word': '대표', 'start_idx': 59, 'end_idx': 60, 'type': 'POH'}
# per:title      no_relation      per:title
# ----------
# ----------
# 7577 데 리트와 호날두는 각각 네덜란드, 포르투갈 국가대표 선수로 출전했다. {'word': '호날두', 'start_idx': 6, 'end_idx': 8, 'type': 'PER'} {'word': '데 리트', 'start_idx': 0, 'end_idx': 3, 'type': 'PER'}
# no_relation      per:colleagues      per:colleagues
# ----------
# ----------
# 7579 최종 후보로 남으면서 등번호 1번이 주어져 있었던 베이징 올림픽 야구 국가대표팀 후보에 관해서는 허리 통증 때문에 오스트레일리아와의 강화 시합에 나갈 수 없게되어 그대로 명단에서 제외되었다. {'word': '야구 국가대표팀', 'start_idx': 36, 'end_idx': 43, 'type': 'ORG'} {'word': '베이징 올림픽', 'start_idx': 28, 'end_idx': 34, 'type': 'POH'}
# org:member_of      org:member_of      no_relation
# ----------
# ----------
# 7598 앞서 조선대학교는 교육부의 권고에 따라 2020학년도 1학기 강의를 4월 3일까지 전면 온라인 강의로 진행하기로 결정했다. {'word': '조선대학교', 'start_idx': 3, 'end_idx': 7, 'type': 'ORG'} {'word': '교육부', 'start_idx': 10, 'end_idx': 12, 'type': 'ORG'}
# org:member_of      org:member_of      no_relation
# ----------
# ----------
# 7626 고조부 원안 이래 4대가 삼공에 오른[사세삼공, 四世三公] 명문 집안에서 원봉의 적자로 태어나 그 위세가 대단했다. {'word': '원봉', 'start_idx': 41, 'end_idx': 42, 'type': 'PER'} {'word': '삼공', 'start_idx': 14, 'end_idx': 15, 'type': 'POH'}
# no_relation      no_relation      per:title
# ----------
# ----------
# 7649 그룹 크레용팝 출신 BJ 엘린(김민영)이 그의 열혈팬에 한 '로맨스 스캠'을 모두 인정하고 사과한 이후 근황을 전했다. {'word': 'BJ 엘린', 'start_idx': 11, 'end_idx': 15, 'type': 'PER'} {'word': '크레용팝', 'start_idx': 3, 'end_idx': 6, 'type': 'ORG'}
# per:origin      per:employee_of      per:origin
# ----------
# ----------
# 7655 학생들이 자발적으로 진행하는 교내 재판의 심리기간은 5일. 료코와 간바라는 그 동안 모은 증거와 증인을 바탕으로 자신의 주장이 옮음을 입증하기 시작한다. {'word': '간바라', 'start_idx': 37, 'end_idx': 39, 'type': 'PER'} {'word': '료코', 'start_idx': 33, 'end_idx': 34, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 7658 증조부 엄성의 두 부인 중 누가 할아버지 엄석구의 생모인지 여부는 불확실하다. {'word': '엄성', 'start_idx': 4, 'end_idx': 5, 'type': 'PER'} {'word': '증조부', 'start_idx': 0, 'end_idx': 2, 'type': 'POH'}
# per:alternate_names      per:parents      per:parents
# ----------
# ----------
# 7663 인촌 김성수와 기업인 김연수의 친할아버지로 김성수 집안의 가계를 실질적으로 일으킨 사람이라 한다. {'word': '김성수', 'start_idx': 24, 'end_idx': 26, 'type': 'PER'} {'word': '김연수', 'start_idx': 12, 'end_idx': 14, 'type': 'PER'}
# per:other_family      per:siblings      per:other_family
# ----------
# ----------
# 7682 김 예비후보는“나주와 화순을 유기적으로 연계하고 한전, 에너지밸리, 에너지클러스트 등 연관된 산업생태계를 활용할 경우, 세계에너지엑스포 유치가 불가능한 일은 아니다”라면서“엑스포 유치와 함께 도시재생 프로젝트 등 다양한 사회적 인프라를 구축하는 작업이야말로 혁신적인 지역발전을 담보하는 변곡점”이라고 의미를 부여했다. {'word': '한전', 'start_idx': 27, 'end_idx': 28, 'type': 'ORG'} {'word': '나주', 'start_idx': 8, 'end_idx': 9, 'type': 'LOC'}
# no_relation      org:place_of_headquarters      no_relation
# ----------
# ----------
# 7700 전라남도는 지난 2월 현장 서류평가와 전문가 심사 등을 통해 17개 시군 30개 운영마을·농가를 최종 선정했다. {'word': '전라남도', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': '17개', 'start_idx': 34, 'end_idx': 36, 'type': 'NOH'}
# no_relation      org:number_of_employees/members      org:number_of_employees/members
# ----------
# ----------
# 7709 고레에다 히로카즈 감독이 신작의 주인공이자 프랑스의 전설적인 여배우 카트린 드뇌브와의 일화들을 통해 영화를 둘러싼 풍부한 이야깃거리를 제공했다. {'word': '고레에다 히로카즈', 'start_idx': 0, 'end_idx': 8, 'type': 'PER'} {'word': '카트린 드뇌브', 'start_idx': 38, 'end_idx': 44, 'type': 'POH'}
# no_relation      per:colleagues      per:colleagues
# ----------
# ----------
# 7712 네이버는 주로 인공지능(AI) 기술을 활용한 부작용 최소화에 주력하고 있으며, 카카오는 문제가 되는 서비스를 잠정 폐지하고 플랫폼 전반을 전면 개편할 방침이다. {'word': '네이버', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'} {'word': 'AI', 'start_idx': 13, 'end_idx': 14, 'type': 'POH'}
# org:product      no_relation      no_relation
# ----------
# ----------
# 7719 금융위원회 재직 당시 자신이 관리ㆍ감독해야 할 업체 관계자들에게 금품과 향응을 제공받은 혐의를 받는 유재수(55) 전 부산시 경제부시장이 27일 구속됐다. {'word': '유재수', 'start_idx': 56, 'end_idx': 58, 'type': 'PER'} {'word': '55', 'start_idx': 60, 'end_idx': 61, 'type': 'NOH'}
# no_relation      no_relation      per:alternate_names
# ----------
# ----------
# 7721 박완주 의원은 “공공시설과 국유지를 정원으로 조성하여 천안시민께 녹색휴식 공간을 제공하는 사업에 선정 돼 기쁘다”며 “많은 시민이 이용하는 시설에 미세먼지 저감과 공기질 개선에 기여할 수 있는 생활밀착형 숲 조성사업이 확대되어 언제, 어디서나 정원에 접근할 수 있도록 더욱 노력하겠다” 말했다. {'word': '박완주', 'start_idx': 0, 'end_idx': 2, 'type': 'PER'} {'word': '천안', 'start_idx': 30, 'end_idx': 31, 'type': 'LOC'}
# no_relation      per:place_of_residence      per:place_of_residence
# ----------
# ----------
# 7722 2013년 7월 4일 교황 프란치스코는 공식적으로 요한 바오로 2세의 전구에 의한 두 번째 기적을 인가하고, 그를 시성한다고 선포하였다. {'word': '요한 바오로 2세', 'start_idx': 28, 'end_idx': 36, 'type': 'PER'} {'word': '프란치스코', 'start_idx': 15, 'end_idx': 19, 'type': 'PER'}
# no_relation      no_relation      per:colleagues
# ----------
# ----------
# 7727 송진우는 김구의 충칭 임정의 통치권 주장을 미군정에서 도저히 받아들이지 않을 것이라고 판단했던 것이다. {'word': '김구', 'start_idx': 5, 'end_idx': 6, 'type': 'PER'} {'word': '충칭', 'start_idx': 9, 'end_idx': 10, 'type': 'LOC'}
# per:employee_of      per:place_of_residence      per:employee_of
# ----------
# ----------
# 7737 잉글랜드 성공회의 성인이기도 하며, 성공회에서는 8월 13일을 나이팅게일의 축일로 지키고 있다. {'word': '성공회', 'start_idx': 20, 'end_idx': 22, 'type': 'ORG'} {'word': '성인', 'start_idx': 10, 'end_idx': 11, 'type': 'POH'}
# org:top_members/employees      no_relation      no_relation
# ----------
# ----------
# 7743 올리브영은 1일 오전 서울시 마포구에 위치한 서울시립청소녀건강센터에 여성 위생용품이 담긴 ‘핑크박스’ 1000개를 전달했다고 1일 밝혔다. {'word': '올리브영', 'start_idx': 0, 'end_idx': 3, 'type': 'ORG'} {'word': '서울시', 'start_idx': 12, 'end_idx': 14, 'type': 'LOC'}
# no_relation      no_relation      org:place_of_headquarters
# ----------
# ----------
# 7748 그러자 다윗은 [[요압]] 대신 요압의 어머니 [[스루야]]의 자매 [[나하스]]의 딸 [[아비가일]]과 혼인 관계인 [[이드라]]의 아들 [[아마사]]를 내세웠다. {'word': '나하스', 'start_idx': 40, 'end_idx': 42, 'type': 'PER'} {'word': '다윗', 'start_idx': 4, 'end_idx': 5, 'type': 'PER'}
# no_relation      per:siblings      per:other_family
# ----------
