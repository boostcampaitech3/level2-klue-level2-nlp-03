# %%
import csv
import pandas as pd
files = []

# %%
first = pd.read_csv('./results/first.csv')
second = pd.read_csv('./results/second.csv')
third = pd.read_csv('./results/third.csv')
fourth = pd.read_csv('./results/fourth.csv')
fifth = pd.read_csv('./results/fifth.csv')
seven = pd.read_csv('./results/seven.csv')
rberts = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_rbert_2100_last_2400(preprocess)/final/submission_final_roberta_large_end.csv')

# %%
rberts.pred_label.value_counts()
# Out:
# no_relation                            4790
# per:title                               780
# org:top_members/employees               316
# per:employee_of                         294
# org:place_of_headquarters               255
# org:product                             218
# per:origin                              161
# per:colleagues                          137
# per:alternate_names                     112
# org:members                              99
# org:member_of                            88
# org:alternate_names                      64
# per:product                              62
# per:spouse                               61
# per:place_of_residence                   60
# per:parents                              36
# per:children                             35
# per:siblings                             33
# org:number_of_employees/members          21
# per:other_family                         21
# org:political/religious_affiliation      18
# ...

# %%
rberts_best = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction/final/submission_final_roberta_large_end.csv')
rberts_best.pred_label.value_counts()
# Out:
# no_relation                            4857
# per:title                               737
# org:top_members/employees               354
# per:employee_of                         302
# org:place_of_headquarters               236
# org:product                             206
# per:origin                              154
# per:colleagues                          130
# per:alternate_names                     105
# org:members                             104
# org:member_of                            92
# org:alternate_names                      67
# per:spouse                               57
# per:product                              55
# per:place_of_residence                   46
# per:parents                              34
# per:children                             33
# per:siblings                             31
# per:other_family                         24
# org:number_of_employees/members          21
# per:date_of_death                        19
# ...

# %%
rberts_more = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction/final/submission_final_roberta_large_end.csv')
rberts_more.pred_label.value_counts()
# Out:
# no_relation                            4774
# per:title                               750
# org:top_members/employees               373
# per:employee_of                         313
# org:place_of_headquarters               243
# org:product                             206
# per:origin                              149
# per:colleagues                          134
# per:alternate_names                     111
# org:members                             103
# org:member_of                            87
# per:place_of_residence                   65
# per:product                              64
# org:alternate_names                      63
# per:spouse                               63
# per:parents                              35
# per:children                             34
# per:siblings                             31
# org:number_of_employees/members          20
# per:other_family                         20
# org:founded                              20
# ...

# %%
rberts_late = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction/final/submission_final_roberta_large_end.csv')
rberts_late.pred_label.value_counts()
# Out:
# no_relation                            4750
# per:title                               759
# org:top_members/employees               381
# per:employee_of                         311
# org:place_of_headquarters               225
# org:product                             211
# per:origin                              151
# per:colleagues                          128
# per:alternate_names                     116
# org:members                              96
# org:member_of                            92
# per:place_of_residence                   73
# per:spouse                               65
# org:alternate_names                      64
# per:product                              63
# per:parents                              40
# per:children                             37
# per:siblings                             31
# per:other_family                         23
# org:number_of_employees/members          21
# org:founded                              20
# ...

# %%
df1 = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_rbert_2100_last_2400(preprocess)/roberta-large/submission_0_end.csv')
df2 = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_rbert_2100_last_2400(preprocess)/roberta-large/submission_1_end.csv')
df3 = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_rbert_2100_last_2400(preprocess)/roberta-large/submission_2_end.csv')
df4 = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_rbert_2100_last_2400(preprocess)/roberta-large/submission_3_end.csv')
df5 = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_rbert_2100_dropout(preprocess)/roberta-large/submission_0_end.csv')

# %%
import csv
import pandas as pd
test_csv = pd.read_csv('/opt/ml/dataset/test/test_data.csv')

# %%
single = pd.read_csv('/opt/ml/tests/level2-klue-level2-nlp-03/custom_baseline_ver3/code/prediction_rbert_2100_last_2400(preprocess)/roberta-large/submission_0_end.csv')

# %%
cnt5
# Out:
# 709

# %%
cnt5 = 0
for idx, (fir, rbert) in enumerate(zip(second['pred_label'],rberts_late['pred_label'])):
    if not (fir == rbert):
        print('-'*10)
        print(idx, test_csv['sentence'][idx],test_csv['subject_entity'][idx], test_csv['object_entity'][idx])
        print(fir, ' '*4, ' '*4, rbert)
        print('-'*10)
        cnt5+= 1
# Out:
# ----------
# 18 A 씨는 대구 방문 6일째 질병관리본부에 전화했다. {'word': 'A', 'start_idx': 0, 'end_idx': 0, 'type': 'PER'} {'word': '대구', 'start_idx': 5, 'end_idx': 6, 'type': 'LOC'}
# no_relation           per:place_of_residence
# ----------
# ----------
# 22 이번 행사에 참여한 광주여대 재학생은 "평소 관심이 있던 마케팅·브랜드 분야의 현직자와 만나 소통할 수 있는 것도 의미 있었으며 진심어린 조언에 힘을 얻었다"고 말했다. {'word': '광주여대', 'start_idx': 11, 'end_idx': 14, 'type': 'ORG'} {'word': '재학생', 'start_idx': 16, 'end_idx': 18, 'type': 'POH'}
# org:top_members/employees           no_relation
# ----------
# ----------
# 25 이에 따라 제주특별자치도청은 한국정보화진흥원을 제주로 이전하는 방안과 대구로의 이전시 현재 대구 혁신도시 이전 공공기관으로 분류된 교육과학기술연수원과 맞바꾸는 방안을 요구했으나 대구광역시청과의 협의가 원활하지 못하면서 1년 넘도록 공공기관 이전계획을 마무리짓지 못하고 있다. {'word': '한국정보화진흥원', 'start_idx': 16, 'end_idx': 23, 'type': 'ORG'} {'word': '대구', 'start_idx': 39, 'end_idx': 40, 'type': 'LOC'}
# no_relation           org:place_of_headquarters
# ----------
# ----------
# ...

# %%
first['pred_label']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-4f91bc1ce142> in <module>
# ----> 1 first['pred_label']
#
# TypeError: string indices must be integers
